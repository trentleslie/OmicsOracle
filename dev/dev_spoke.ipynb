# %%
from pyArango.connection import Connection
import os
from dotenv import load_dotenv
import logging

class SpokeWrapper:
    def __init__(self):
        load_dotenv(os.path.join(os.getcwd(), '..', '.env'))
        
        self.host = os.getenv('ARANGO_HOST')
        self.db_name = os.getenv('ARANGO_DB')
        self.username = os.getenv('ARANGO_USERNAME')
        self.password = os.getenv('ARANGO_PASSWORD')
        
        try:
            self.conn = Connection(arangoURL=self.host, username=self.username, password=self.password)
            self.db = self.conn[self.db_name]
            logging.info(f"Connected to database: {self.db_name}")
        except Exception as e:
            logging.error(f"Failed to connect to database: {e}")
            raise

    def list_collections(self):
        return list(self.db.collections.keys())

    def execute_aql(self, query, bind_vars=None):
        try:
            return list(self.db.AQLQuery(query, bindVars=bind_vars, rawResults=True))
        except Exception as e:
            logging.error(f"AQL Query Error: {e}")
            return []

    def get_entity(self, collection, key):
        try:
            return self.db[collection][key]
        except Exception as e:
            logging.error(f"Failed to retrieve entity: {e}")
            return None

    def get_connected_entities(self, start_id, edge_label=None):
        query = """
        FOR v, e IN 1..1 OUTBOUND @start_id @@edge_collection
        FILTER e.label == @edge_label
        RETURN {entity: v, edge: e}
        """
        bind_vars = {
            'start_id': start_id,
            '@edge_collection': 'Edges',
            'edge_label': edge_label
        }
        return self.execute_aql(query, bind_vars=bind_vars)

def test_spoke_wrapper():
    spoke = SpokeWrapper()
    
    logging.info("Listing all collections:")
    logging.info(spoke.list_collections())
    
    logging.info("\nFetching a single entity:")
    entity = spoke.get_entity('Nodes', '100005')  # Adjust the key if needed
    logging.info(entity)
    
    if entity:
        logging.info("\nFetching connected entities:")
        connected = spoke.get_connected_entities(entity._id, "PARTICIPATES_GpPW")
        logging.info(f"Number of connected entities: {len(connected)}")
        for item in connected[:5]:  # Print the first 5 connected entities
            logging.info(f"Entity: {item['entity']}")
            logging.info(f"Edge: {item['edge']}")
            logging.info("---")

if __name__ == "__main__":
    logging.basicConfig(level=logging.INFO)
    test_spoke_wrapper()
# Out:
# INFO:root:Connected to database: spoke23_human
# INFO:root:Listing all collections:
# INFO:root:['_analyzers', '_jobs', 'Nodes', '_apps', '_aqlfunctions', 'Edges', '_appbundles', '_graphs', '_queues', '_frontend']
# INFO:root:
# Fetching a single entity:
# INFO:root:ArangoDoc '_id: Nodes/100005, _key: 100005, _rev: _iYaMlBe---': <store: {'type': 'node', 'id': '100005', 'labels': ['Gene'], 'properties': <store: {'license': 'CC0 1.0', 'identifier': 7054, 'ensembl': 'ENSG00000180176', 'Mate_Version': 'V1', 'chromosome': '11', 'name': 'TH', 'description': 'tyrosine hydroxylase', 'source': 'Entrez Gene', 'chembl_id': 'CHEMBL1969'}>}>
# INFO:root:
# Fetching connected entities:
# INFO:root:Number of connected entities: 48
# INFO:root:Entity: {'_key': '35575', '_id': 'Nodes/35575', '_rev': '_iYaKmnC---', 'type': 'node', 'id': '35575', 'labels': ['Pathway'], 'properties': {'identifier': 'WP4220_r120526', 'license': 'CC BY 4.0', 'database': 'WikiPathways', 'Mate_Version': 'V1', 'name': 'Neurotransmitter disorders', 'source': 'WikiPathways', 'url': 'http://www.wikipathways.org/instance/WP4220_r120526'}}
# INFO:root:Edge: {'_key': '33171379', '_id': 'Edges/33171379', '_from': 'Nodes/100005', '_to': 'Nodes/35575', '_rev': '_iYkm8bW---', 'label': 'PARTICIPATES_GpPW', 'properties': {'license': 'CC BY 4.0', 'database': 'WikiPathways', 'vestige': False, 'Mate_Version': 'V1', 'reverse_degrees': 4, 'unbiased': False, 'forward_degrees': 24, 'source': 'WikiPathways'}, 'start': {'id': '100005', 'labels': ['Gene'], 'properties': {'license': 'CC0 1.0', 'identifier': 7054, 'ensembl': 'ENSG00000180176', 'Mate_Version': 'V1', 'chromosome': '11', 'name': 'TH', 'description': 'tyrosine hydroxylase', 'source': 'Entrez Gene', 'chembl_id': 'CHEMBL1969'}}, 'end': {'id': '35575', 'labels': ['Pathway'], 'properties': {'identifier': 'WP4220_r120526', 'license': 'CC BY 4.0', 'database': 'WikiPathways', 'Mate_Version': 'V1', 'name': 'Neurotransmitter disorders', 'source': 'WikiPathways', 'url': 'http://www.wikipathways.org/instance/WP4220_r120526'}}}
# INFO:root:---
# INFO:root:Entity: {'_key': '35337', '_id': 'Nodes/35337', '_rev': '_iYaKmIq---', 'type': 'node', 'id': '35337', 'labels': ['Pathway'], 'properties': {'identifier': 'WP4220_r106196', 'license': 'CC BY 4.0', 'database': 'WikiPathways', 'vestige': True, 'Mate_Version': 'V1', 'name': 'Neurotransmitter Disorders', 'source': 'WikiPathways', 'url': 'http://www.wikipathways.org/instance/WP4220_r106196'}}
# INFO:root:Edge: {'_key': '33171371', '_id': 'Edges/33171371', '_from': 'Nodes/100005', '_to': 'Nodes/35337', '_rev': '_iYkm8a6---', 'label': 'PARTICIPATES_GpPW', 'properties': {'license': 'CC BY 4.0', 'database': 'WikiPathways', 'vestige': True, 'Mate_Version': 'V1', 'reverse_degrees': 4, 'unbiased': False, 'forward_degrees': 24, 'source': 'WikiPathways'}, 'start': {'id': '100005', 'labels': ['Gene'], 'properties': {'license': 'CC0 1.0', 'identifier': 7054, 'ensembl': 'ENSG00000180176', 'Mate_Version': 'V1', 'chromosome': '11', 'name': 'TH', 'description': 'tyrosine hydroxylase', 'source': 'Entrez Gene', 'chembl_id': 'CHEMBL1969'}}, 'end': {'id': '35337', 'labels': ['Pathway'], 'properties': {'identifier': 'WP4220_r106196', 'license': 'CC BY 4.0', 'database': 'WikiPathways', 'vestige': True, 'Mate_Version': 'V1', 'name': 'Neurotransmitter Disorders', 'source': 'WikiPathways', 'url': 'http://www.wikipathways.org/instance/WP4220_r106196'}}}
# INFO:root:---
# INFO:root:Entity: {'_key': '34720', '_id': 'Nodes/34720', '_rev': '_iYaKk7W---', 'type': 'node', 'id': '34720', 'labels': ['Pathway'], 'properties': {'identifier': 'WP4220_r119285', 'license': 'CC BY 4.0', 'database': 'WikiPathways', 'vestige': True, 'Mate_Version': 'V1', 'name': 'Neurotransmitter disorders', 'source': 'WikiPathways', 'url': 'http://www.wikipathways.org/instance/WP4220_r119285'}}
# INFO:root:Edge: {'_key': '33171363', '_id': 'Edges/33171363', '_from': 'Nodes/100005', '_to': 'Nodes/34720', '_rev': '_iYkm8ae---', 'label': 'PARTICIPATES_GpPW', 'properties': {'license': 'CC BY 4.0', 'database': 'WikiPathways', 'vestige': True, 'Mate_Version': 'V1', 'reverse_degrees': 4, 'unbiased': False, 'forward_degrees': 24, 'source': 'WikiPathways'}, 'start': {'id': '100005', 'labels': ['Gene'], 'properties': {'license': 'CC0 1.0', 'identifier': 7054, 'ensembl': 'ENSG00000180176', 'Mate_Version': 'V1', 'chromosome': '11', 'name': 'TH', 'description': 'tyrosine hydroxylase', 'source': 'Entrez Gene', 'chembl_id': 'CHEMBL1969'}}, 'end': {'id': '34720', 'labels': ['Pathway'], 'properties': {'identifier': 'WP4220_r119285', 'license': 'CC BY 4.0', 'database': 'WikiPathways', 'vestige': True, 'Mate_Version': 'V1', 'name': 'Neurotransmitter disorders', 'source': 'WikiPathways', 'url': 'http://www.wikipathways.org/instance/WP4220_r119285'}}}
# INFO:root:---
# INFO:root:Entity: {'_key': '34366', '_id': 'Nodes/34366', '_rev': '_iYaKkN----', 'type': 'node', 'id': '34366', 'labels': ['Pathway'], 'properties': {'identifier': 'WP4220_r117163', 'license': 'CC BY 4.0', 'database': 'WikiPathways', 'vestige': True, 'Mate_Version': 'V1', 'name': 'Neurotransmitter disorders', 'source': 'WikiPathways', 'url': 'http://www.wikipathways.org/instance/WP4220_r117163'}}
# INFO:root:Edge: {'_key': '33171355', '_id': 'Edges/33171355', '_from': 'Nodes/100005', '_to': 'Nodes/34366', '_rev': '_iYkm8a----', 'label': 'PARTICIPATES_GpPW', 'properties': {'license': 'CC BY 4.0', 'database': 'WikiPathways', 'vestige': True, 'Mate_Version': 'V1', 'reverse_degrees': 4, 'unbiased': False, 'forward_degrees': 24, 'source': 'WikiPathways'}, 'start': {'id': '100005', 'labels': ['Gene'], 'properties': {'license': 'CC0 1.0', 'identifier': 7054, 'ensembl': 'ENSG00000180176', 'Mate_Version': 'V1', 'chromosome': '11', 'name': 'TH', 'description': 'tyrosine hydroxylase', 'source': 'Entrez Gene', 'chembl_id': 'CHEMBL1969'}}, 'end': {'id': '34366', 'labels': ['Pathway'], 'properties': {'identifier': 'WP4220_r117163', 'license': 'CC BY 4.0', 'database': 'WikiPathways', 'vestige': True, 'Mate_Version': 'V1', 'name': 'Neurotransmitter disorders', 'source': 'WikiPathways', 'url': 'http://www.wikipathways.org/instance/WP4220_r117163'}}}
# INFO:root:---
# INFO:root:Entity: {'_key': '35366', '_id': 'Nodes/35366', '_rev': '_iYaKmMO---', 'type': 'node', 'id': '35366', 'labels': ['Pathway'], 'properties': {'identifier': 'WP550_r106312', 'license': 'CC BY 4.0', 'database': 'WikiPathways', 'Mate_Version': 'V1', 'vestige': True, 'name': 'Biogenic Amine Synthesis', 'source': 'WikiPathways', 'url': 'http://www.wikipathways.org/instance/WP550_r106312'}}
# INFO:root:Edge: {'_key': '33168805', '_id': 'Edges/33168805', '_from': 'Nodes/100005', '_to': 'Nodes/35366', '_rev': '_iYkm586---', 'label': 'PARTICIPATES_GpPW', 'properties': {'license': 'CC BY 4.0', 'database': 'WikiPathways', 'vestige': True, 'Mate_Version': 'V1', 'reverse_degrees': 15, 'unbiased': False, 'forward_degrees': 24, 'source': 'WikiPathways'}, 'start': {'id': '100005', 'labels': ['Gene'], 'properties': {'license': 'CC0 1.0', 'identifier': 7054, 'ensembl': 'ENSG00000180176', 'Mate_Version': 'V1', 'chromosome': '11', 'name': 'TH', 'description': 'tyrosine hydroxylase', 'source': 'Entrez Gene', 'chembl_id': 'CHEMBL1969'}}, 'end': {'id': '35366', 'labels': ['Pathway'], 'properties': {'identifier': 'WP550_r106312', 'license': 'CC BY 4.0', 'database': 'WikiPathways', 'Mate_Version': 'V1', 'vestige': True, 'name': 'Biogenic Amine Synthesis', 'source': 'WikiPathways', 'url': 'http://www.wikipathways.org/instance/WP550_r106312'}}}
# INFO:root:---

# %%
import os
from dotenv import load_dotenv
from arango import ArangoClient

# Load environment variables
load_dotenv()

# Connection details from .env
base_url = os.getenv('SPOKE_HOST')
username = os.getenv('SPOKE_USERNAME')
password = os.getenv('SPOKE_PASSWORD')
main_db = os.getenv('SPOKE_DB')

# Establish a connection
client = ArangoClient(hosts=base_url)
db = client.db(main_db, username=username, password=password)

def execute_aql(aql_query, bind_vars=None):
    cursor = db.aql.execute(aql_query, bind_vars=bind_vars)
    return [doc for doc in cursor]

# Get available collections
collections = db.collections()
print("Available Collections:")
for collection in collections:
    print(collection['name'])

# Assuming 'Entity' is the collection name for nodes
# Get entity types
aql_query = """
FOR doc IN Entity
    COLLECT entityType = doc.entityType WITH COUNT INTO count
    RETURN {entityType: entityType, count: count}
"""
entity_types = execute_aql(aql_query)
print("\nEntity Types:")
for et in entity_types:
    print(f"{et['entityType']}: {et['count']}")

# Get data elements
aql_query = """
FOR doc IN Entity
    FILTER doc.entityType == 'DATA_ELEMENT'
    LIMIT 5
    RETURN doc
"""
data_elements = execute_aql(aql_query)
print("\nData Elements (first 5):")
for element in data_elements:
    print(element)

# Get connections for a specific entity
entity_uuid = '5afd2304-f739-4f06-b1f8-61ddda331ff6'  # UUID of MEDICATION_DOSAGES
aql_query = """
FOR edge IN contains
    FILTER edge._from == @entity_id
    RETURN edge
"""
connections = execute_aql(aql_query, bind_vars={'entity_id': f'Entity/{entity_uuid}'})
print("\nConnections for MEDICATION_DOSAGES:")
for connection in connections:
    print(connection)

# Traverse the graph
aql_query = """
FOR v, e, p IN 1..2 OUTBOUND @start_vertex contains
    RETURN {
        vertex: v,
        edge: e,
        path: p
    }
"""
traversal_result = execute_aql(aql_query, bind_vars={'start_vertex': f'Entity/{entity_uuid}'})
print("\nGraph Traversal Result:")
print(traversal_result)
# Out:
# Available Collections:
# INCREASEDIN_PiD
# INCLUDES_PCiC
# ISA_PWiPW
# INCLUDES_OiPW
# INCLUDES_OiEC
# ISIN_ACTiiA
# ENCODES_GeP
# INCLUDES_PWiEC
# DOWNREGULATES_OGdG
# DOWNREGULATES_KGdG
# TREATS_CtD
# DECREASEDIN_PdD
# DOWNREGULATES_GPdG
# AFFECTS_CamG
# LOCALIZES_DlA
# CAUSES_OcD
# CONSUMES_RcC
# CATALYZES_ECcR
# ASSOCIATES_DaG
# CONTAINS_FcN
# CONTAINS_PWcPW
# EC
# SARSCov2
# PRODUCES_RpC
# contains
# Compound
# EXPRESSES_ACTeG
# MolecularFunction
# _appbundles
# PARTICIPATES_GpBP
# ISA_DiD
# Pathway
# _apps
# CellType
# _jobs
# Organism
# MEMBEROF_PDmPF
# _queues
# Disease
# ENCODES_OeP
# Nutrient
# _analyzers
# RESEMBLES_DrD
# PARTOF_PDpP
# DOWNREGULATES_AdG
# PharmacologicClass
# UPREGULATES_KGuG
# Anatomy
# AnatomyCellType
# ProteinFamily
# BINDS_CbP
# Symptom
# Reaction
# _graphs
# PARTICIPATES_GpMF
# BiologicalProcess
# SideEffect
# ISA_AiA
# Protein
# INTERACTS_PiP
# Food
# ISA_PiEC
# CellularComponent
# Gene
# ProteinDomain
# CONTAINS_DcD
# UPREGULATES_OGuG
# UPREGULATES_GPuG
# Entity
# UPREGULATES_CuG
# PRESENTS_DpS
# PARTICIPATES_GpCC
# ISIN_ACTiiCT
# UPREGULATES_AuG
# INTERACTS_CPiP
# _aqlfunctions
# CAUSES_CcSE
# PARTOF_ApA
# _frontend
# EXPRESSES_AeG
# CONTAINS_OcO
# CONTRAINDICATES_CcD
# DOWNREGULATES_CdG
# CONTAINS_FcC
# ISA_OiO
# CONTAINS_AcA
#
# Entity Types:
# DATA_ELEMENT: 5
# DATA_SET: 1
# DATA_TYPE: 2546
# PH_ID: 20
#
# Data Elements (first 5):
# {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_rev': '_emidfZW---', 'uuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'name': 'metabolomics_corrected.csv', 'enum': 'DATA_ELEMENT_METABOLOMICS_CORRECTED', 'basicEnum': 'METABOLOMICS_CORRECTED', 'system': True, 'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7', 'creatorType': 'USER', 'entityType': 'DATA_ELEMENT', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}
# {'_key': 'DATA_ELEMENT.DATA_ELEMENT_SALIVA', '_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_SALIVA', '_rev': '_emigPha---', 'uuid': 'b7ba781f-f903-4c99-bca2-64b36811e06a', 'name': 'saliva.csv', 'enum': 'DATA_ELEMENT_SALIVA', 'basicEnum': 'SALIVA', 'system': True, 'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7', 'creatorType': 'USER', 'entityType': 'DATA_ELEMENT', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}
# {'_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES', '_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES', '_rev': '_emigRCG---', 'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6', 'name': 'medication_dosages.csv', 'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES', 'basicEnum': 'MEDICATION_DOSAGES', 'system': True, 'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7', 'creatorType': 'USER', 'entityType': 'DATA_ELEMENT', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}
# {'_key': 'DATA_ELEMENT.DATA_ELEMENT_BLOOD_PRESSURE', '_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_BLOOD_PRESSURE', '_rev': '_emigRxi---', 'uuid': 'f49c8cac-1d31-49fa-a8e8-5f8254a890f9', 'name': 'blood_pressure.csv', 'enum': 'DATA_ELEMENT_BLOOD_PRESSURE', 'basicEnum': 'BLOOD_PRESSURE', 'system': True, 'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7', 'creatorType': 'USER', 'entityType': 'DATA_ELEMENT', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}
# {'_key': 'DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED', '_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED', '_rev': '_emigTGi---', 'uuid': 'd46a063d-0ebe-4051-a0e8-dc9d2520bd83', 'name': 'proteomics_corrected.csv', 'enum': 'DATA_ELEMENT_PROTEOMICS_CORRECTED', 'basicEnum': 'PROTEOMICS_CORRECTED', 'system': True, 'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7', 'creatorType': 'USER', 'entityType': 'DATA_ELEMENT', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}
#
# Connections for MEDICATION_DOSAGES:
#
# Graph Traversal Result:
# []

# %%
edge_collections = ['INCLUDES_PCiC', 'ASSOCIATES_DaG', 'CONTAINS_FcC']  # Add more as needed

for edge_collection in edge_collections:
    aql_query = f"""
    FOR edge IN {edge_collection}
        FILTER edge._from == @entity_id OR edge._to == @entity_id
        RETURN edge
    """
    connections = execute_aql(aql_query, bind_vars={'entity_id': f'Entity/{entity_uuid}'})
    print(f"\nConnections for MEDICATION_DOSAGES in {edge_collection}:")
    for connection in connections:
        print(connection)


aql_query = """
FOR doc IN Entity
    FILTER doc.entityType == 'DATA_TYPE'
    LIMIT 10
    RETURN doc
"""
data_types = execute_aql(aql_query)
print("\nSample DATA_TYPE entities:")
for dt in data_types:
    print(dt)


aql_query = """
FOR elem IN Entity
    FILTER elem.entityType == 'DATA_ELEMENT'
    FOR edge IN contains
        FILTER edge._from == elem._id
        FOR dtype IN Entity
            FILTER dtype._id == edge._to AND dtype.entityType == 'DATA_TYPE'
            RETURN {dataElement: elem.name, dataType: dtype.name, relationship: edge}
"""
element_type_relations = execute_aql(aql_query)
print("\nRelationships between DATA_ELEMENT and DATA_TYPE:")
for relation in element_type_relations:
    print(relation)


aql_query = """
FOR doc IN Entity
    FILTER doc.entityType == 'DATA_SET'
    RETURN doc
"""
data_set = execute_aql(aql_query)
print("\nDATA_SET entity:")
print(data_set)
# Out:
# Connections for MEDICATION_DOSAGES in INCLUDES_PCiC:
#
# Connections for MEDICATION_DOSAGES in ASSOCIATES_DaG:
#
# Connections for MEDICATION_DOSAGES in CONTAINS_FcC:
#
# Sample DATA_TYPE entities:
# {'_key': 'DATA_TYPE.DATA_TYPE_BLOOD_PRESSURE', '_id': 'Entity/DATA_TYPE.DATA_TYPE_BLOOD_PRESSURE', '_rev': '_emidfX----', 'uuid': 'ec344e6d-4222-4cc3-b102-1d657bd96e97', 'name': 'Blood Pressure', 'enum': 'DATA_TYPE_BLOOD_PRESSURE', 'basicEnum': 'BLOOD_PRESSURE', 'system': True, 'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7', 'creatorType': 'USER', 'entityType': 'DATA_TYPE', 'candidateId': '4689f863-3977-4f4f-bcca-965d9136cbcb', 'verified': True}
# {'_key': 'DATA_TYPE.DATA_TYPE_MEDICATION_DOSAGES', '_id': 'Entity/DATA_TYPE.DATA_TYPE_MEDICATION_DOSAGES', '_rev': '_emidfXa---', 'uuid': '09eeff38-6550-4bab-97c1-47354f1ed83c', 'name': 'Medication Dosages', 'enum': 'DATA_TYPE_MEDICATION_DOSAGES', 'basicEnum': 'MEDICATION_DOSAGES', 'system': True, 'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7', 'creatorType': 'USER', 'entityType': 'DATA_TYPE', 'candidateId': '4689f863-3977-4f4f-bcca-965d9136cbcb', 'verified': True}
# {'_key': 'DATA_TYPE.DATA_TYPE_METABOLOMICS_CORRECTED', '_id': 'Entity/DATA_TYPE.DATA_TYPE_METABOLOMICS_CORRECTED', '_rev': '_emidfXy---', 'uuid': '0b0e4b49-56b5-4019-abca-a8f717646164', 'name': 'Metabolomics Corrected', 'enum': 'DATA_TYPE_METABOLOMICS_CORRECTED', 'basicEnum': 'METABOLOMICS_CORRECTED', 'system': True, 'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7', 'creatorType': 'USER', 'entityType': 'DATA_TYPE', 'candidateId': '4689f863-3977-4f4f-bcca-965d9136cbcb', 'verified': True}
# {'_key': 'DATA_TYPE.DATA_TYPE_PROTEOMICS_CORRECTED', '_id': 'Entity/DATA_TYPE.DATA_TYPE_PROTEOMICS_CORRECTED', '_rev': '_emidfYW---', 'uuid': 'a54dfcaa-9092-427a-a4c6-4fa1100a9caf', 'name': 'Proteomics Corrected', 'enum': 'DATA_TYPE_PROTEOMICS_CORRECTED', 'basicEnum': 'PROTEOMICS_CORRECTED', 'system': True, 'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7', 'creatorType': 'USER', 'entityType': 'DATA_TYPE', 'candidateId': '4689f863-3977-4f4f-bcca-965d9136cbcb', 'verified': True}
# {'_key': 'DATA_TYPE.DATA_TYPE_SALIVA', '_id': 'Entity/DATA_TYPE.DATA_TYPE_SALIVA', '_rev': '_emidfYu---', 'uuid': 'dcfdf3c8-4d0b-48d2-8f4a-8ef3606d07f8', 'name': 'Saliva', 'enum': 'DATA_TYPE_SALIVA', 'basicEnum': 'SALIVA', 'system': True, 'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7', 'creatorType': 'USER', 'entityType': 'DATA_TYPE', 'candidateId': '4689f863-3977-4f4f-bcca-965d9136cbcb', 'verified': True}
# {'_key': 'DATA_TYPE.DATA_TYPE_PUBLIC_CLIENT_ID', '_id': 'Entity/DATA_TYPE.DATA_TYPE_PUBLIC_CLIENT_ID', '_rev': '_emidfbO---', 'uuid': '709ac009-cac2-4946-a57c-4eb028f3fbf9', 'name': 'public_client_id', 'enum': 'DATA_TYPE_PUBLIC_CLIENT_ID', 'basicEnum': 'PUBLIC_CLIENT_ID', 'system': True, 'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7', 'creatorType': 'USER', 'entityType': 'DATA_TYPE', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}
# {'_key': 'DATA_TYPE.DATA_TYPE_SAMPLE_ID', '_id': 'Entity/DATA_TYPE.DATA_TYPE_SAMPLE_ID', '_rev': '_emidfcm---', 'uuid': 'ba61f7ff-54c9-4b26-9ca4-70dc227a7992', 'name': 'sample_id', 'enum': 'DATA_TYPE_SAMPLE_ID', 'basicEnum': 'SAMPLE_ID', 'system': True, 'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7', 'creatorType': 'USER', 'entityType': 'DATA_TYPE', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}
# {'_key': 'DATA_TYPE.DATA_TYPE_DAYS_IN_PROGRAM', '_id': 'Entity/DATA_TYPE.DATA_TYPE_DAYS_IN_PROGRAM', '_rev': '_emidfdy---', 'uuid': 'cab1246f-c5ae-462f-9e82-3be3388a7da8', 'name': 'days_in_program', 'enum': 'DATA_TYPE_DAYS_IN_PROGRAM', 'basicEnum': 'DAYS_IN_PROGRAM', 'system': True, 'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7', 'creatorType': 'USER', 'entityType': 'DATA_TYPE', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}
# {'_key': 'DATA_TYPE.DATA_TYPE_DAYS_SINCE_FIRST_CALL', '_id': 'Entity/DATA_TYPE.DATA_TYPE_DAYS_SINCE_FIRST_CALL', '_rev': '_emidfe6---', 'uuid': '93c8c258-da56-4c51-98a5-e5a4a406793b', 'name': 'days_since_first_call', 'enum': 'DATA_TYPE_DAYS_SINCE_FIRST_CALL', 'basicEnum': 'DAYS_SINCE_FIRST_CALL', 'system': True, 'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7', 'creatorType': 'USER', 'entityType': 'DATA_TYPE', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}
# {'_key': 'DATA_TYPE.DATA_TYPE_DAYS_SINCE_FIRST_DRAW', '_id': 'Entity/DATA_TYPE.DATA_TYPE_DAYS_SINCE_FIRST_DRAW', '_rev': '_emidfgG---', 'uuid': '2f970036-2bde-4dbd-be3c-acf913bd71ae', 'name': 'days_since_first_draw', 'enum': 'DATA_TYPE_DAYS_SINCE_FIRST_DRAW', 'basicEnum': 'DAYS_SINCE_FIRST_DRAW', 'system': True, 'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7', 'creatorType': 'USER', 'entityType': 'DATA_TYPE', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}
#
# Relationships between DATA_ELEMENT and DATA_TYPE:
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': 'public_client_id', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_PUBLIC_CLIENT_ID', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_PUBLIC_CLIENT_ID', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_PUBLIC_CLIENT_ID', '_rev': '_emidfc----', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '709ac009-cac2-4946-a57c-4eb028f3fbf9', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': 'sample_id', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_SAMPLE_ID', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_SAMPLE_ID', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_SAMPLE_ID', '_rev': '_emidfda---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': 'ba61f7ff-54c9-4b26-9ca4-70dc227a7992', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': 'days_in_program', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_DAYS_IN_PROGRAM', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_DAYS_IN_PROGRAM', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_DAYS_IN_PROGRAM', '_rev': '_emidfei---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': 'cab1246f-c5ae-462f-9e82-3be3388a7da8', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': 'days_since_first_call', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_DAYS_SINCE_FIRST_CALL', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_DAYS_SINCE_FIRST_CALL', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_DAYS_SINCE_FIRST_CALL', '_rev': '_emidffi---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '93c8c258-da56-4c51-98a5-e5a4a406793b', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': 'days_since_first_draw', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_DAYS_SINCE_FIRST_DRAW', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_DAYS_SINCE_FIRST_DRAW', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_DAYS_SINCE_FIRST_DRAW', '_rev': '_emidfg6---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '2f970036-2bde-4dbd-be3c-acf913bd71ae', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': 'month', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_MONTH', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_MONTH', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_MONTH', '_rev': '_emidfi----', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '490eb71e-5d3c-4d29-b732-6762e7f9401c', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': 'weekday', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_WEEKDAY', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_WEEKDAY', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_WEEKDAY', '_rev': '_emidfj----', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '21b63ad6-3bdd-4fce-a175-1f7f6687f9de', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': 'season', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_SEASON', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_SEASON', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_SEASON', '_rev': '_emidfkG---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '23050d6a-2a24-449f-802f-3e5939fe5b3b', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '35', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_35', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_35', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_35', '_rev': '_emidfla---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '2b7243d0-add5-4c92-82cd-8316cb71638e', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '50', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_50', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_50', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_50', '_rev': '_emidfmm---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': 'dfb4290a-13f5-4a5a-bb6a-cb1d5ee28222', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '55', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_55', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_55', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_55', '_rev': '_emidfnm---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '0766cca0-9a61-42df-920b-05ddcc87c309', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '62', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_62', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_62', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_62', '_rev': '_emidfoq---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '306c225e-9ea8-4be1-9343-726be2a3dda1', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '71', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_71', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_71', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_71', '_rev': '_emidfpq---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '16df3421-dd54-44f6-a4a2-af833bf3d32c', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '93', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_93', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_93', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_93', '_rev': '_emidfqq---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': 'd211f1cf-1127-4ca6-949e-2078c43c8278', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '98', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_98', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_98', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_98', '_rev': '_emidfrm---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '2336640c-5c6d-4f2a-8c4b-52d3b25146cb', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '111', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_111', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_111', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_111', '_rev': '_emidfsq---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '96142c05-ca1d-496a-8341-b82f5d8572b6', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '112', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_112', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_112', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_112', '_rev': '_emidftq---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '3f8e0070-9798-4838-a88a-53c1f052b82e', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '117', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_117', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_117', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_117', '_rev': '_emidfuq---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': 'f3ca1cc7-fa0d-4bb4-86fa-31854a12bf2a', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '132', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_132', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_132', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_132', '_rev': '_emidfvm---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': 'e3d1a7f3-788f-43e7-bff5-1580288bca87', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '136', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_136', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_136', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_136', '_rev': '_emidfwu---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '1abf4160-c7ee-4167-b95b-4ef46feb7b2a', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '144', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_144', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_144', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_144', '_rev': '_emidfxq---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': 'b673eda0-a7c3-4631-8cd1-47f73c02f085', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '158', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_158', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_158', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_158', '_rev': '_emidfym---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '27ae583d-cd5d-4716-855b-b5befa76ee35', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '171', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_171', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_171', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_171', '_rev': '_emidfzm---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '34fabb41-61a2-4131-af0b-bfbfb7c1716a', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '179', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_179', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_179', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_179', '_rev': '_emidf0q---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '43dae3fe-04aa-4fc0-a0ca-e2047dfe02a7', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '180', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_180', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_180', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_180', '_rev': '_emidf1q---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': 'f243aabb-ef68-462d-8e4c-c36911262437', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '181', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_181', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_181', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_181', '_rev': '_emidf2u---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': 'a93a99be-e3fc-4e9d-a4b0-a9005b7f594f', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '182', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_182', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_182', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_182', '_rev': '_emidf32---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '2826be07-44d2-44a0-b5b2-4316fbe29e12', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '189', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_189', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_189', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_189', '_rev': '_emidf42---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': 'd9192152-2867-4b26-a3d8-842980f9f349', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '192', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_192', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_192', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_192', '_rev': '_emidf56---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '17e81f0b-4492-4cb4-b301-1cdb9cf868ef', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '194', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_194', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_194', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_194', '_rev': '_emidf66---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '228c2e9b-9c56-408a-b18e-9233ede221b0', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '197', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_197', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_197', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_197', '_rev': '_emidf76---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': 'bb2db3d1-644b-476f-80a4-a214b902c3d9', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '207', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_207', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_207', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_207', '_rev': '_emidf9----', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '3b6fc922-55cb-4708-b08d-c78fe3dfdce5', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '209', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_209', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_209', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_209', '_rev': '_emidg-----', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '4d5defd6-c448-4aec-bc15-3ee14ca36535', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '212', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_212', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_212', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_212', '_rev': '_emidg_----', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '9ee63d38-cc44-4a80-8f8e-a25b60b10a8b', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '229', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_229', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_229', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_229', '_rev': '_emidgA----', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': 'd537ff73-7cc9-40ba-b9f8-96362e3a4cfe', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '231', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_231', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_231', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_231', '_rev': '_emidgB----', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': 'ff5d80ae-1996-4112-8dcc-8d8f6d00fdbc', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '234', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_234', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_234', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_234', '_rev': '_emidgC----', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '581ef743-b26b-40fe-b895-478b9e61187c', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '235', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_235', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_235', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_235', '_rev': '_emidgD----', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '20943619-b852-4c25-a6da-a8138b72e766', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '240', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_240', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_240', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_240', '_rev': '_emidgE----', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '0ae4b12a-e3fd-4b4b-bb61-3081d756d687', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '241', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_241', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_241', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_241', '_rev': '_emidgE6---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': 'daef7a43-e63d-46eb-96b7-b6aa36d67534', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '244', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_244', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_244', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_244', '_rev': '_emidgF2---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '38f57801-6924-4bd3-82eb-405bf802f245', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '249', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_249', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_249', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_249', '_rev': '_emidgG2---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '59c7816a-d026-43ad-914d-71b81716ed58', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '250', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_250', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_250', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_250', '_rev': '_emidgH6---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '7dfb5d75-6848-4d14-b5c3-2c2ce238ac84', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '252', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_252', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_252', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_252', '_rev': '_emidgI2---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '250c0fdc-b0a2-4fbe-8b03-349c478fb044', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '254', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_254', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_254', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_254', '_rev': '_emidgJ6---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': 'af322227-b1d5-491b-b522-4805d2a26e26', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '266', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_266', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_266', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_266', '_rev': '_emidgK6---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '558999aa-47b3-4399-bb20-b12907a1f637', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '267', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_267', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_267', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_267', '_rev': '_emidgL6---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '3a09e42a-10ad-46dd-895c-ccf60f4e7029', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '272', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_272', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_272', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_272', '_rev': '_emidgM6---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '4c4e9567-a72d-4a73-bac2-ab1513d5aebe', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '273', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_273', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_273', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_273', '_rev': '_emidgN6---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': 'f1c1aa18-5e87-4faa-a591-f4edca4130ec', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '275', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_275', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_275', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_275', '_rev': '_emidgO2---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '48cca9ec-0f0a-40eb-b375-e24c179b2fa7', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '278', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_278', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_278', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_278', '_rev': '_emidgP2---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': 'f7de5cb7-0860-4f71-9078-bb2fb321238b', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '279', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_279', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_279', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_279', '_rev': '_emidgQ2---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': 'b3cf23ba-f768-46bf-b691-7dc9ad79c728', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '297', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_297', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_297', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_297', '_rev': '_emidgR2---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '7529b738-af81-476e-94a4-9be5f6339423', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '302', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_302', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_302', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_302', '_rev': '_emidgS2---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': 'd389cd19-3c13-4729-8876-570a1bd6d9d0', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '310', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_310', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_310', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_310', '_rev': '_emidgT2---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '0f6948cb-ba14-424c-a43c-5229046caf9e', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '313', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_313', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_313', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_313', '_rev': '_emidgUy---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '1a87cf1d-580f-49cb-967c-586b54b0169a', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '327', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_327', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_327', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_327', '_rev': '_emidgVy---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '9e718436-15c9-44c6-b764-693f8d039e9c', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '330', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_330', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_330', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_330', '_rev': '_emidgWy---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': 'fdcdd43a-5dda-413e-a335-2134a2a679c9', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '331', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_331', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_331', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_331', '_rev': '_emidgXu---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': 'c585ff91-35ed-42b4-993c-bee421370bea', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '338', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_338', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_338', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_338', '_rev': '_emidgYu---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '77d9a58c-2c0e-4149-82bc-57529a7e3228', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '339', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_339', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_339', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_339', '_rev': '_emidgZq---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '81fd5db4-ed48-4f94-a4a3-d6833a703fde', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '340', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_340', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_340', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_340', '_rev': '_emidgam---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '8a204bda-5a0d-4552-b470-9f125388801c', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '342', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_342', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_342', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_342', '_rev': '_emidgbi---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': 'cbcb8ebc-8392-4778-8e17-3b88d9e74066', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '344', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_344', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_344', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_344', '_rev': '_emidgce---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '9ff3f1e6-9a42-4af9-8d7b-fe28e3104805', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '355', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_355', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_355', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_355', '_rev': '_emidgda---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': 'f5730ae0-13e2-4e43-b714-38778253204b', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '356', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_356', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_356', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_356', '_rev': '_emidgeW---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '861cf3b1-faf2-4195-9714-9329e77127e6', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '358', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_358', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_358', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_358', '_rev': '_emidgfa---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': 'a4d19f4f-a117-4b47-a741-34cf4280cc25', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '361', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_361', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_361', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_361', '_rev': '_emidgga---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '303ac0f0-8f1c-4a96-8323-e1405de3b9d4', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '363', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_363', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_363', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_363', '_rev': '_emidghe---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '0e92b247-4193-49d3-8ef4-cd08def96380', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '376', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_376', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_376', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_376', '_rev': '_emidgim---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '08f97c41-0018-4fab-bb02-2bdec74f1e69', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '381', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_381', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_381', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_381', '_rev': '_emidgju---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '40cc6dc0-aea4-4f6f-9bf9-f70e918ea340', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '391', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_391', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_391', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_391', '_rev': '_emidgk2---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': 'f7b8cf8c-341c-4d8c-8318-dcd6df1dcb29', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '393', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_393', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_393', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_393', '_rev': '_emidgl2---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': 'f4f58cdc-b8fe-49fe-9840-96e33fee6bac', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '397', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_397', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_397', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_397', '_rev': '_emidgmy---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': 'd0b5ce84-923c-4159-810a-39134f3c598a', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'metabolomics_corrected.csv', 'dataType': '407', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_407', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_407', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_407', '_rev': '_emidgn2---', 'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c', 'toUuid': '8193554c-4852-40d9-8cf7-4322f096ebda', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# ...
# {'dataElement': 'proteomics_corrected.csv', 'dataType': 'ONC3_Q92832', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q92832', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q92832', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_ONC3_Q92832', '_rev': '_emigij2---', 'fromUuid': 'd46a063d-0ebe-4051-a0e8-dc9d2520bd83', 'toUuid': 'a853de86-0531-46f0-b50b-b633ca7edc8a', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'proteomics_corrected.csv', 'dataType': 'ONC3_Q93096', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q93096', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q93096', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_ONC3_Q93096', '_rev': '_emigiku---', 'fromUuid': 'd46a063d-0ebe-4051-a0e8-dc9d2520bd83', 'toUuid': '0472764d-ea98-4c0a-8e72-2a27e4dca200', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'proteomics_corrected.csv', 'dataType': 'ONC3_Q96FQ6', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q96FQ6', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q96FQ6', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_ONC3_Q96FQ6', '_rev': '_emigili---', 'fromUuid': 'd46a063d-0ebe-4051-a0e8-dc9d2520bd83', 'toUuid': '128faae8-1f32-4519-887d-ffdb372e98c3', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'proteomics_corrected.csv', 'dataType': 'ONC3_Q96I15', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q96I15', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q96I15', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_ONC3_Q96I15', '_rev': '_emigimW---', 'fromUuid': 'd46a063d-0ebe-4051-a0e8-dc9d2520bd83', 'toUuid': '19e9ff69-b733-458e-95ab-278ce180e859', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'proteomics_corrected.csv', 'dataType': 'ONC3_Q96J42', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q96J42', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q96J42', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_ONC3_Q96J42', '_rev': '_emiginG---', 'fromUuid': 'd46a063d-0ebe-4051-a0e8-dc9d2520bd83', 'toUuid': '180804f2-c1db-476c-9bdd-7dcc2de58962', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'proteomics_corrected.csv', 'dataType': 'ONC3_Q96PD4', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q96PD4', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q96PD4', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_ONC3_Q96PD4', '_rev': '_emigio----', 'fromUuid': 'd46a063d-0ebe-4051-a0e8-dc9d2520bd83', 'toUuid': 'f22b8eba-a1bf-49ae-9fa1-0f2c9b562cb2', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'proteomics_corrected.csv', 'dataType': 'ONC3_Q99536', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q99536', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q99536', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_ONC3_Q99536', '_rev': '_emigioy---', 'fromUuid': 'd46a063d-0ebe-4051-a0e8-dc9d2520bd83', 'toUuid': '85692a5e-4773-4c77-ad00-e6085da342b1', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'proteomics_corrected.csv', 'dataType': 'ONC3_Q99795', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q99795', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q99795', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_ONC3_Q99795', '_rev': '_emigipm---', 'fromUuid': 'd46a063d-0ebe-4051-a0e8-dc9d2520bd83', 'toUuid': '69a169f6-d4e7-487f-b2ad-89a9c2883faf', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'proteomics_corrected.csv', 'dataType': 'ONC3_Q9BS26', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q9BS26', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q9BS26', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_ONC3_Q9BS26', '_rev': '_emigiqa---', 'fromUuid': 'd46a063d-0ebe-4051-a0e8-dc9d2520bd83', 'toUuid': 'e1027e6d-b499-49c9-b9a9-701fce7f30da', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'proteomics_corrected.csv', 'dataType': 'ONC3_Q9BSL1', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q9BSL1', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q9BSL1', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_ONC3_Q9BSL1', '_rev': '_emigirO---', 'fromUuid': 'd46a063d-0ebe-4051-a0e8-dc9d2520bd83', 'toUuid': 'fd461300-f3b9-4bf4-baac-4993386cbd8f', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'proteomics_corrected.csv', 'dataType': 'ONC3_Q9BYE9', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q9BYE9', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q9BYE9', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_ONC3_Q9BYE9', '_rev': '_emigisC---', 'fromUuid': 'd46a063d-0ebe-4051-a0e8-dc9d2520bd83', 'toUuid': 'b5035e0c-2178-44b4-9544-7c35d6358f14', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'proteomics_corrected.csv', 'dataType': 'ONC3_Q9H0P0', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q9H0P0', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q9H0P0', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_ONC3_Q9H0P0', '_rev': '_emigit----', 'fromUuid': 'd46a063d-0ebe-4051-a0e8-dc9d2520bd83', 'toUuid': 'f74207a7-4440-417b-bf21-865ac6250941', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'proteomics_corrected.csv', 'dataType': 'ONC3_Q9H3G5', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q9H3G5', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q9H3G5', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_ONC3_Q9H3G5', '_rev': '_emigity---', 'fromUuid': 'd46a063d-0ebe-4051-a0e8-dc9d2520bd83', 'toUuid': '0e0b68c3-8ce8-411c-92b6-731c3c38f466', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'proteomics_corrected.csv', 'dataType': 'ONC3_Q9H773', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q9H773', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q9H773', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_ONC3_Q9H773', '_rev': '_emigiui---', 'fromUuid': 'd46a063d-0ebe-4051-a0e8-dc9d2520bd83', 'toUuid': 'b4784e41-df80-45be-8235-7eec20a80817', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'proteomics_corrected.csv', 'dataType': 'ONC3_Q9H8J5', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q9H8J5', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q9H8J5', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_ONC3_Q9H8J5', '_rev': '_emigivW---', 'fromUuid': 'd46a063d-0ebe-4051-a0e8-dc9d2520bd83', 'toUuid': '26858e77-ad05-4def-b00c-f27b7f3b93b5', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'proteomics_corrected.csv', 'dataType': 'ONC3_Q9HD26', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q9HD26', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q9HD26', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_ONC3_Q9HD26', '_rev': '_emigiwK---', 'fromUuid': 'd46a063d-0ebe-4051-a0e8-dc9d2520bd83', 'toUuid': 'd6b9b6ff-2688-4e02-965a-d8569744e4e6', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'proteomics_corrected.csv', 'dataType': 'ONC3_Q9NTU7', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q9NTU7', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q9NTU7', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_ONC3_Q9NTU7', '_rev': '_emigixC---', 'fromUuid': 'd46a063d-0ebe-4051-a0e8-dc9d2520bd83', 'toUuid': '7c34227a-17e8-433c-a665-daf0c51b522b', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'proteomics_corrected.csv', 'dataType': 'ONC3_Q9P1Z2', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q9P1Z2', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q9P1Z2', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_ONC3_Q9P1Z2', '_rev': '_emigix2---', 'fromUuid': 'd46a063d-0ebe-4051-a0e8-dc9d2520bd83', 'toUuid': 'a3532e8d-9ff6-4fff-8d70-3458ff35d922', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'proteomics_corrected.csv', 'dataType': 'ONC3_Q9UDT6', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q9UDT6', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q9UDT6', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_ONC3_Q9UDT6', '_rev': '_emigiyq---', 'fromUuid': 'd46a063d-0ebe-4051-a0e8-dc9d2520bd83', 'toUuid': '514adacf-fb09-45e8-a0f0-ab327b65111d', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'proteomics_corrected.csv', 'dataType': 'ONC3_Q9UHD8', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q9UHD8', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q9UHD8', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_ONC3_Q9UHD8', '_rev': '_emigize---', 'fromUuid': 'd46a063d-0ebe-4051-a0e8-dc9d2520bd83', 'toUuid': 'dae660c1-ce6b-4627-b141-e38e9c4e4989', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'proteomics_corrected.csv', 'dataType': 'ONC3_Q9UJY5', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q9UJY5', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q9UJY5', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_ONC3_Q9UJY5', '_rev': '_emigi0S---', 'fromUuid': 'd46a063d-0ebe-4051-a0e8-dc9d2520bd83', 'toUuid': '5f7fc5da-6243-4b45-bbd3-8a74079dba33', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'proteomics_corrected.csv', 'dataType': 'ONC3_Q9UMF0', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q9UMF0', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q9UMF0', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_ONC3_Q9UMF0', '_rev': '_emigi1G---', 'fromUuid': 'd46a063d-0ebe-4051-a0e8-dc9d2520bd83', 'toUuid': '1469c8b3-fe3f-41a9-950c-60dbbc6ea226', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'proteomics_corrected.csv', 'dataType': 'ONC3_Q9Y2B0', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q9Y2B0', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q9Y2B0', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_ONC3_Q9Y2B0', '_rev': '_emigi16---', 'fromUuid': 'd46a063d-0ebe-4051-a0e8-dc9d2520bd83', 'toUuid': '4b0ee1a9-aa2b-4682-af12-fb363de632c2', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'proteomics_corrected.csv', 'dataType': 'ONC3_Q9Y5K2', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q9Y5K2', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q9Y5K2', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_ONC3_Q9Y5K2', '_rev': '_emigi2y---', 'fromUuid': 'd46a063d-0ebe-4051-a0e8-dc9d2520bd83', 'toUuid': 'd0630753-6e88-496f-8226-2dd5470c0ac7', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'proteomics_corrected.csv', 'dataType': 'ONC3_Q9Y5K8', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q9Y5K8', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q9Y5K8', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_ONC3_Q9Y5K8', '_rev': '_emigi3m---', 'fromUuid': 'd46a063d-0ebe-4051-a0e8-dc9d2520bd83', 'toUuid': '2f4ebdcb-6b81-4e9c-9d55-c73a8860818d', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
# {'dataElement': 'proteomics_corrected.csv', 'dataType': 'ONC3_Q9Y644', 'relationship': {'_key': 'DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q9Y644', '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_ONC3_Q9Y644', '_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED', '_to': 'Entity/DATA_TYPE.DATA_TYPE_ONC3_Q9Y644', '_rev': '_emigi4a---', 'fromUuid': 'd46a063d-0ebe-4051-a0e8-dc9d2520bd83', 'toUuid': '6f90ce86-a1e8-43c3-a2e3-0a3c1892ee4a', 'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2', 'verified': False}}
#
# DATA_SET entity:
# [{'_key': 'DATA_SET.DATA_SET_SCIENTIFIC_WELLNESS_COHORT', '_id': 'Entity/DATA_SET.DATA_SET_SCIENTIFIC_WELLNESS_COHORT', '_rev': '_emidfWW---', 'uuid': '5308b32a-4e51-489f-8adb-7c842152d161', 'name': 'Scientific Wellness Cohort', 'enum': 'DATA_SET_SCIENTIFIC_WELLNESS_COHORT', 'basicEnum': 'SCIENTIFIC_WELLNESS_COHORT', 'system': True, 'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7', 'creatorType': 'USER', 'entityType': 'DATA_SET', 'candidateId': '4689f863-3977-4f4f-bcca-965d9136cbcb', 'verified': True}]

# %%
import pprint
from knowledge_engine_sdk import *

# Initialize the SDK
sdk = KnowledgeEngine()

# Pretty printer for structured output
pp = pprint.PrettyPrinter(indent=1)

# 1. Get list of Entity Types
try:
    entity_types = sdk.get_entity_types()
    print("Successfully connected to SPOKE database")
    pp.pprint(entity_types)
except Exception as e:
    print(f"Failed to connect to SPOKE database: {e}")

# 2. Get list of entities for a specific entity type (e.g., DATA_ELEMENT)
query_params = GetEntityListParams(entity_type_enum="DATA_ELEMENT")

try:
    data_elements = sdk.get_entities(params=query_params)
    pp.pprint(data_elements)
except Exception as e:
    print(f"Error retrieving data elements: {e}")

# 3. Get a particular entity by uuid, enum, and entity_type_enum
if data_elements:
    entity_uuid = data_elements[0]['uuid']  # Example: fetching the uuid of the first entity
    entity_enum = data_elements[0]['enum']  # Fetching the enum of the first entity
    entity_params = GetEntityParams(uuid=entity_uuid, enum=entity_enum, entity_type_enum="DATA_ELEMENT")

    try:
        entity = sdk.get_entity(params=entity_params)
        pp.pprint(entity)
    except Exception as e:
        print(f"Error retrieving entity: {e}")

    # 4. Traverse a graph starting from this entity
    try:
        traversal_params = TraverseParams(
            start_entity_uuid=entity['uuid'],
            direction="out",
            max_depth=1
        )
        traversal = sdk.traverse_graph(params=traversal_params)
        pp.pprint(traversal)
    except Exception as e:
        print(f"Error traversing the graph: {e}")

# 5. Get list of connection types
try:
    connection_types = sdk.get_connection_types()
    pp.pprint(connection_types)
except Exception as e:
    print(f"Error retrieving connection types: {e}")

# 6. Get list of connections for the entity
if entity:
    connection_params = GetConnectionListParams(
        connection_type_name="contains",
        entity_uuid=entity["uuid"],
        direction="out"
    )

    try:
        connections = sdk.get_connections(params=connection_params)
        pp.pprint(connections)
    except Exception as e:
        print(f"Error retrieving connections: {e}")
# Out:
# Successfully connected to SPOKE database
# ['DATA_SET', 'DATA_TYPE', 'DATA_ELEMENT', 'PH_ID']
# [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_rev': '_emidfZW---',
#   'basicEnum': 'METABOLOMICS_CORRECTED',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#   'creatorType': 'USER',
#   'entityType': 'DATA_ELEMENT',
#   'enum': 'DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   'name': 'metabolomics_corrected.csv',
#   'system': True,
#   'uuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'verified': False},
#  {'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_SALIVA',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_SALIVA',
#   '_rev': '_emigPha---',
#   'basicEnum': 'SALIVA',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#   'creatorType': 'USER',
#   'entityType': 'DATA_ELEMENT',
#   'enum': 'DATA_ELEMENT_SALIVA',
#   'name': 'saliva.csv',
#   'system': True,
#   'uuid': 'b7ba781f-f903-4c99-bca2-64b36811e06a',
#   'verified': False},
#  {'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#   '_rev': '_emigRCG---',
#   'basicEnum': 'MEDICATION_DOSAGES',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#   'creatorType': 'USER',
#   'entityType': 'DATA_ELEMENT',
#   'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#   'name': 'medication_dosages.csv',
#   'system': True,
#   'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#   'verified': False},
#  {'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_BLOOD_PRESSURE',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_BLOOD_PRESSURE',
#   '_rev': '_emigRxi---',
#   'basicEnum': 'BLOOD_PRESSURE',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#   'creatorType': 'USER',
#   'entityType': 'DATA_ELEMENT',
#   'enum': 'DATA_ELEMENT_BLOOD_PRESSURE',
#   'name': 'blood_pressure.csv',
#   'system': True,
#   'uuid': 'f49c8cac-1d31-49fa-a8e8-5f8254a890f9',
#   'verified': False},
#  {'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_PROTEOMICS_CORRECTED',
#   '_rev': '_emigTGi---',
#   'basicEnum': 'PROTEOMICS_CORRECTED',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#   'creatorType': 'USER',
#   'entityType': 'DATA_ELEMENT',
#   'enum': 'DATA_ELEMENT_PROTEOMICS_CORRECTED',
#   'name': 'proteomics_corrected.csv',
#   'system': True,
#   'uuid': 'd46a063d-0ebe-4051-a0e8-dc9d2520bd83',
#   'verified': False}]
# {'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#  '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#  '_rev': '_emidfZW---',
#  'basicEnum': 'METABOLOMICS_CORRECTED',
#  'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#  'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#  'creatorType': 'USER',
#  'entityType': 'DATA_ELEMENT',
#  'enum': 'DATA_ELEMENT_METABOLOMICS_CORRECTED',
#  'name': 'metabolomics_corrected.csv',
#  'system': True,
#  'uuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#  'verified': False}
# Error traversing the graph: 2 validation errors for TraverseParams
# min_depth
#   Field required [type=missing, input_value={'start_entity_uuid': '53...: 'out', 'max_depth': 1}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# algorithm
#   Field required [type=missing, input_value={'start_entity_uuid': '53...: 'out', 'max_depth': 1}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# [{'edge_collection': 'contains',
#   'from_vertex_collections': ['Entity'],
#   'to_vertex_collections': ['Entity']}]
# [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_PUBLIC_CLIENT_ID',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_PUBLIC_CLIENT_ID',
#   '_rev': '_emidfc----',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_PUBLIC_CLIENT_ID',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '709ac009-cac2-4946-a57c-4eb028f3fbf9',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_SAMPLE_ID',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_SAMPLE_ID',
#   '_rev': '_emidfda---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_SAMPLE_ID',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'ba61f7ff-54c9-4b26-9ca4-70dc227a7992',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_DAYS_IN_PROGRAM',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_DAYS_IN_PROGRAM',
#   '_rev': '_emidfei---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_DAYS_IN_PROGRAM',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'cab1246f-c5ae-462f-9e82-3be3388a7da8',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_DAYS_SINCE_FIRST_CALL',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_DAYS_SINCE_FIRST_CALL',
#   '_rev': '_emidffi---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_DAYS_SINCE_FIRST_CALL',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '93c8c258-da56-4c51-98a5-e5a4a406793b',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_DAYS_SINCE_FIRST_DRAW',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_DAYS_SINCE_FIRST_DRAW',
#   '_rev': '_emidfg6---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_DAYS_SINCE_FIRST_DRAW',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '2f970036-2bde-4dbd-be3c-acf913bd71ae',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_MONTH',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_MONTH',
#   '_rev': '_emidfi----',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_MONTH',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '490eb71e-5d3c-4d29-b732-6762e7f9401c',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_WEEKDAY',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_WEEKDAY',
#   '_rev': '_emidfj----',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_WEEKDAY',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '21b63ad6-3bdd-4fce-a175-1f7f6687f9de',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_SEASON',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_SEASON',
#   '_rev': '_emidfkG---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_SEASON',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '23050d6a-2a24-449f-802f-3e5939fe5b3b',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_35',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_35',
#   '_rev': '_emidfla---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_35',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '2b7243d0-add5-4c92-82cd-8316cb71638e',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_50',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_50',
#   '_rev': '_emidfmm---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_50',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'dfb4290a-13f5-4a5a-bb6a-cb1d5ee28222',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_55',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_55',
#   '_rev': '_emidfnm---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_55',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '0766cca0-9a61-42df-920b-05ddcc87c309',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_62',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_62',
#   '_rev': '_emidfoq---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_62',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '306c225e-9ea8-4be1-9343-726be2a3dda1',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_71',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_71',
#   '_rev': '_emidfpq---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_71',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '16df3421-dd54-44f6-a4a2-af833bf3d32c',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_93',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_93',
#   '_rev': '_emidfqq---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_93',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'd211f1cf-1127-4ca6-949e-2078c43c8278',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_98',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_98',
#   '_rev': '_emidfrm---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_98',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '2336640c-5c6d-4f2a-8c4b-52d3b25146cb',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_111',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_111',
#   '_rev': '_emidfsq---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_111',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '96142c05-ca1d-496a-8341-b82f5d8572b6',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_112',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_112',
#   '_rev': '_emidftq---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_112',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '3f8e0070-9798-4838-a88a-53c1f052b82e',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_117',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_117',
#   '_rev': '_emidfuq---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_117',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'f3ca1cc7-fa0d-4bb4-86fa-31854a12bf2a',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_132',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_132',
#   '_rev': '_emidfvm---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_132',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'e3d1a7f3-788f-43e7-bff5-1580288bca87',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_136',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_136',
#   '_rev': '_emidfwu---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_136',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '1abf4160-c7ee-4167-b95b-4ef46feb7b2a',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_144',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_144',
#   '_rev': '_emidfxq---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_144',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'b673eda0-a7c3-4631-8cd1-47f73c02f085',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_158',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_158',
#   '_rev': '_emidfym---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_158',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '27ae583d-cd5d-4716-855b-b5befa76ee35',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_171',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_171',
#   '_rev': '_emidfzm---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_171',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '34fabb41-61a2-4131-af0b-bfbfb7c1716a',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_179',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_179',
#   '_rev': '_emidf0q---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_179',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '43dae3fe-04aa-4fc0-a0ca-e2047dfe02a7',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_180',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_180',
#   '_rev': '_emidf1q---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_180',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'f243aabb-ef68-462d-8e4c-c36911262437',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_181',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_181',
#   '_rev': '_emidf2u---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_181',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'a93a99be-e3fc-4e9d-a4b0-a9005b7f594f',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_182',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_182',
#   '_rev': '_emidf32---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_182',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '2826be07-44d2-44a0-b5b2-4316fbe29e12',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_189',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_189',
#   '_rev': '_emidf42---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_189',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'd9192152-2867-4b26-a3d8-842980f9f349',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_192',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_192',
#   '_rev': '_emidf56---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_192',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '17e81f0b-4492-4cb4-b301-1cdb9cf868ef',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_194',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_194',
#   '_rev': '_emidf66---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_194',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '228c2e9b-9c56-408a-b18e-9233ede221b0',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_197',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_197',
#   '_rev': '_emidf76---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_197',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'bb2db3d1-644b-476f-80a4-a214b902c3d9',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_207',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_207',
#   '_rev': '_emidf9----',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_207',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '3b6fc922-55cb-4708-b08d-c78fe3dfdce5',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_209',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_209',
#   '_rev': '_emidg-----',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_209',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '4d5defd6-c448-4aec-bc15-3ee14ca36535',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_212',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_212',
#   '_rev': '_emidg_----',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_212',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '9ee63d38-cc44-4a80-8f8e-a25b60b10a8b',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_229',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_229',
#   '_rev': '_emidgA----',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_229',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'd537ff73-7cc9-40ba-b9f8-96362e3a4cfe',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_231',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_231',
#   '_rev': '_emidgB----',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_231',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'ff5d80ae-1996-4112-8dcc-8d8f6d00fdbc',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_234',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_234',
#   '_rev': '_emidgC----',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_234',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '581ef743-b26b-40fe-b895-478b9e61187c',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_235',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_235',
#   '_rev': '_emidgD----',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_235',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '20943619-b852-4c25-a6da-a8138b72e766',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_240',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_240',
#   '_rev': '_emidgE----',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_240',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '0ae4b12a-e3fd-4b4b-bb61-3081d756d687',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_241',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_241',
#   '_rev': '_emidgE6---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_241',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'daef7a43-e63d-46eb-96b7-b6aa36d67534',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_244',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_244',
#   '_rev': '_emidgF2---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_244',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '38f57801-6924-4bd3-82eb-405bf802f245',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_249',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_249',
#   '_rev': '_emidgG2---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_249',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '59c7816a-d026-43ad-914d-71b81716ed58',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_250',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_250',
#   '_rev': '_emidgH6---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_250',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '7dfb5d75-6848-4d14-b5c3-2c2ce238ac84',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_252',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_252',
#   '_rev': '_emidgI2---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_252',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '250c0fdc-b0a2-4fbe-8b03-349c478fb044',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_254',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_254',
#   '_rev': '_emidgJ6---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_254',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'af322227-b1d5-491b-b522-4805d2a26e26',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_266',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_266',
#   '_rev': '_emidgK6---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_266',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '558999aa-47b3-4399-bb20-b12907a1f637',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_267',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_267',
#   '_rev': '_emidgL6---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_267',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '3a09e42a-10ad-46dd-895c-ccf60f4e7029',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_272',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_272',
#   '_rev': '_emidgM6---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_272',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '4c4e9567-a72d-4a73-bac2-ab1513d5aebe',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_273',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_273',
#   '_rev': '_emidgN6---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_273',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'f1c1aa18-5e87-4faa-a591-f4edca4130ec',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_275',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_275',
#   '_rev': '_emidgO2---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_275',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '48cca9ec-0f0a-40eb-b375-e24c179b2fa7',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_278',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_278',
#   '_rev': '_emidgP2---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_278',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'f7de5cb7-0860-4f71-9078-bb2fb321238b',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_279',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_279',
#   '_rev': '_emidgQ2---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_279',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'b3cf23ba-f768-46bf-b691-7dc9ad79c728',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_297',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_297',
#   '_rev': '_emidgR2---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_297',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '7529b738-af81-476e-94a4-9be5f6339423',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_302',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_302',
#   '_rev': '_emidgS2---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_302',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'd389cd19-3c13-4729-8876-570a1bd6d9d0',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_310',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_310',
#   '_rev': '_emidgT2---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_310',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '0f6948cb-ba14-424c-a43c-5229046caf9e',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_313',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_313',
#   '_rev': '_emidgUy---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_313',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '1a87cf1d-580f-49cb-967c-586b54b0169a',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_327',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_327',
#   '_rev': '_emidgVy---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_327',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '9e718436-15c9-44c6-b764-693f8d039e9c',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_330',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_330',
#   '_rev': '_emidgWy---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_330',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'fdcdd43a-5dda-413e-a335-2134a2a679c9',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_331',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_331',
#   '_rev': '_emidgXu---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_331',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'c585ff91-35ed-42b4-993c-bee421370bea',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_338',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_338',
#   '_rev': '_emidgYu---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_338',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '77d9a58c-2c0e-4149-82bc-57529a7e3228',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_339',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_339',
#   '_rev': '_emidgZq---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_339',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '81fd5db4-ed48-4f94-a4a3-d6833a703fde',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_340',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_340',
#   '_rev': '_emidgam---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_340',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '8a204bda-5a0d-4552-b470-9f125388801c',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_342',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_342',
#   '_rev': '_emidgbi---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_342',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'cbcb8ebc-8392-4778-8e17-3b88d9e74066',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_344',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_344',
#   '_rev': '_emidgce---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_344',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '9ff3f1e6-9a42-4af9-8d7b-fe28e3104805',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_355',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_355',
#   '_rev': '_emidgda---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_355',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'f5730ae0-13e2-4e43-b714-38778253204b',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_356',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_356',
#   '_rev': '_emidgeW---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_356',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '861cf3b1-faf2-4195-9714-9329e77127e6',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_358',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_358',
#   '_rev': '_emidgfa---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_358',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'a4d19f4f-a117-4b47-a741-34cf4280cc25',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_361',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_361',
#   '_rev': '_emidgga---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_361',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '303ac0f0-8f1c-4a96-8323-e1405de3b9d4',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_363',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_363',
#   '_rev': '_emidghe---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_363',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '0e92b247-4193-49d3-8ef4-cd08def96380',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_376',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_376',
#   '_rev': '_emidgim---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_376',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '08f97c41-0018-4fab-bb02-2bdec74f1e69',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_381',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_381',
#   '_rev': '_emidgju---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_381',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '40cc6dc0-aea4-4f6f-9bf9-f70e918ea340',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_391',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_391',
#   '_rev': '_emidgk2---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_391',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'f7b8cf8c-341c-4d8c-8318-dcd6df1dcb29',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_393',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_393',
#   '_rev': '_emidgl2---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_393',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'f4f58cdc-b8fe-49fe-9840-96e33fee6bac',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_397',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_397',
#   '_rev': '_emidgmy---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_397',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'd0b5ce84-923c-4159-810a-39134f3c598a',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_407',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_407',
#   '_rev': '_emidgn2---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_407',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '8193554c-4852-40d9-8cf7-4322f096ebda',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_409',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_409',
#   '_rev': '_emidgo2---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_409',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '415ba5f2-8f55-4e5c-a979-72165c82834a',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_415',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_415',
#   '_rev': '_emidgp2---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_415',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'd0b270ca-acc9-440b-a54b-e1032e509103',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_424',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_424',
#   '_rev': '_emidgqy---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_424',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '38ed68fd-1309-45c0-9f69-f680a0740a21',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_432',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_432',
#   '_rev': '_emidgry---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_432',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '542d650a-a790-4c72-b9e2-a0c227bd3a64',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_439',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_439',
#   '_rev': '_emidgsy---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_439',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '9c4d7253-081d-4208-8877-372c1de21542',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_444',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_444',
#   '_rev': '_emidgty---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_444',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '562ea536-b73b-4533-a6f5-e7ecd32067b3',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_445',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_445',
#   '_rev': '_emidgu2---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_445',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'd6d521bc-9111-4dad-a7ad-b438282ea353',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_452',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_452',
#   '_rev': '_emidgw----',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_452',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'dd7a27ad-bfb3-4931-9d82-40fd5195f449',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_460',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_460',
#   '_rev': '_emidgw6---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_460',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'c37aca65-de88-483c-b915-76e20423c3f9',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_461',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_461',
#   '_rev': '_emidgx2---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_461',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '16fb2f1c-3068-4a03-b996-0eae6c2f780e',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_480',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_480',
#   '_rev': '_emidgyy---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_480',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '6011d896-533b-452f-b4b0-4e776701d645',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_482',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_482',
#   '_rev': '_emidgzy---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_482',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '29b3b535-52d0-4fee-abf8-29976f102c63',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_491',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_491',
# ...
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_999952906',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_999952906',
#   '_rev': '_emidzlm---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_999952906',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'a7142d2e-212a-4acd-88f0-a0bb508f05da',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_999952909',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_999952909',
#   '_rev': '_emidzmm---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_999952909',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '8ab714d4-c52b-4e80-9d9b-4fdc8a840a37',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_999953065',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_999953065',
#   '_rev': '_emidznm---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_999953065',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '053b4482-04da-49db-9630-5aecd12b89cc',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_999953114',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_999953114',
#   '_rev': '_emidzom---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_999953114',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '563591c6-2aa7-442c-94d0-df400e04cc83',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_999953157',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_999953157',
#   '_rev': '_emidzpi---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_999953157',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'a3ea0a21-3886-4284-a18e-a3bff6ade58b',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_999953172',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_999953172',
#   '_rev': '_emidzqi---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_999953172',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'e8f35bc6-df77-408f-a4cc-bb59e0e1b97f',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_999953266',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_999953266',
#   '_rev': '_emidzre---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_999953266',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '60a12d03-d3ce-4ea6-8d66-db6fcfb8b84f',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_999953267',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_999953267',
#   '_rev': '_emidzsa---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_999953267',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '3ef1d2d7-114f-4b74-9689-7239750943a4',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_999954831',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_999954831',
#   '_rev': '_emidztW---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_999954831',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '031d87a8-d568-4c20-bee5-af06ef6e9959',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_999954832',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_999954832',
#   '_rev': '_emidzuW---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_999954832',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '1e37f187-f489-4cda-9225-b7689af7c09a',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_999954834',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_999954834',
#   '_rev': '_emidzvS---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_999954834',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'ddce5cd3-921c-4b07-b1a6-e2c860e4a63b',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_999954839',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_999954839',
#   '_rev': '_emidzwO---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_999954839',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'cc1e2108-0614-47d8-951b-11197b855850',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_999954840',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.DATA_TYPE.DATA_TYPE_999954840',
#   '_rev': '_emidzxO---',
#   '_to': 'Entity/DATA_TYPE.DATA_TYPE_999954840',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '3f7b111a-a52b-4011-a0f4-e5615cb1a7b0',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.p1c5b',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.p1c5b',
#   '_rev': '_emidzyS---',
#   '_to': 'Entity/p1c5b',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '39f8794a-2bf9-4581-aac3-232e0716a187',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.p6da5',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.p6da5',
#   '_rev': '_emid76e---',
#   '_to': 'Entity/p6da5',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'f90d3397-b1c0-4a3c-9834-595cc472a286',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.p841a',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.p841a',
#   '_rev': '_emieDx6---',
#   '_to': 'Entity/p841a',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'c87d5c44-c761-4cbc-ab22-120514aec384',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.p883f',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.p883f',
#   '_rev': '_emieLhW---',
#   '_to': 'Entity/p883f',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '674e9d1c-f541-40ee-9868-c7aad5e5ffbd',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.pb742',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.pb742',
#   '_rev': '_emieTUu---',
#   '_to': 'Entity/pb742',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '1620fa3a-579b-4f3b-a361-9cc412212fdc',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.p8051',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.p8051',
#   '_rev': '_emiebJu---',
#   '_to': 'Entity/p8051',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'd154153f-100f-4614-9953-389f5e40b5f4',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.pe419',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.pe419',
#   '_rev': '_emiei9C---',
#   '_to': 'Entity/pe419',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '60c48be0-7f8f-409c-8630-c27959269739',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.p665c',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.p665c',
#   '_rev': '_emieq2e---',
#   '_to': 'Entity/p665c',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'f97261ae-f58c-4f27-b2fe-1637b77e67e2',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.p39d9',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.p39d9',
#   '_rev': '_emiey1m---',
#   '_to': 'Entity/p39d9',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '45ea140a-738a-41fe-9a7d-6e88bf4422ef',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.pede5',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.pede5',
#   '_rev': '_emie6mS---',
#   '_to': 'Entity/pede5',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'bd1e7f8f-1f7f-4e29-ba5b-ba8d663cc085',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.pff00',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.pff00',
#   '_rev': '_emifCbC---',
#   '_to': 'Entity/pff00',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '38ea99d3-315c-4def-87be-608f1a7db4cf',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.pd184',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.pd184',
#   '_rev': '_emifKWO---',
#   '_to': 'Entity/pd184',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': 'c8874fb6-1479-4e5b-af24-002fc3616f15',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.p99bc',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.p99bc',
#   '_rev': '_emifSRO---',
#   '_to': 'Entity/p99bc',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '37bf7edf-5c80-4ee0-b279-612885803a05',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.p1e35',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.p1e35',
#   '_rev': '_emifaUi---',
#   '_to': 'Entity/p1e35',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '050b7187-1a6e-468c-b51a-2c1f4d5ae62f',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.p344b',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.p344b',
#   '_rev': '_emifiYO---',
#   '_to': 'Entity/p344b',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '6cf65c5b-60c4-4831-b005-1ae6a8bd5ebd',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.p8f11',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.p8f11',
#   '_rev': '_emifqXi---',
#   '_to': 'Entity/p8f11',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '6c843458-75ec-431f-b05f-baace41b9b40',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.p5191',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.p5191',
#   '_rev': '_emifyQC---',
#   '_to': 'Entity/p5191',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '0db09a8b-41da-4c4d-ba83-2cf20d1fd0ec',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.p7d72',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.p7d72',
#   '_rev': '_emif7_S---',
#   '_to': 'Entity/p7d72',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '4c6e80f3-3cde-4b4d-9898-42dc113978e6',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.p3604',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.p3604',
#   '_rev': '_emigByq---',
#   '_to': 'Entity/p3604',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '1e8ac239-140a-45ed-925b-048b0840c22e',
#   'verified': False},
#  {'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.p9c05',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED.PH_ID.p9c05',
#   '_rev': '_emigIrq---',
#   '_to': 'Entity/p9c05',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'toUuid': '38a5a625-3a7d-4b32-be86-db4d45b6e56b',
#   'verified': False}]

# %%
import knowledge_engine_sdk
print(dir(knowledge_engine_sdk))
print(knowledge_engine_sdk.__doc__)
print(dir(KnowledgeEngine))
help(knowledge_engine_sdk)
print(knowledge_engine_sdk.__file__)

from knowledge_engine_sdk import KnowledgeEngine
help(KnowledgeEngine)

import inspect
from knowledge_engine_sdk import KnowledgeEngine

sdk = KnowledgeEngine()
print(inspect.signature(sdk.get_entities))

import inspect
from knowledge_engine_sdk import KnowledgeEngine

print(inspect.getsource(KnowledgeEngine))
# Out:
# ['Any', 'BaseModel', 'Connection', 'ConnectionDirection', 'ConnectionTypes', 'CreateConnection', 'CreateEntity', 'DeleteConnection', 'DeleteEntity', 'Entity', 'EntityTypes', 'Enum', 'GetConnectionListParams', 'GetConnectionParams', 'GetEntityListParams', 'GetEntityParams', 'GetEntityTypeParams', 'Knowledge', 'KnowledgeEngine', 'List', 'Optional', 'OrderBy', 'Pagination', 'TraverseAlgorithm', 'TraverseParams', 'Union', 'ValidationError', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'datetime', 'errors', 'knowledge_engine_sdk', 'models', 'utils']
# None
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_init_db', 'create_candidate_id', 'create_connection', 'create_entity', 'delete_connection', 'delete_entity', 'get_connection', 'get_connection_types', 'get_connections', 'get_entities', 'get_entity', 'get_entity_types', 'traverse_graph']
# Help on package knowledge_engine_sdk:
#
# NAME
#     knowledge_engine_sdk
#
# PACKAGE CONTENTS
#     errors
#     knowledge_engine_sdk
#     models
#     utils
#
# DATA
#     Any = typing.Any
#         Special type indicating an unconstrained type.
#
#         - Any is compatible with every type.
#         - Any assumed to have all methods.
#         - All values assumed to be instances of Any.
#
#         Note that all the above statements are true from the point of view of
#         static type checkers. At runtime, Any should not be used with instance
#         or class checks.
#
#     List = typing.List
#         A generic version of list.
#
#     Optional = typing.Optional
#         Optional type.
#
#         Optional[X] is equivalent to Union[X, None].
#
#     Union = typing.Union
#         Union type; Union[X, Y] means either X or Y.
#
#         To define a union, use e.g. Union[int, str].  Details:
#         - The arguments must be types and there must be at least one.
#         - None as an argument is a special case and is replaced by
#           type(None).
#         - Unions of unions are flattened, e.g.::
#
#             Union[Union[int, str], float] == Union[int, str, float]
#
#         - Unions of a single argument vanish, e.g.::
#
#             Union[int] == int  # The constructor actually returns int
#
#         - Redundant arguments are skipped, e.g.::
#
#             Union[int, str, int] == Union[int, str]
#
#         - When comparing unions, the argument order is ignored, e.g.::
#
#             Union[int, str] == Union[str, int]
#
#         - You cannot subclass or instantiate a union.
#         - You can use Optional[X] as a shorthand for Union[X, None].
#
# FILE
#     /usr/local/lib/python3.9/dist-packages/knowledge_engine_sdk/__init__.py
#
#
# /usr/local/lib/python3.9/dist-packages/knowledge_engine_sdk/__init__.py
# Help on class KnowledgeEngine in module knowledge_engine_sdk.knowledge_engine_sdk:
#
# class KnowledgeEngine(builtins.object)
#  |  KnowledgeEngine(base_url: str = 'http://10.0.0.15:8529', username: str = 'root', password: str = 'aBkWsa5vhIVx8GzF', main_db: str = 'PhenomeDB')
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, base_url: str = 'http://10.0.0.15:8529', username: str = 'root', password: str = 'aBkWsa5vhIVx8GzF', main_db: str = 'PhenomeDB')
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  create_candidate_id(self)
#  |
#  |  create_connection(self, data: knowledge_engine_sdk.models.CreateConnection)
#  |
#  |  create_entity(self, data: knowledge_engine_sdk.models.CreateEntity)
#  |
#  |  delete_connection(self, data: knowledge_engine_sdk.models.DeleteConnection)
#  |
#  |  delete_entity(self, data: knowledge_engine_sdk.models.DeleteEntity)
#  |
#  |  get_connection(self, params: knowledge_engine_sdk.models.GetConnectionParams)
#  |
#  |  get_connection_types(self)
#  |
#  |  get_connections(self, params: knowledge_engine_sdk.models.GetConnectionListParams)
#  |
#  |  get_entities(self, params: Optional[knowledge_engine_sdk.models.GetEntityListParams])
#  |
#  |  get_entity(self, params: knowledge_engine_sdk.models.GetEntityParams)
#  |
#  |  get_entity_types(self)
#  |
#  |  traverse_graph(self, params: knowledge_engine_sdk.models.TraverseParams)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#
# (params: Optional[knowledge_engine_sdk.models.GetEntityListParams])
# class KnowledgeEngine(object):
#
#     @typed()
#     def __init__(self, base_url: str = "http://10.0.0.15:8529", username: str = "root", password: str = "aBkWsa5vhIVx8GzF", main_db: str = "PhenomeDB"):
#         self.test = "I am the Knowledge Engine."
#
#         # Environment variables
#         self.procedure_uuid = os.getenv("PROCEDURE_UUID")
#
#         # Init db
#         self._init_db(main_db, base_url, username, password)
#
#     ##### KNOWLEDGE ENGINE FUNCTIONS #####
#
#     @validate_arguments
#     def create_candidate_id(self):
#         return create_uuid()
#
#     @validate_arguments
#     def create_entity(self, data: CreateEntity):
#
#         # Convert to dict
#         body = json.loads(data.json())
#         body["uuid"] = create_uuid()
#         body["basicEnum"] = create_enum(body["name"])
#         body["enum"] = body["entityType"] + "_" + body["basicEnum"]
#         body["creator"] = "SYSTEM"
#         body["creatorType"] = "SYSTEM"
#         body["verified"] = False
#
#         is_system = body["isSystem"]
#         del body["isSystem"]
#         body["system"] = is_system
#
#         # Check for existing
#         cursor = self.aql.execute(
#             f'FOR doc IN Entity FILTER doc.enum == @value LIMIT 1 RETURN doc',
#             bind_vars={'value': body["enum"]}
#         )
#
#         new_cursor = list(cursor)
#
#         if len(new_cursor) > 0:
#             result = new_cursor[0]
#             return result
#
#         # Create record
#         self.def_collection.insert(body)
#
#         # Get record
#         cursor = self.aql.execute(
#             f'FOR doc IN Entity FILTER doc.uuid == @value LIMIT 1 RETURN doc',
#             bind_vars={'value': body["uuid"]}
#         )
#
#         result = list(cursor)[0]
#
#         return result
#
#     @validate_arguments
#     def delete_entity(self, data: DeleteEntity):
#
#         # Convert to dict
#         body = json.loads(data.json())
#
#         # Check for existing
#         cursor = self.aql.execute(
#             f'FOR doc IN Entity FILTER doc.uuid == @value LIMIT 1 RETURN doc',
#             bind_vars={'value': body["uuid"]}
#         )
#
#         new_cursor = list(cursor)
#
#         if len(new_cursor) == 0:
#             raise ValueError(record_not_found)
#         else:
#             result = list(new_cursor)[0]
#
#         # Delete record
#         self.def_collection.delete(result["_key"])
#
#         return
#
#     @validate_arguments
#     def create_connection(self, data: CreateConnection):
#
#         # Convert to dict
#         body = json.loads(data.json())
#         body["verified"] = False
#         if "payload" not in body:
#             body["payload"] = {}
#
#         # Get from entity
#         cursor = self.aql.execute(
#             f'FOR doc IN Entity FILTER doc.uuid == @value LIMIT 1 RETURN doc',
#             bind_vars={'value': body["fromUuid"]}
#         )
#
#         from_entity = list(cursor)[0]
#
#         # Get to entity
#         cursor = self.aql.execute(
#             f'FOR doc IN Entity FILTER doc.uuid == @value LIMIT 1 RETURN doc',
#             bind_vars={'value': body["toUuid"]}
#         )
#
#         to_entity = list(cursor)[0]
#
#         body["_from"] = from_entity["_id"]
#         body["_to"] = to_entity["_id"]
#         body["_key"] = from_entity["_key"] + "_" + to_entity["_key"]
#
#         # Check existing
#         existing = self.contains.get(body["_key"])
#         if existing is not None:
#             return
#
#         # Create record
#         self.contains.insert(body)
#
#         cursor = self.aql.execute(
#             f'FOR doc IN contains FILTER doc.fromUuid == @value1 && doc.toUuid == @value2 RETURN doc',
#             bind_vars={'value1': body["fromUuid"], 'value2': body["toUuid"]})
#
#         results = list(cursor)
#
#         return
#
#     @validate_arguments
#     def delete_connection(self, data: DeleteConnection):
#
#         # Convert to dict
#         body = json.loads(data.json())
#
#         cursor = self.aql.execute(
#             f'FOR doc IN contains FILTER doc.fromUuid == @value1 && doc.toUuid == @value2 RETURN doc',
#             bind_vars={'value1': body["fromUuid"], 'value2': body["toUuid"]})
#
#         result = list(cursor)[0]
#
#         # Delete record
#         self.contains.delete(result["_key"])
#
#         return
#
#     @validate_arguments
#     def get_entity_types(self):
#         cursor = self.aql.execute('FOR doc IN Entity RETURN DISTINCT doc.entityType')
#
#         results = list(cursor)
#
#         return results
#
#     @validate_arguments
#     def get_entities(self, params: Optional[GetEntityListParams]):
#         if params is not None:
#             params = json.loads(params.json())
#
#             cursor = self.aql.execute(
#                 'FOR doc IN Entity FILTER doc.entityType == @value RETURN doc',
#                 bind_vars={'value': params["entity_type_enum"]}
#             )
#
#             results = list(cursor)
#
#         else:
#             cursor = self.aql.execute('FOR doc IN Entity RETURN doc')
#
#             results = list(cursor)
#
#         return results
#
#     @validate_arguments
#     def get_entity(self, params: GetEntityParams):
#         params = json.loads(params.json())
#
#         if params["uuid"] is not None:
#             query_param = "uuid"
#             query_value = params["uuid"]
#         else:
#             query_param = "enum"
#             query_value = params["entity_type_enum"] + "_" + params["enum"]
#
#         cursor = self.aql.execute(
#             f'FOR doc IN Entity FILTER doc.{query_param} == @value LIMIT 1 RETURN doc',
#             bind_vars={'value': query_value}
#         )
#
#         new_cursor = list(cursor)
#
#         if len(new_cursor) == 0:
#             return
#         else:
#             result = new_cursor[0]
#
#         return result
#
#     @validate_arguments
#     def get_connection_types(self):
#         results = self.def_graph.edge_definitions()
#
#         return results
#
#     @validate_arguments
#     def get_connections(self, params: GetConnectionListParams):
#         params = json.loads(params.json())
#
#         if params["direction"] == "in":
#             edge_direction = "toUuid"
#         else:
#             edge_direction = "fromUuid"
#
#         cursor = self.aql.execute(
#             f'FOR doc IN {params["connection_type_name"]} FILTER doc.{edge_direction} == @value RETURN doc',
#             bind_vars={'value': params["entity_uuid"]})
#
#         results = list(cursor)
#
#         return results
#
#     @validate_arguments
#     def get_connection(self, params: GetConnectionParams):
#         params = json.loads(params.json())
#
#         cursor = self.aql.execute(
#             f'FOR doc IN contains FILTER doc.fromUuid == @value1 && doc.toUuid == @value2 RETURN doc',
#             bind_vars={'value1': params["from_entity_uuid"], 'value2': params["to_entity_uuid"]})
#
#         results = list(cursor)
#
#         return results
#
#     @validate_arguments
#     def traverse_graph(self, params: TraverseParams):
#         params = json.loads(params.json())
#
#         cursor = self.aql.execute(
#             f'FOR doc IN Entity FILTER doc.uuid == @value LIMIT 1 RETURN doc',
#             bind_vars={'value': params["start_entity_uuid"]}
#         )
#
#         start_vertex = list(cursor)[0]
#
#         if params["direction"] == "in":
#             direction = "inbound"
#         else:
#             direction = "outbound"
#
#         result = self.def_graph.traverse(
#             start_vertex = start_vertex["_id"],
#             direction = direction,
#             strategy = params["algorithm"],
#             min_depth = params["min_depth"],
#             max_depth = params["max_depth"]
#         )
#
#         return result
#
#     ##### HELPER FUNCTIONS #####
#
#     @validate_arguments
#     def _init_db(self, main_db, base_url, username, password):
#
#         # Initialize the client for ArangoDB
#         client = ArangoClient(hosts=base_url)
#
#         # Connect to "_system" database as root user
#         sys_db = client.db("_system", username=username, password=password)
#
#         # Connect to "PhenomeDB" database as root user.
#         if not sys_db.has_database(main_db):
#             sys_db.create_database(main_db)
#         self.db = client.db(main_db, username=username, password=password)
#
#         # Init AQL
#         self.aql = self.db.aql
#
#         # Define default graph
#         self.def_graph = self.db.graph('Knowledge')
#
#         # Define default collection
#         self.def_collection = self.def_graph.vertex_collection("Entity")
#
#         # Define contains edge
#         self.contains = self.def_graph.edge_collection('contains')
#
#         return

# %%
from knowledge_engine_sdk import *
import pprint
import pandas as pd

pp = pprint.PrettyPrinter(indent=1)

sdk = KnowledgeEngine()

# Get list of entities
query_params = GetEntityListParams(
    entity_type_enum = EntityTypes.DATA_ELEMENT
)

data_elements = sdk.get_entities(params=query_params)

query_params = GetEntityListParams(
    entity_type_enum = EntityTypes.DATA_SET
)

data_sets = sdk.get_entities(params=query_params)
pp.pprint(data_sets)

# Get a particular entity
medication_dosages_entity = next((entity for entity in data_elements if entity['enum'] == 'DATA_ELEMENT_MEDICATION_DOSAGES'), None)

if medication_dosages_entity:
    query_params = GetEntityParams(
        uuid = medication_dosages_entity['uuid'],
        enum = medication_dosages_entity['basicEnum'],
        entity_type_enum = EntityTypes.DATA_ELEMENT
    )
else:
    query_params = GetEntityParams(
        uuid = None,
        enum = "MEDICATION_DOSAGES",
        entity_type_enum = EntityTypes.DATA_ELEMENT
    )

entity = sdk.get_entity(params=query_params)
pp.pprint(entity)

pd.DataFrame.from_dict(entity, orient='index')
# Out:
# [{'_id': 'Entity/DATA_SET.DATA_SET_SCIENTIFIC_WELLNESS_COHORT',
#   '_key': 'DATA_SET.DATA_SET_SCIENTIFIC_WELLNESS_COHORT',
#   '_rev': '_emidfWW---',
#   'basicEnum': 'SCIENTIFIC_WELLNESS_COHORT',
#   'candidateId': '4689f863-3977-4f4f-bcca-965d9136cbcb',
#   'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#   'creatorType': 'USER',
#   'entityType': 'DATA_SET',
#   'enum': 'DATA_SET_SCIENTIFIC_WELLNESS_COHORT',
#   'name': 'Scientific Wellness Cohort',
#   'system': True,
#   'uuid': '5308b32a-4e51-489f-8adb-7c842152d161',
#   'verified': True}]
# {'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#  '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#  '_rev': '_emigRCG---',
#  'basicEnum': 'MEDICATION_DOSAGES',
#  'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#  'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#  'creatorType': 'USER',
#  'entityType': 'DATA_ELEMENT',
#  'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#  'name': 'medication_dosages.csv',
#  'system': True,
#  'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#  'verified': False}
#                                                              0
# _key              DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES
# _id          Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DO...
# _rev                                               _emigRCG---
# uuid                      5afd2304-f739-4f06-b1f8-61ddda331ff6
# name                                    medication_dosages.csv
# enum                           DATA_ELEMENT_MEDICATION_DOSAGES
# basicEnum                                   MEDICATION_DOSAGES
# system                                                    True
# creator                   29abf4b0-8d11-4eed-81d1-9ec501cc2ee7
# creatorType                                               USER
# entityType                                        DATA_ELEMENT
# candidateId               576d7aba-6cf0-4f27-8a19-aa01b38a5ef2
# verified                                                 False

# %%
# Connections

# Get list of connection types
connection_types = sdk.get_connection_types()
# pp.pprint(connection_types)

# Get list of connections for an entity
query_params = GetConnectionListParams(
    connection_type_name = "contains",
    entity_uuid = entity["uuid"],
    direction = "out"
)

connections = sdk.get_connections(params=query_params)
# pp.pprint(connections)

# Get a particular connection between 2 entities
query_params = GetConnectionParams(
    from_entity_uuid = data_sets[0]["uuid"],
    to_entity_uuid = data_elements[0]["uuid"]
)

connection = sdk.get_connection(params=query_params)
pp.pprint(connection)


pd.DataFrame.from_dict(connections).transpose()

from knowledge_engine_sdk import TraverseAlgorithm

# Graphs

# Traverse a graph
query_params = TraverseParams(
    start_entity_uuid = entity["uuid"],
    direction = "out",
    max_depth = 1,
    min_depth = 0,
    algorithm = TraverseAlgorithm.BREADTH  # Changed from BREADTH_FIRST to BREADTH
)

traversal = sdk.traverse_graph(params=query_params)
pp.pprint(traversal)
# Out:
# [{'_from': 'Entity/DATA_SET.DATA_SET_SCIENTIFIC_WELLNESS_COHORT',
#   '_id': 'contains/DATA_SET.DATA_SET_SCIENTIFIC_WELLNESS_COHORT.DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_key': 'DATA_SET.DATA_SET_SCIENTIFIC_WELLNESS_COHORT.DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_rev': '_emidfaC---',
#   '_to': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '5308b32a-4e51-489f-8adb-7c842152d161',
#   'toUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'verified': False}]
# {'paths': [{'edges': [],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.DATA_TYPE.DATA_TYPE_MEDICATION_ID',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.DATA_TYPE.DATA_TYPE_MEDICATION_ID',
#                        '_rev': '_emigRDy---',
#                        '_to': 'Entity/DATA_TYPE.DATA_TYPE_MEDICATION_ID',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': 'd7192137-a103-457e-9075-39770e53de33',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/DATA_TYPE.DATA_TYPE_MEDICATION_ID',
#                           '_key': 'DATA_TYPE.DATA_TYPE_MEDICATION_ID',
#                           '_rev': '_emigRDS---',
#                           'basicEnum': 'MEDICATION_ID',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_TYPE',
#                           'enum': 'DATA_TYPE_MEDICATION_ID',
#                           'name': 'medication_id',
#                           'system': True,
#                           'uuid': 'd7192137-a103-457e-9075-39770e53de33',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.DATA_TYPE.DATA_TYPE_NAME',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.DATA_TYPE.DATA_TYPE_NAME',
#                        '_rev': '_emigREq---',
#                        '_to': 'Entity/DATA_TYPE.DATA_TYPE_NAME',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': 'f2b0f9a7-c0cc-4830-8fe9-20ec9adcf89f',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/DATA_TYPE.DATA_TYPE_NAME',
#                           '_key': 'DATA_TYPE.DATA_TYPE_NAME',
#                           '_rev': '_emigREK---',
#                           'basicEnum': 'NAME',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_TYPE',
#                           'enum': 'DATA_TYPE_NAME',
#                           'name': 'name',
#                           'system': True,
#                           'uuid': 'f2b0f9a7-c0cc-4830-8fe9-20ec9adcf89f',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.DATA_TYPE.DATA_TYPE_AMOUNT',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.DATA_TYPE.DATA_TYPE_AMOUNT',
#                        '_rev': '_emigRFi---',
#                        '_to': 'Entity/DATA_TYPE.DATA_TYPE_AMOUNT',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': 'd9c1ade2-7f06-4fb8-9841-9084710f6474',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/DATA_TYPE.DATA_TYPE_AMOUNT',
#                           '_key': 'DATA_TYPE.DATA_TYPE_AMOUNT',
#                           '_rev': '_emigRFC---',
#                           'basicEnum': 'AMOUNT',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_TYPE',
#                           'enum': 'DATA_TYPE_AMOUNT',
#                           'name': 'amount',
#                           'system': True,
#                           'uuid': 'd9c1ade2-7f06-4fb8-9841-9084710f6474',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.DATA_TYPE.DATA_TYPE_UNIT',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.DATA_TYPE.DATA_TYPE_UNIT',
#                        '_rev': '_emigRGa---',
#                        '_to': 'Entity/DATA_TYPE.DATA_TYPE_UNIT',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': 'c5bf4059-1034-4af1-b0e2-6f55fbca8a70',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/DATA_TYPE.DATA_TYPE_UNIT',
#                           '_key': 'DATA_TYPE.DATA_TYPE_UNIT',
#                           '_rev': '_emigRF6---',
#                           'basicEnum': 'UNIT',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_TYPE',
#                           'enum': 'DATA_TYPE_UNIT',
#                           'name': 'unit',
#                           'system': True,
#                           'uuid': 'c5bf4059-1034-4af1-b0e2-6f55fbca8a70',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p1c5b',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p1c5b',
#                        '_rev': '_emigRHG---',
#                        '_to': 'Entity/p1c5b',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': '39f8794a-2bf9-4581-aac3-232e0716a187',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/p1c5b',
#                           '_key': 'p1c5b',
#                           '_rev': '_emidzxq---',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'PH_ID',
#                           'name': 'p1c5b',
#                           'phId': 'p1c5b',
#                           'system': True,
#                           'uuid': '39f8794a-2bf9-4581-aac3-232e0716a187',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p6da5',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p6da5',
#                        '_rev': '_emigRJO---',
#                        '_to': 'Entity/p6da5',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': 'f90d3397-b1c0-4a3c-9834-595cc472a286',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/p6da5',
#                           '_key': 'p6da5',
#                           '_rev': '_emid76----',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'PH_ID',
#                           'name': 'p6da5',
#                           'phId': 'p6da5',
#                           'system': True,
#                           'uuid': 'f90d3397-b1c0-4a3c-9834-595cc472a286',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p841a',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p841a',
#                        '_rev': '_emigRLa---',
#                        '_to': 'Entity/p841a',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': 'c87d5c44-c761-4cbc-ab22-120514aec384',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/p841a',
#                           '_key': 'p841a',
#                           '_rev': '_emieDxW---',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'PH_ID',
#                           'name': 'p841a',
#                           'phId': 'p841a',
#                           'system': True,
#                           'uuid': 'c87d5c44-c761-4cbc-ab22-120514aec384',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p883f',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p883f',
#                        '_rev': '_emigRNu---',
#                        '_to': 'Entity/p883f',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': '674e9d1c-f541-40ee-9868-c7aad5e5ffbd',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/p883f',
#                           '_key': 'p883f',
#                           '_rev': '_emieLgy---',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'PH_ID',
#                           'name': 'p883f',
#                           'phId': 'p883f',
#                           'system': True,
#                           'uuid': '674e9d1c-f541-40ee-9868-c7aad5e5ffbd',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.pb742',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.pb742',
#                        '_rev': '_emigRP6---',
#                        '_to': 'Entity/pb742',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': '1620fa3a-579b-4f3b-a361-9cc412212fdc',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/pb742',
#                           '_key': 'pb742',
#                           '_rev': '_emieTUK---',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'PH_ID',
#                           'name': 'pb742',
#                           'phId': 'pb742',
#                           'system': True,
#                           'uuid': '1620fa3a-579b-4f3b-a361-9cc412212fdc',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p8051',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p8051',
#                        '_rev': '_emigRSG---',
#                        '_to': 'Entity/p8051',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': 'd154153f-100f-4614-9953-389f5e40b5f4',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/p8051',
#                           '_key': 'p8051',
#                           '_rev': '_emiebJK---',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'PH_ID',
#                           'name': 'p8051',
#                           'phId': 'p8051',
#                           'system': True,
#                           'uuid': 'd154153f-100f-4614-9953-389f5e40b5f4',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.pe419',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.pe419',
#                        '_rev': '_emigRUO---',
#                        '_to': 'Entity/pe419',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': '60c48be0-7f8f-409c-8630-c27959269739',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/pe419',
#                           '_key': 'pe419',
#                           '_rev': '_emiei8e---',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'PH_ID',
#                           'name': 'pe419',
#                           'phId': 'pe419',
#                           'system': True,
#                           'uuid': '60c48be0-7f8f-409c-8630-c27959269739',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p665c',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p665c',
#                        '_rev': '_emigRWS---',
#                        '_to': 'Entity/p665c',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': 'f97261ae-f58c-4f27-b2fe-1637b77e67e2',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/p665c',
#                           '_key': 'p665c',
#                           '_rev': '_emieq2----',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'PH_ID',
#                           'name': 'p665c',
#                           'phId': 'p665c',
#                           'system': True,
#                           'uuid': 'f97261ae-f58c-4f27-b2fe-1637b77e67e2',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p39d9',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p39d9',
#                        '_rev': '_emigRYa---',
#                        '_to': 'Entity/p39d9',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': '45ea140a-738a-41fe-9a7d-6e88bf4422ef',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/p39d9',
#                           '_key': 'p39d9',
#                           '_rev': '_emiey1----',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'PH_ID',
#                           'name': 'p39d9',
#                           'phId': 'p39d9',
#                           'system': True,
#                           'uuid': '45ea140a-738a-41fe-9a7d-6e88bf4422ef',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.pede5',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.pede5',
#                        '_rev': '_emigRai---',
#                        '_to': 'Entity/pede5',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': 'bd1e7f8f-1f7f-4e29-ba5b-ba8d663cc085',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/pede5',
#                           '_key': 'pede5',
#                           '_rev': '_emie6ly---',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'PH_ID',
#                           'name': 'pede5',
#                           'phId': 'pede5',
#                           'system': True,
#                           'uuid': 'bd1e7f8f-1f7f-4e29-ba5b-ba8d663cc085',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.pff00',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.pff00',
#                        '_rev': '_emigRcm---',
#                        '_to': 'Entity/pff00',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': '38ea99d3-315c-4def-87be-608f1a7db4cf',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/pff00',
#                           '_key': 'pff00',
#                           '_rev': '_emifCae---',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'PH_ID',
#                           'name': 'pff00',
#                           'phId': 'pff00',
#                           'system': True,
#                           'uuid': '38ea99d3-315c-4def-87be-608f1a7db4cf',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.pd184',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.pd184',
#                        '_rev': '_emigRey---',
#                        '_to': 'Entity/pd184',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': 'c8874fb6-1479-4e5b-af24-002fc3616f15',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/pd184',
#                           '_key': 'pd184',
#                           '_rev': '_emifKVq---',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'PH_ID',
#                           'name': 'pd184',
#                           'phId': 'pd184',
#                           'system': True,
#                           'uuid': 'c8874fb6-1479-4e5b-af24-002fc3616f15',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p99bc',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p99bc',
#                        '_rev': '_emigRg6---',
#                        '_to': 'Entity/p99bc',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': '37bf7edf-5c80-4ee0-b279-612885803a05',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/p99bc',
#                           '_key': 'p99bc',
#                           '_rev': '_emifSQq---',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'PH_ID',
#                           'name': 'p99bc',
#                           'phId': 'p99bc',
#                           'system': True,
#                           'uuid': '37bf7edf-5c80-4ee0-b279-612885803a05',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p1e35',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p1e35',
#                        '_rev': '_emigRjG---',
#                        '_to': 'Entity/p1e35',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': '050b7187-1a6e-468c-b51a-2c1f4d5ae62f',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/p1e35',
#                           '_key': 'p1e35',
#                           '_rev': '_emifaU----',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'PH_ID',
#                           'name': 'p1e35',
#                           'phId': 'p1e35',
#                           'system': True,
#                           'uuid': '050b7187-1a6e-468c-b51a-2c1f4d5ae62f',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p344b',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p344b',
#                        '_rev': '_emigRlW---',
#                        '_to': 'Entity/p344b',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': '6cf65c5b-60c4-4831-b005-1ae6a8bd5ebd',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/p344b',
#                           '_key': 'p344b',
#                           '_rev': '_emifiXm---',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'PH_ID',
#                           'name': 'p344b',
#                           'phId': 'p344b',
#                           'system': True,
#                           'uuid': '6cf65c5b-60c4-4831-b005-1ae6a8bd5ebd',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p8f11',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p8f11',
#                        '_rev': '_emigRne---',
#                        '_to': 'Entity/p8f11',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': '6c843458-75ec-431f-b05f-baace41b9b40',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/p8f11',
#                           '_key': 'p8f11',
#                           '_rev': '_emifqW2---',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'PH_ID',
#                           'name': 'p8f11',
#                           'phId': 'p8f11',
#                           'system': True,
#                           'uuid': '6c843458-75ec-431f-b05f-baace41b9b40',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p5191',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p5191',
#                        '_rev': '_emigRpm---',
#                        '_to': 'Entity/p5191',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': '0db09a8b-41da-4c4d-ba83-2cf20d1fd0ec',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/p5191',
#                           '_key': 'p5191',
#                           '_rev': '_emifyPi---',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'PH_ID',
#                           'name': 'p5191',
#                           'phId': 'p5191',
#                           'system': True,
#                           'uuid': '0db09a8b-41da-4c4d-ba83-2cf20d1fd0ec',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p7d72',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p7d72',
#                        '_rev': '_emigRri---',
#                        '_to': 'Entity/p7d72',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': '4c6e80f3-3cde-4b4d-9898-42dc113978e6',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
# ...
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'PH_ID',
#                           'name': 'p3604',
#                           'phId': 'p3604',
#                           'system': True,
#                           'uuid': '1e8ac239-140a-45ed-925b-048b0840c22e',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p9c05',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p9c05',
#                        '_rev': '_emigRvy---',
#                        '_to': 'Entity/p9c05',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': '38a5a625-3a7d-4b32-be86-db4d45b6e56b',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/p9c05',
#                           '_key': 'p9c05',
#                           '_rev': '_emigIrK---',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'PH_ID',
#                           'name': 'p9c05',
#                           'phId': 'p9c05',
#                           'system': True,
#                           'uuid': '38a5a625-3a7d-4b32-be86-db4d45b6e56b',
#                           'verified': False}]}],
#  'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                '_rev': '_emigRCG---',
#                'basicEnum': 'MEDICATION_DOSAGES',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'DATA_ELEMENT',
#                'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                'name': 'medication_dosages.csv',
#                'system': True,
#                'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                'verified': False},
#               {'_id': 'Entity/DATA_TYPE.DATA_TYPE_MEDICATION_ID',
#                '_key': 'DATA_TYPE.DATA_TYPE_MEDICATION_ID',
#                '_rev': '_emigRDS---',
#                'basicEnum': 'MEDICATION_ID',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'DATA_TYPE',
#                'enum': 'DATA_TYPE_MEDICATION_ID',
#                'name': 'medication_id',
#                'system': True,
#                'uuid': 'd7192137-a103-457e-9075-39770e53de33',
#                'verified': False},
#               {'_id': 'Entity/DATA_TYPE.DATA_TYPE_NAME',
#                '_key': 'DATA_TYPE.DATA_TYPE_NAME',
#                '_rev': '_emigREK---',
#                'basicEnum': 'NAME',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'DATA_TYPE',
#                'enum': 'DATA_TYPE_NAME',
#                'name': 'name',
#                'system': True,
#                'uuid': 'f2b0f9a7-c0cc-4830-8fe9-20ec9adcf89f',
#                'verified': False},
#               {'_id': 'Entity/DATA_TYPE.DATA_TYPE_AMOUNT',
#                '_key': 'DATA_TYPE.DATA_TYPE_AMOUNT',
#                '_rev': '_emigRFC---',
#                'basicEnum': 'AMOUNT',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'DATA_TYPE',
#                'enum': 'DATA_TYPE_AMOUNT',
#                'name': 'amount',
#                'system': True,
#                'uuid': 'd9c1ade2-7f06-4fb8-9841-9084710f6474',
#                'verified': False},
#               {'_id': 'Entity/DATA_TYPE.DATA_TYPE_UNIT',
#                '_key': 'DATA_TYPE.DATA_TYPE_UNIT',
#                '_rev': '_emigRF6---',
#                'basicEnum': 'UNIT',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'DATA_TYPE',
#                'enum': 'DATA_TYPE_UNIT',
#                'name': 'unit',
#                'system': True,
#                'uuid': 'c5bf4059-1034-4af1-b0e2-6f55fbca8a70',
#                'verified': False},
#               {'_id': 'Entity/p1c5b',
#                '_key': 'p1c5b',
#                '_rev': '_emidzxq---',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'p1c5b',
#                'phId': 'p1c5b',
#                'system': True,
#                'uuid': '39f8794a-2bf9-4581-aac3-232e0716a187',
#                'verified': False},
#               {'_id': 'Entity/p6da5',
#                '_key': 'p6da5',
#                '_rev': '_emid76----',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'p6da5',
#                'phId': 'p6da5',
#                'system': True,
#                'uuid': 'f90d3397-b1c0-4a3c-9834-595cc472a286',
#                'verified': False},
#               {'_id': 'Entity/p841a',
#                '_key': 'p841a',
#                '_rev': '_emieDxW---',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'p841a',
#                'phId': 'p841a',
#                'system': True,
#                'uuid': 'c87d5c44-c761-4cbc-ab22-120514aec384',
#                'verified': False},
#               {'_id': 'Entity/p883f',
#                '_key': 'p883f',
#                '_rev': '_emieLgy---',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'p883f',
#                'phId': 'p883f',
#                'system': True,
#                'uuid': '674e9d1c-f541-40ee-9868-c7aad5e5ffbd',
#                'verified': False},
#               {'_id': 'Entity/pb742',
#                '_key': 'pb742',
#                '_rev': '_emieTUK---',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'pb742',
#                'phId': 'pb742',
#                'system': True,
#                'uuid': '1620fa3a-579b-4f3b-a361-9cc412212fdc',
#                'verified': False},
#               {'_id': 'Entity/p8051',
#                '_key': 'p8051',
#                '_rev': '_emiebJK---',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'p8051',
#                'phId': 'p8051',
#                'system': True,
#                'uuid': 'd154153f-100f-4614-9953-389f5e40b5f4',
#                'verified': False},
#               {'_id': 'Entity/pe419',
#                '_key': 'pe419',
#                '_rev': '_emiei8e---',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'pe419',
#                'phId': 'pe419',
#                'system': True,
#                'uuid': '60c48be0-7f8f-409c-8630-c27959269739',
#                'verified': False},
#               {'_id': 'Entity/p665c',
#                '_key': 'p665c',
#                '_rev': '_emieq2----',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'p665c',
#                'phId': 'p665c',
#                'system': True,
#                'uuid': 'f97261ae-f58c-4f27-b2fe-1637b77e67e2',
#                'verified': False},
#               {'_id': 'Entity/p39d9',
#                '_key': 'p39d9',
#                '_rev': '_emiey1----',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'p39d9',
#                'phId': 'p39d9',
#                'system': True,
#                'uuid': '45ea140a-738a-41fe-9a7d-6e88bf4422ef',
#                'verified': False},
#               {'_id': 'Entity/pede5',
#                '_key': 'pede5',
#                '_rev': '_emie6ly---',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'pede5',
#                'phId': 'pede5',
#                'system': True,
#                'uuid': 'bd1e7f8f-1f7f-4e29-ba5b-ba8d663cc085',
#                'verified': False},
#               {'_id': 'Entity/pff00',
#                '_key': 'pff00',
#                '_rev': '_emifCae---',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'pff00',
#                'phId': 'pff00',
#                'system': True,
#                'uuid': '38ea99d3-315c-4def-87be-608f1a7db4cf',
#                'verified': False},
#               {'_id': 'Entity/pd184',
#                '_key': 'pd184',
#                '_rev': '_emifKVq---',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'pd184',
#                'phId': 'pd184',
#                'system': True,
#                'uuid': 'c8874fb6-1479-4e5b-af24-002fc3616f15',
#                'verified': False},
#               {'_id': 'Entity/p99bc',
#                '_key': 'p99bc',
#                '_rev': '_emifSQq---',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'p99bc',
#                'phId': 'p99bc',
#                'system': True,
#                'uuid': '37bf7edf-5c80-4ee0-b279-612885803a05',
#                'verified': False},
#               {'_id': 'Entity/p1e35',
#                '_key': 'p1e35',
#                '_rev': '_emifaU----',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'p1e35',
#                'phId': 'p1e35',
#                'system': True,
#                'uuid': '050b7187-1a6e-468c-b51a-2c1f4d5ae62f',
#                'verified': False},
#               {'_id': 'Entity/p344b',
#                '_key': 'p344b',
#                '_rev': '_emifiXm---',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'p344b',
#                'phId': 'p344b',
#                'system': True,
#                'uuid': '6cf65c5b-60c4-4831-b005-1ae6a8bd5ebd',
#                'verified': False},
#               {'_id': 'Entity/p8f11',
#                '_key': 'p8f11',
#                '_rev': '_emifqW2---',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'p8f11',
#                'phId': 'p8f11',
#                'system': True,
#                'uuid': '6c843458-75ec-431f-b05f-baace41b9b40',
#                'verified': False},
#               {'_id': 'Entity/p5191',
#                '_key': 'p5191',
#                '_rev': '_emifyPi---',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'p5191',
#                'phId': 'p5191',
#                'system': True,
#                'uuid': '0db09a8b-41da-4c4d-ba83-2cf20d1fd0ec',
#                'verified': False},
#               {'_id': 'Entity/p7d72',
#                '_key': 'p7d72',
#                '_rev': '_emif7-y---',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'p7d72',
#                'phId': 'p7d72',
#                'system': True,
#                'uuid': '4c6e80f3-3cde-4b4d-9898-42dc113978e6',
#                'verified': False},
#               {'_id': 'Entity/p3604',
#                '_key': 'p3604',
#                '_rev': '_emigByK---',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'p3604',
#                'phId': 'p3604',
#                'system': True,
#                'uuid': '1e8ac239-140a-45ed-925b-048b0840c22e',
#                'verified': False},
#               {'_id': 'Entity/p9c05',
#                '_key': 'p9c05',
#                '_rev': '_emigIrK---',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'p9c05',
#                'phId': 'p9c05',
#                'system': True,
#                'uuid': '38a5a625-3a7d-4b32-be86-db4d45b6e56b',
#                'verified': False}]}

# %%
from knowledge_engine_sdk import *
import pprint
import pandas as pd

class KnowledgeEngineWrapper:
    def __init__(self):
        self.sdk = KnowledgeEngine()

    def get_entity_types(self):
        return self.sdk.get_entity_types()

    def get_entities(self, entity_type_enum):
        query_params = GetEntityListParams(entity_type_enum=entity_type_enum)
        return self.sdk.get_entities(params=query_params)

    def get_entity(self, enum, entity_type_enum):
        # First, we need to find the entity's UUID
        entities = self.get_entities(entity_type_enum)
        entity = next((e for e in entities if e['enum'] == enum), None)
        if not entity:
            raise ValueError(f"No entity found with enum '{enum}' and type '{entity_type_enum}'")
        
        query_params = GetEntityParams(
            uuid=entity['uuid'],
            enum=enum,
            entity_type_enum=entity_type_enum
        )
        return self.sdk.get_entity(params=query_params)

# Usage
ke_wrapper = KnowledgeEngineWrapper()
pp = pprint.PrettyPrinter(indent=1)

# Get list of Entity Types
entity_types = ke_wrapper.get_entity_types()
print("Entity Types:")
pp.pprint(entity_types)

# Get list of entities
data_elements = ke_wrapper.get_entities(EntityTypes.DATA_ELEMENT)
print("\nData Elements (first 2):")
pp.pprint(data_elements[:2])

data_sets = ke_wrapper.get_entities(EntityTypes.DATA_SET)
print("\nData Sets (first 2):")
pp.pprint(data_sets[:2])

# Get a particular entity
try:
    entity = ke_wrapper.get_entity("DATA_ELEMENT_MEDICATION_DOSAGES", EntityTypes.DATA_ELEMENT)
    print("\nSpecific Entity:")
    pp.pprint(entity)

    # Convert to DataFrame
    df = pd.DataFrame.from_dict(entity, orient='index')
    print("\nEntity as DataFrame:")
    print(df)
except ValueError as e:
    print(f"Error: {e}")
# Out:
# Entity Types:
# ['DATA_SET', 'DATA_TYPE', 'DATA_ELEMENT', 'PH_ID']
#
# Data Elements (first 2):
# [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_rev': '_emidfZW---',
#   'basicEnum': 'METABOLOMICS_CORRECTED',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#   'creatorType': 'USER',
#   'entityType': 'DATA_ELEMENT',
#   'enum': 'DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   'name': 'metabolomics_corrected.csv',
#   'system': True,
#   'uuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'verified': False},
#  {'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_SALIVA',
#   '_key': 'DATA_ELEMENT.DATA_ELEMENT_SALIVA',
#   '_rev': '_emigPha---',
#   'basicEnum': 'SALIVA',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#   'creatorType': 'USER',
#   'entityType': 'DATA_ELEMENT',
#   'enum': 'DATA_ELEMENT_SALIVA',
#   'name': 'saliva.csv',
#   'system': True,
#   'uuid': 'b7ba781f-f903-4c99-bca2-64b36811e06a',
#   'verified': False}]
#
# Data Sets (first 2):
# [{'_id': 'Entity/DATA_SET.DATA_SET_SCIENTIFIC_WELLNESS_COHORT',
#   '_key': 'DATA_SET.DATA_SET_SCIENTIFIC_WELLNESS_COHORT',
#   '_rev': '_emidfWW---',
#   'basicEnum': 'SCIENTIFIC_WELLNESS_COHORT',
#   'candidateId': '4689f863-3977-4f4f-bcca-965d9136cbcb',
#   'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#   'creatorType': 'USER',
#   'entityType': 'DATA_SET',
#   'enum': 'DATA_SET_SCIENTIFIC_WELLNESS_COHORT',
#   'name': 'Scientific Wellness Cohort',
#   'system': True,
#   'uuid': '5308b32a-4e51-489f-8adb-7c842152d161',
#   'verified': True}]
#
# Specific Entity:
# {'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#  '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#  '_rev': '_emigRCG---',
#  'basicEnum': 'MEDICATION_DOSAGES',
#  'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#  'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#  'creatorType': 'USER',
#  'entityType': 'DATA_ELEMENT',
#  'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#  'name': 'medication_dosages.csv',
#  'system': True,
#  'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#  'verified': False}
#
# Entity as DataFrame:
#                                                              0
# _key              DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES
# _id          Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DO...
# _rev                                               _emigRCG---
# uuid                      5afd2304-f739-4f06-b1f8-61ddda331ff6
# name                                    medication_dosages.csv
# enum                           DATA_ELEMENT_MEDICATION_DOSAGES
# basicEnum                                   MEDICATION_DOSAGES
# system                                                    True
# creator                   29abf4b0-8d11-4eed-81d1-9ec501cc2ee7
# creatorType                                               USER
# entityType                                        DATA_ELEMENT
# candidateId               576d7aba-6cf0-4f27-8a19-aa01b38a5ef2
# verified                                                 False

# %%
# Connections

# Get list of connection types
connection_types = sdk.get_connection_types()
# pp.pprint(connection_types)

# Get list of connections for an entity
query_params = GetConnectionListParams(
    connection_type_name = "contains",
    entity_uuid = entity["uuid"],
    direction = "out"
)

connections = sdk.get_connections(params=query_params)
# pp.pprint(connections)

# Get a particular connection between 2 entities
query_params = GetConnectionParams(
    from_entity_uuid = data_sets[0]["uuid"],
    to_entity_uuid = data_elements[0]["uuid"]
)

connection = sdk.get_connection(params=query_params)
pp.pprint(connection)


pd.DataFrame.from_dict(connections).transpose()
# Out:
# [{'_from': 'Entity/DATA_SET.DATA_SET_SCIENTIFIC_WELLNESS_COHORT',
#   '_id': 'contains/DATA_SET.DATA_SET_SCIENTIFIC_WELLNESS_COHORT.DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_key': 'DATA_SET.DATA_SET_SCIENTIFIC_WELLNESS_COHORT.DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   '_rev': '_emidfaC---',
#   '_to': 'Entity/DATA_ELEMENT.DATA_ELEMENT_METABOLOMICS_CORRECTED',
#   'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#   'fromUuid': '5308b32a-4e51-489f-8adb-7c842152d161',
#   'toUuid': '53812404-886e-4cd2-8e14-395a0fe8fb6c',
#   'verified': False}]
#                                                             0   \
# _key         DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.D...
# _id          contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_...
# _from        Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DO...
# _to                   Entity/DATA_TYPE.DATA_TYPE_MEDICATION_ID
# _rev                                               _emigRDy---
# fromUuid                  5afd2304-f739-4f06-b1f8-61ddda331ff6
# toUuid                    d7192137-a103-457e-9075-39770e53de33
# candidateId               576d7aba-6cf0-4f27-8a19-aa01b38a5ef2
# verified                                                 False
#
#                                                             1   \
# _key         DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.D...
# _id          contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_...
# _from        Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DO...
# _to                            Entity/DATA_TYPE.DATA_TYPE_NAME
# _rev                                               _emigREq---
# fromUuid                  5afd2304-f739-4f06-b1f8-61ddda331ff6
# toUuid                    f2b0f9a7-c0cc-4830-8fe9-20ec9adcf89f
# candidateId               576d7aba-6cf0-4f27-8a19-aa01b38a5ef2
# verified                                                 False
#
#                                                             2   \
# _key         DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.D...
# _id          contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_...
# _from        Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DO...
# _to                          Entity/DATA_TYPE.DATA_TYPE_AMOUNT
# _rev                                               _emigRFi---
# fromUuid                  5afd2304-f739-4f06-b1f8-61ddda331ff6
# toUuid                    d9c1ade2-7f06-4fb8-9841-9084710f6474
# candidateId               576d7aba-6cf0-4f27-8a19-aa01b38a5ef2
# verified                                                 False
#
#                                                             3   \
# _key         DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.D...
# _id          contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_...
# _from        Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DO...
# _to                            Entity/DATA_TYPE.DATA_TYPE_UNIT
# _rev                                               _emigRGa---
# fromUuid                  5afd2304-f739-4f06-b1f8-61ddda331ff6
# toUuid                    c5bf4059-1034-4af1-b0e2-6f55fbca8a70
# candidateId               576d7aba-6cf0-4f27-8a19-aa01b38a5ef2
# verified                                                 False
#
#                                                             4   \
# _key         DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.P...
# _id          contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_...
# _from        Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DO...
# _to                                               Entity/p1c5b
# _rev                                               _emigRHG---
# fromUuid                  5afd2304-f739-4f06-b1f8-61ddda331ff6
# toUuid                    39f8794a-2bf9-4581-aac3-232e0716a187
# candidateId               576d7aba-6cf0-4f27-8a19-aa01b38a5ef2
# verified                                                 False
#
#                                                             5   \
# _key         DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.P...
# _id          contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_...
# _from        Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DO...
# _to                                               Entity/p6da5
# _rev                                               _emigRJO---
# fromUuid                  5afd2304-f739-4f06-b1f8-61ddda331ff6
# toUuid                    f90d3397-b1c0-4a3c-9834-595cc472a286
# candidateId               576d7aba-6cf0-4f27-8a19-aa01b38a5ef2
# verified                                                 False
#
#                                                             6   \
# _key         DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.P...
# _id          contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_...
# _from        Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DO...
# _to                                               Entity/p841a
# _rev                                               _emigRLa---
# fromUuid                  5afd2304-f739-4f06-b1f8-61ddda331ff6
# toUuid                    c87d5c44-c761-4cbc-ab22-120514aec384
# candidateId               576d7aba-6cf0-4f27-8a19-aa01b38a5ef2
# verified                                                 False
#
#                                                             7   \
# _key         DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.P...
# _id          contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_...
# _from        Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DO...
# _to                                               Entity/p883f
# _rev                                               _emigRNu---
# fromUuid                  5afd2304-f739-4f06-b1f8-61ddda331ff6
# toUuid                    674e9d1c-f541-40ee-9868-c7aad5e5ffbd
# candidateId               576d7aba-6cf0-4f27-8a19-aa01b38a5ef2
# verified                                                 False
#
#                                                             8   \
# _key         DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.P...
# _id          contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_...
# _from        Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DO...
# _to                                               Entity/pb742
# _rev                                               _emigRP6---
# fromUuid                  5afd2304-f739-4f06-b1f8-61ddda331ff6
# toUuid                    1620fa3a-579b-4f3b-a361-9cc412212fdc
# candidateId               576d7aba-6cf0-4f27-8a19-aa01b38a5ef2
# verified                                                 False
#
#                                                             9   ...  \
# _key         DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.P...  ...
# _id          contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_...  ...
# _from        Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DO...  ...
# _to                                               Entity/p8051  ...
# _rev                                               _emigRSG---  ...
# fromUuid                  5afd2304-f739-4f06-b1f8-61ddda331ff6  ...
# toUuid                    d154153f-100f-4614-9953-389f5e40b5f4  ...
# candidateId               576d7aba-6cf0-4f27-8a19-aa01b38a5ef2  ...
# verified                                                 False  ...
#
#                                                             14  \
# _key         DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.P...
# _id          contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_...
# _from        Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DO...
# _to                                               Entity/pff00
# _rev                                               _emigRcm---
# fromUuid                  5afd2304-f739-4f06-b1f8-61ddda331ff6
# toUuid                    38ea99d3-315c-4def-87be-608f1a7db4cf
# candidateId               576d7aba-6cf0-4f27-8a19-aa01b38a5ef2
# verified                                                 False
#
#                                                             15  \
# _key         DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.P...
# _id          contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_...
# _from        Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DO...
# _to                                               Entity/pd184
# _rev                                               _emigRey---
# fromUuid                  5afd2304-f739-4f06-b1f8-61ddda331ff6
# toUuid                    c8874fb6-1479-4e5b-af24-002fc3616f15
# candidateId               576d7aba-6cf0-4f27-8a19-aa01b38a5ef2
# verified                                                 False
#
#                                                             16  \
# _key         DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.P...
# _id          contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_...
# _from        Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DO...
# _to                                               Entity/p99bc
# _rev                                               _emigRg6---
# fromUuid                  5afd2304-f739-4f06-b1f8-61ddda331ff6
# toUuid                    37bf7edf-5c80-4ee0-b279-612885803a05
# candidateId               576d7aba-6cf0-4f27-8a19-aa01b38a5ef2
# verified                                                 False
#
#                                                             17  \
# _key         DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.P...
# _id          contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_...
# _from        Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DO...
# _to                                               Entity/p1e35
# _rev                                               _emigRjG---
# fromUuid                  5afd2304-f739-4f06-b1f8-61ddda331ff6
# toUuid                    050b7187-1a6e-468c-b51a-2c1f4d5ae62f
# candidateId               576d7aba-6cf0-4f27-8a19-aa01b38a5ef2
# verified                                                 False
#
#                                                             18  \
# _key         DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.P...
# _id          contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_...
# _from        Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DO...
# _to                                               Entity/p344b
# _rev                                               _emigRlW---
# fromUuid                  5afd2304-f739-4f06-b1f8-61ddda331ff6
# toUuid                    6cf65c5b-60c4-4831-b005-1ae6a8bd5ebd
# candidateId               576d7aba-6cf0-4f27-8a19-aa01b38a5ef2
# verified                                                 False
#
#                                                             19  \
# _key         DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.P...
# _id          contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_...
# _from        Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DO...
# _to                                               Entity/p8f11
# _rev                                               _emigRne---
# fromUuid                  5afd2304-f739-4f06-b1f8-61ddda331ff6
# toUuid                    6c843458-75ec-431f-b05f-baace41b9b40
# candidateId               576d7aba-6cf0-4f27-8a19-aa01b38a5ef2
# verified                                                 False
#
#                                                             20  \
# _key         DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.P...
# _id          contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_...
# _from        Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DO...
# _to                                               Entity/p5191
# _rev                                               _emigRpm---
# fromUuid                  5afd2304-f739-4f06-b1f8-61ddda331ff6
# toUuid                    0db09a8b-41da-4c4d-ba83-2cf20d1fd0ec
# candidateId               576d7aba-6cf0-4f27-8a19-aa01b38a5ef2
# verified                                                 False
#
#                                                             21  \
# _key         DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.P...
# _id          contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_...
# _from        Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DO...
# _to                                               Entity/p7d72
# _rev                                               _emigRri---
# fromUuid                  5afd2304-f739-4f06-b1f8-61ddda331ff6
# toUuid                    4c6e80f3-3cde-4b4d-9898-42dc113978e6
# candidateId               576d7aba-6cf0-4f27-8a19-aa01b38a5ef2
# verified                                                 False
#
#                                                             22  \
# _key         DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.P...
# _id          contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_...
# _from        Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DO...
# _to                                               Entity/p3604
# _rev                                               _emigRtu---
# fromUuid                  5afd2304-f739-4f06-b1f8-61ddda331ff6
# toUuid                    1e8ac239-140a-45ed-925b-048b0840c22e
# candidateId               576d7aba-6cf0-4f27-8a19-aa01b38a5ef2
# verified                                                 False
#
#                                                             23
# _key         DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.P...
# _id          contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_...
# _from        Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DO...
# _to                                               Entity/p9c05
# _rev                                               _emigRvy---
# fromUuid                  5afd2304-f739-4f06-b1f8-61ddda331ff6
# toUuid                    38a5a625-3a7d-4b32-be86-db4d45b6e56b
# candidateId               576d7aba-6cf0-4f27-8a19-aa01b38a5ef2
# verified                                                 False
#
# [9 rows x 24 columns]

# %%
from knowledge_engine_sdk.models import TraverseParams, ConnectionDirection, TraverseAlgorithm

# First, let's print out the available options for ConnectionDirection
print("Available ConnectionDirection options:")
for direction in ConnectionDirection:
    print(f"- {direction.name}: {direction.value}")

# Now, let's create the TraverseParams object
query_params = TraverseParams(
    start_entity_uuid=entity["uuid"],
    direction=ConnectionDirection.OUTBOUND,  # We're assuming OUTBOUND is the correct value
    max_depth=1,
    min_depth=0,
    algorithm=TraverseAlgorithm.DEPTH
)

traversal = sdk.traverse_graph(params=query_params)
pp.pprint(traversal)
# Out:
# Available ConnectionDirection options:
# - INBOUND: in
# - OUTBOUND: out
# {'paths': [{'edges': [],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.DATA_TYPE.DATA_TYPE_MEDICATION_ID',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.DATA_TYPE.DATA_TYPE_MEDICATION_ID',
#                        '_rev': '_emigRDy---',
#                        '_to': 'Entity/DATA_TYPE.DATA_TYPE_MEDICATION_ID',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': 'd7192137-a103-457e-9075-39770e53de33',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/DATA_TYPE.DATA_TYPE_MEDICATION_ID',
#                           '_key': 'DATA_TYPE.DATA_TYPE_MEDICATION_ID',
#                           '_rev': '_emigRDS---',
#                           'basicEnum': 'MEDICATION_ID',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_TYPE',
#                           'enum': 'DATA_TYPE_MEDICATION_ID',
#                           'name': 'medication_id',
#                           'system': True,
#                           'uuid': 'd7192137-a103-457e-9075-39770e53de33',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.DATA_TYPE.DATA_TYPE_NAME',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.DATA_TYPE.DATA_TYPE_NAME',
#                        '_rev': '_emigREq---',
#                        '_to': 'Entity/DATA_TYPE.DATA_TYPE_NAME',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': 'f2b0f9a7-c0cc-4830-8fe9-20ec9adcf89f',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/DATA_TYPE.DATA_TYPE_NAME',
#                           '_key': 'DATA_TYPE.DATA_TYPE_NAME',
#                           '_rev': '_emigREK---',
#                           'basicEnum': 'NAME',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_TYPE',
#                           'enum': 'DATA_TYPE_NAME',
#                           'name': 'name',
#                           'system': True,
#                           'uuid': 'f2b0f9a7-c0cc-4830-8fe9-20ec9adcf89f',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.DATA_TYPE.DATA_TYPE_AMOUNT',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.DATA_TYPE.DATA_TYPE_AMOUNT',
#                        '_rev': '_emigRFi---',
#                        '_to': 'Entity/DATA_TYPE.DATA_TYPE_AMOUNT',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': 'd9c1ade2-7f06-4fb8-9841-9084710f6474',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/DATA_TYPE.DATA_TYPE_AMOUNT',
#                           '_key': 'DATA_TYPE.DATA_TYPE_AMOUNT',
#                           '_rev': '_emigRFC---',
#                           'basicEnum': 'AMOUNT',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_TYPE',
#                           'enum': 'DATA_TYPE_AMOUNT',
#                           'name': 'amount',
#                           'system': True,
#                           'uuid': 'd9c1ade2-7f06-4fb8-9841-9084710f6474',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.DATA_TYPE.DATA_TYPE_UNIT',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.DATA_TYPE.DATA_TYPE_UNIT',
#                        '_rev': '_emigRGa---',
#                        '_to': 'Entity/DATA_TYPE.DATA_TYPE_UNIT',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': 'c5bf4059-1034-4af1-b0e2-6f55fbca8a70',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/DATA_TYPE.DATA_TYPE_UNIT',
#                           '_key': 'DATA_TYPE.DATA_TYPE_UNIT',
#                           '_rev': '_emigRF6---',
#                           'basicEnum': 'UNIT',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_TYPE',
#                           'enum': 'DATA_TYPE_UNIT',
#                           'name': 'unit',
#                           'system': True,
#                           'uuid': 'c5bf4059-1034-4af1-b0e2-6f55fbca8a70',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p1c5b',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p1c5b',
#                        '_rev': '_emigRHG---',
#                        '_to': 'Entity/p1c5b',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': '39f8794a-2bf9-4581-aac3-232e0716a187',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/p1c5b',
#                           '_key': 'p1c5b',
#                           '_rev': '_emidzxq---',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'PH_ID',
#                           'name': 'p1c5b',
#                           'phId': 'p1c5b',
#                           'system': True,
#                           'uuid': '39f8794a-2bf9-4581-aac3-232e0716a187',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p6da5',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p6da5',
#                        '_rev': '_emigRJO---',
#                        '_to': 'Entity/p6da5',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': 'f90d3397-b1c0-4a3c-9834-595cc472a286',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/p6da5',
#                           '_key': 'p6da5',
#                           '_rev': '_emid76----',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'PH_ID',
#                           'name': 'p6da5',
#                           'phId': 'p6da5',
#                           'system': True,
#                           'uuid': 'f90d3397-b1c0-4a3c-9834-595cc472a286',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p841a',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p841a',
#                        '_rev': '_emigRLa---',
#                        '_to': 'Entity/p841a',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': 'c87d5c44-c761-4cbc-ab22-120514aec384',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/p841a',
#                           '_key': 'p841a',
#                           '_rev': '_emieDxW---',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'PH_ID',
#                           'name': 'p841a',
#                           'phId': 'p841a',
#                           'system': True,
#                           'uuid': 'c87d5c44-c761-4cbc-ab22-120514aec384',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p883f',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p883f',
#                        '_rev': '_emigRNu---',
#                        '_to': 'Entity/p883f',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': '674e9d1c-f541-40ee-9868-c7aad5e5ffbd',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/p883f',
#                           '_key': 'p883f',
#                           '_rev': '_emieLgy---',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'PH_ID',
#                           'name': 'p883f',
#                           'phId': 'p883f',
#                           'system': True,
#                           'uuid': '674e9d1c-f541-40ee-9868-c7aad5e5ffbd',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.pb742',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.pb742',
#                        '_rev': '_emigRP6---',
#                        '_to': 'Entity/pb742',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': '1620fa3a-579b-4f3b-a361-9cc412212fdc',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/pb742',
#                           '_key': 'pb742',
#                           '_rev': '_emieTUK---',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'PH_ID',
#                           'name': 'pb742',
#                           'phId': 'pb742',
#                           'system': True,
#                           'uuid': '1620fa3a-579b-4f3b-a361-9cc412212fdc',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p8051',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p8051',
#                        '_rev': '_emigRSG---',
#                        '_to': 'Entity/p8051',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': 'd154153f-100f-4614-9953-389f5e40b5f4',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/p8051',
#                           '_key': 'p8051',
#                           '_rev': '_emiebJK---',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'PH_ID',
#                           'name': 'p8051',
#                           'phId': 'p8051',
#                           'system': True,
#                           'uuid': 'd154153f-100f-4614-9953-389f5e40b5f4',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.pe419',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.pe419',
#                        '_rev': '_emigRUO---',
#                        '_to': 'Entity/pe419',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': '60c48be0-7f8f-409c-8630-c27959269739',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/pe419',
#                           '_key': 'pe419',
#                           '_rev': '_emiei8e---',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'PH_ID',
#                           'name': 'pe419',
#                           'phId': 'pe419',
#                           'system': True,
#                           'uuid': '60c48be0-7f8f-409c-8630-c27959269739',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p665c',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p665c',
#                        '_rev': '_emigRWS---',
#                        '_to': 'Entity/p665c',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': 'f97261ae-f58c-4f27-b2fe-1637b77e67e2',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/p665c',
#                           '_key': 'p665c',
#                           '_rev': '_emieq2----',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'PH_ID',
#                           'name': 'p665c',
#                           'phId': 'p665c',
#                           'system': True,
#                           'uuid': 'f97261ae-f58c-4f27-b2fe-1637b77e67e2',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p39d9',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p39d9',
#                        '_rev': '_emigRYa---',
#                        '_to': 'Entity/p39d9',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': '45ea140a-738a-41fe-9a7d-6e88bf4422ef',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/p39d9',
#                           '_key': 'p39d9',
#                           '_rev': '_emiey1----',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'PH_ID',
#                           'name': 'p39d9',
#                           'phId': 'p39d9',
#                           'system': True,
#                           'uuid': '45ea140a-738a-41fe-9a7d-6e88bf4422ef',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.pede5',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.pede5',
#                        '_rev': '_emigRai---',
#                        '_to': 'Entity/pede5',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': 'bd1e7f8f-1f7f-4e29-ba5b-ba8d663cc085',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/pede5',
#                           '_key': 'pede5',
#                           '_rev': '_emie6ly---',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'PH_ID',
#                           'name': 'pede5',
#                           'phId': 'pede5',
#                           'system': True,
#                           'uuid': 'bd1e7f8f-1f7f-4e29-ba5b-ba8d663cc085',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.pff00',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.pff00',
#                        '_rev': '_emigRcm---',
#                        '_to': 'Entity/pff00',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': '38ea99d3-315c-4def-87be-608f1a7db4cf',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/pff00',
#                           '_key': 'pff00',
#                           '_rev': '_emifCae---',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'PH_ID',
#                           'name': 'pff00',
#                           'phId': 'pff00',
#                           'system': True,
#                           'uuid': '38ea99d3-315c-4def-87be-608f1a7db4cf',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.pd184',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.pd184',
#                        '_rev': '_emigRey---',
#                        '_to': 'Entity/pd184',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': 'c8874fb6-1479-4e5b-af24-002fc3616f15',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/pd184',
#                           '_key': 'pd184',
#                           '_rev': '_emifKVq---',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'PH_ID',
#                           'name': 'pd184',
#                           'phId': 'pd184',
#                           'system': True,
#                           'uuid': 'c8874fb6-1479-4e5b-af24-002fc3616f15',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p99bc',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p99bc',
#                        '_rev': '_emigRg6---',
#                        '_to': 'Entity/p99bc',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': '37bf7edf-5c80-4ee0-b279-612885803a05',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/p99bc',
#                           '_key': 'p99bc',
#                           '_rev': '_emifSQq---',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'PH_ID',
#                           'name': 'p99bc',
#                           'phId': 'p99bc',
#                           'system': True,
#                           'uuid': '37bf7edf-5c80-4ee0-b279-612885803a05',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p1e35',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p1e35',
#                        '_rev': '_emigRjG---',
#                        '_to': 'Entity/p1e35',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': '050b7187-1a6e-468c-b51a-2c1f4d5ae62f',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/p1e35',
#                           '_key': 'p1e35',
#                           '_rev': '_emifaU----',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'PH_ID',
#                           'name': 'p1e35',
#                           'phId': 'p1e35',
#                           'system': True,
#                           'uuid': '050b7187-1a6e-468c-b51a-2c1f4d5ae62f',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p344b',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p344b',
#                        '_rev': '_emigRlW---',
#                        '_to': 'Entity/p344b',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': '6cf65c5b-60c4-4831-b005-1ae6a8bd5ebd',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/p344b',
#                           '_key': 'p344b',
#                           '_rev': '_emifiXm---',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'PH_ID',
#                           'name': 'p344b',
#                           'phId': 'p344b',
#                           'system': True,
#                           'uuid': '6cf65c5b-60c4-4831-b005-1ae6a8bd5ebd',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p8f11',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p8f11',
#                        '_rev': '_emigRne---',
#                        '_to': 'Entity/p8f11',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': '6c843458-75ec-431f-b05f-baace41b9b40',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/p8f11',
#                           '_key': 'p8f11',
#                           '_rev': '_emifqW2---',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'PH_ID',
#                           'name': 'p8f11',
#                           'phId': 'p8f11',
#                           'system': True,
#                           'uuid': '6c843458-75ec-431f-b05f-baace41b9b40',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p5191',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p5191',
#                        '_rev': '_emigRpm---',
#                        '_to': 'Entity/p5191',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': '0db09a8b-41da-4c4d-ba83-2cf20d1fd0ec',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/p5191',
#                           '_key': 'p5191',
#                           '_rev': '_emifyPi---',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'PH_ID',
#                           'name': 'p5191',
#                           'phId': 'p5191',
#                           'system': True,
#                           'uuid': '0db09a8b-41da-4c4d-ba83-2cf20d1fd0ec',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p7d72',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p7d72',
#                        '_rev': '_emigRri---',
#                        '_to': 'Entity/p7d72',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': '4c6e80f3-3cde-4b4d-9898-42dc113978e6',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/p7d72',
#                           '_key': 'p7d72',
#                           '_rev': '_emif7-y---',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'PH_ID',
# ...
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'PH_ID',
#                           'name': 'p3604',
#                           'phId': 'p3604',
#                           'system': True,
#                           'uuid': '1e8ac239-140a-45ed-925b-048b0840c22e',
#                           'verified': False}]},
#            {'edges': [{'_from': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                        '_id': 'contains/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p9c05',
#                        '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES.PH_ID.p9c05',
#                        '_rev': '_emigRvy---',
#                        '_to': 'Entity/p9c05',
#                        'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                        'fromUuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                        'toUuid': '38a5a625-3a7d-4b32-be86-db4d45b6e56b',
#                        'verified': False}],
#             'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                           '_rev': '_emigRCG---',
#                           'basicEnum': 'MEDICATION_DOSAGES',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'DATA_ELEMENT',
#                           'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                           'name': 'medication_dosages.csv',
#                           'system': True,
#                           'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                           'verified': False},
#                          {'_id': 'Entity/p9c05',
#                           '_key': 'p9c05',
#                           '_rev': '_emigIrK---',
#                           'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                           'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                           'creatorType': 'USER',
#                           'entityType': 'PH_ID',
#                           'name': 'p9c05',
#                           'phId': 'p9c05',
#                           'system': True,
#                           'uuid': '38a5a625-3a7d-4b32-be86-db4d45b6e56b',
#                           'verified': False}]}],
#  'vertices': [{'_id': 'Entity/DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                '_key': 'DATA_ELEMENT.DATA_ELEMENT_MEDICATION_DOSAGES',
#                '_rev': '_emigRCG---',
#                'basicEnum': 'MEDICATION_DOSAGES',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'DATA_ELEMENT',
#                'enum': 'DATA_ELEMENT_MEDICATION_DOSAGES',
#                'name': 'medication_dosages.csv',
#                'system': True,
#                'uuid': '5afd2304-f739-4f06-b1f8-61ddda331ff6',
#                'verified': False},
#               {'_id': 'Entity/DATA_TYPE.DATA_TYPE_MEDICATION_ID',
#                '_key': 'DATA_TYPE.DATA_TYPE_MEDICATION_ID',
#                '_rev': '_emigRDS---',
#                'basicEnum': 'MEDICATION_ID',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'DATA_TYPE',
#                'enum': 'DATA_TYPE_MEDICATION_ID',
#                'name': 'medication_id',
#                'system': True,
#                'uuid': 'd7192137-a103-457e-9075-39770e53de33',
#                'verified': False},
#               {'_id': 'Entity/DATA_TYPE.DATA_TYPE_NAME',
#                '_key': 'DATA_TYPE.DATA_TYPE_NAME',
#                '_rev': '_emigREK---',
#                'basicEnum': 'NAME',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'DATA_TYPE',
#                'enum': 'DATA_TYPE_NAME',
#                'name': 'name',
#                'system': True,
#                'uuid': 'f2b0f9a7-c0cc-4830-8fe9-20ec9adcf89f',
#                'verified': False},
#               {'_id': 'Entity/DATA_TYPE.DATA_TYPE_AMOUNT',
#                '_key': 'DATA_TYPE.DATA_TYPE_AMOUNT',
#                '_rev': '_emigRFC---',
#                'basicEnum': 'AMOUNT',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'DATA_TYPE',
#                'enum': 'DATA_TYPE_AMOUNT',
#                'name': 'amount',
#                'system': True,
#                'uuid': 'd9c1ade2-7f06-4fb8-9841-9084710f6474',
#                'verified': False},
#               {'_id': 'Entity/DATA_TYPE.DATA_TYPE_UNIT',
#                '_key': 'DATA_TYPE.DATA_TYPE_UNIT',
#                '_rev': '_emigRF6---',
#                'basicEnum': 'UNIT',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'DATA_TYPE',
#                'enum': 'DATA_TYPE_UNIT',
#                'name': 'unit',
#                'system': True,
#                'uuid': 'c5bf4059-1034-4af1-b0e2-6f55fbca8a70',
#                'verified': False},
#               {'_id': 'Entity/p1c5b',
#                '_key': 'p1c5b',
#                '_rev': '_emidzxq---',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'p1c5b',
#                'phId': 'p1c5b',
#                'system': True,
#                'uuid': '39f8794a-2bf9-4581-aac3-232e0716a187',
#                'verified': False},
#               {'_id': 'Entity/p6da5',
#                '_key': 'p6da5',
#                '_rev': '_emid76----',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'p6da5',
#                'phId': 'p6da5',
#                'system': True,
#                'uuid': 'f90d3397-b1c0-4a3c-9834-595cc472a286',
#                'verified': False},
#               {'_id': 'Entity/p841a',
#                '_key': 'p841a',
#                '_rev': '_emieDxW---',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'p841a',
#                'phId': 'p841a',
#                'system': True,
#                'uuid': 'c87d5c44-c761-4cbc-ab22-120514aec384',
#                'verified': False},
#               {'_id': 'Entity/p883f',
#                '_key': 'p883f',
#                '_rev': '_emieLgy---',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'p883f',
#                'phId': 'p883f',
#                'system': True,
#                'uuid': '674e9d1c-f541-40ee-9868-c7aad5e5ffbd',
#                'verified': False},
#               {'_id': 'Entity/pb742',
#                '_key': 'pb742',
#                '_rev': '_emieTUK---',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'pb742',
#                'phId': 'pb742',
#                'system': True,
#                'uuid': '1620fa3a-579b-4f3b-a361-9cc412212fdc',
#                'verified': False},
#               {'_id': 'Entity/p8051',
#                '_key': 'p8051',
#                '_rev': '_emiebJK---',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'p8051',
#                'phId': 'p8051',
#                'system': True,
#                'uuid': 'd154153f-100f-4614-9953-389f5e40b5f4',
#                'verified': False},
#               {'_id': 'Entity/pe419',
#                '_key': 'pe419',
#                '_rev': '_emiei8e---',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'pe419',
#                'phId': 'pe419',
#                'system': True,
#                'uuid': '60c48be0-7f8f-409c-8630-c27959269739',
#                'verified': False},
#               {'_id': 'Entity/p665c',
#                '_key': 'p665c',
#                '_rev': '_emieq2----',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'p665c',
#                'phId': 'p665c',
#                'system': True,
#                'uuid': 'f97261ae-f58c-4f27-b2fe-1637b77e67e2',
#                'verified': False},
#               {'_id': 'Entity/p39d9',
#                '_key': 'p39d9',
#                '_rev': '_emiey1----',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'p39d9',
#                'phId': 'p39d9',
#                'system': True,
#                'uuid': '45ea140a-738a-41fe-9a7d-6e88bf4422ef',
#                'verified': False},
#               {'_id': 'Entity/pede5',
#                '_key': 'pede5',
#                '_rev': '_emie6ly---',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'pede5',
#                'phId': 'pede5',
#                'system': True,
#                'uuid': 'bd1e7f8f-1f7f-4e29-ba5b-ba8d663cc085',
#                'verified': False},
#               {'_id': 'Entity/pff00',
#                '_key': 'pff00',
#                '_rev': '_emifCae---',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'pff00',
#                'phId': 'pff00',
#                'system': True,
#                'uuid': '38ea99d3-315c-4def-87be-608f1a7db4cf',
#                'verified': False},
#               {'_id': 'Entity/pd184',
#                '_key': 'pd184',
#                '_rev': '_emifKVq---',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'pd184',
#                'phId': 'pd184',
#                'system': True,
#                'uuid': 'c8874fb6-1479-4e5b-af24-002fc3616f15',
#                'verified': False},
#               {'_id': 'Entity/p99bc',
#                '_key': 'p99bc',
#                '_rev': '_emifSQq---',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'p99bc',
#                'phId': 'p99bc',
#                'system': True,
#                'uuid': '37bf7edf-5c80-4ee0-b279-612885803a05',
#                'verified': False},
#               {'_id': 'Entity/p1e35',
#                '_key': 'p1e35',
#                '_rev': '_emifaU----',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'p1e35',
#                'phId': 'p1e35',
#                'system': True,
#                'uuid': '050b7187-1a6e-468c-b51a-2c1f4d5ae62f',
#                'verified': False},
#               {'_id': 'Entity/p344b',
#                '_key': 'p344b',
#                '_rev': '_emifiXm---',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'p344b',
#                'phId': 'p344b',
#                'system': True,
#                'uuid': '6cf65c5b-60c4-4831-b005-1ae6a8bd5ebd',
#                'verified': False},
#               {'_id': 'Entity/p8f11',
#                '_key': 'p8f11',
#                '_rev': '_emifqW2---',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'p8f11',
#                'phId': 'p8f11',
#                'system': True,
#                'uuid': '6c843458-75ec-431f-b05f-baace41b9b40',
#                'verified': False},
#               {'_id': 'Entity/p5191',
#                '_key': 'p5191',
#                '_rev': '_emifyPi---',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'p5191',
#                'phId': 'p5191',
#                'system': True,
#                'uuid': '0db09a8b-41da-4c4d-ba83-2cf20d1fd0ec',
#                'verified': False},
#               {'_id': 'Entity/p7d72',
#                '_key': 'p7d72',
#                '_rev': '_emif7-y---',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'p7d72',
#                'phId': 'p7d72',
#                'system': True,
#                'uuid': '4c6e80f3-3cde-4b4d-9898-42dc113978e6',
#                'verified': False},
#               {'_id': 'Entity/p3604',
#                '_key': 'p3604',
#                '_rev': '_emigByK---',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'p3604',
#                'phId': 'p3604',
#                'system': True,
#                'uuid': '1e8ac239-140a-45ed-925b-048b0840c22e',
#                'verified': False},
#               {'_id': 'Entity/p9c05',
#                '_key': 'p9c05',
#                '_rev': '_emigIrK---',
#                'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#                'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#                'creatorType': 'USER',
#                'entityType': 'PH_ID',
#                'name': 'p9c05',
#                'phId': 'p9c05',
#                'system': True,
#                'uuid': '38a5a625-3a7d-4b32-be86-db4d45b6e56b',
#                'verified': False}]}

# %%
from knowledge_engine_sdk.models import GetEntityParams, EntityTypes, CreateEntity, CreateConnection, GetConnectionParams, DeleteConnection, DeleteEntity

# Get entity
query_params = GetEntityParams(
    enum="MET_O95544",
    entity_type_enum=EntityTypes.DATA_TYPE,
    uuid=None  # Add this line to provide a value for the required uuid field
)

entity = sdk.get_entity(params=query_params)
pp.pprint(entity)

# Create new entity
new_data = CreateEntity(
    name="NAD",
    isSystem=True,
    entityType=EntityTypes.DATA_TYPE,
    candidateId="184e1f33-4b1b-47b6-9f5d-f7f6ef9d1fb5",
    payload={
        "type": "protein",
        "class": "kinase",
        "ec_number": "2.7.1.23",
        "pathway": "O95544"
    }
)

new_entity = sdk.create_entity(data=new_data)
pp.pprint(new_entity)

# Create new connection
new_connection_data = CreateConnection(
    fromUuid=entity["uuid"],
    toUuid=new_entity["uuid"],
    connectionType="contains",
    candidateId="184e1f33-4b1b-47b6-9f5d-f7f6ef9d1fb5",
    payload={
        "my_data": "here is the data"
    }
)

sdk.create_connection(data=new_connection_data)

# Get new connection
get_connection_params = GetConnectionParams(
    from_entity_uuid=entity["uuid"],
    to_entity_uuid=new_entity["uuid"]
)
new_connection = sdk.get_connection(params=get_connection_params)
pp.pprint(new_connection)

# Delete connection (commented out)
# delete_connection_data = DeleteConnection(
#     fromUuid=entity["uuid"],
#     toUuid=new_entity["uuid"],
#     connectionType="contains"
# )
# sdk.delete_connection(data=delete_connection_data)

# Delete entity (commented out)
# delete_entity_data = DeleteEntity(uuid=new_entity["uuid"])
# sdk.delete_entity(data=delete_entity_data)

# Get the newly created entity
get_new_entity_params = GetEntityParams(
    enum="NAD",
    entity_type_enum=EntityTypes.DATA_TYPE,
    uuid=None  # Add this line to provide a value for the required uuid field
)

new_entity_retrieved = sdk.get_entity(params=get_new_entity_params)
pp.pprint(new_entity_retrieved)
# Out:
# {'_id': 'Entity/DATA_TYPE.DATA_TYPE_MET_O95544',
#  '_key': 'DATA_TYPE.DATA_TYPE_MET_O95544',
#  '_rev': '_emigb4i---',
#  'basicEnum': 'MET_O95544',
#  'candidateId': '576d7aba-6cf0-4f27-8a19-aa01b38a5ef2',
#  'creator': '29abf4b0-8d11-4eed-81d1-9ec501cc2ee7',
#  'creatorType': 'USER',
#  'entityType': 'DATA_TYPE',
#  'enum': 'DATA_TYPE_MET_O95544',
#  'name': 'MET_O95544',
#  'system': True,
#  'uuid': '9377e839-e633-483c-a7e5-b34ae5131c52',
#  'verified': False}
# {'_id': 'Entity/2064000',
#  '_key': '2064000',
#  '_rev': '_erW8PC----',
#  'basicEnum': 'NAD',
#  'candidateId': '184e1f33-4b1b-47b6-9f5d-f7f6ef9d1fb5',
#  'creator': 'SYSTEM',
#  'creatorType': 'SYSTEM',
#  'entityType': 'DATA_TYPE',
#  'enum': 'DATA_TYPE_NAD',
#  'name': 'NAD',
#  'payload': {'class': 'kinase',
#              'ec_number': '2.7.1.23',
#              'pathway': 'O95544',
#              'type': 'protein'},
#  'system': True,
#  'uuid': 'f23622ac-5a1c-4630-bacd-f5af9fe75df4',
#  'verified': False}
# [{'_from': 'Entity/DATA_TYPE.DATA_TYPE_MET_O95544',
#   '_id': 'contains/DATA_TYPE_MET_O95544_DATA_TYPE_NAD',
#   '_key': 'DATA_TYPE_MET_O95544_DATA_TYPE_NAD',
#   '_rev': '_erW8PDi---',
#   '_to': 'Entity/2064000',
#   'candidateId': '184e1f33-4b1b-47b6-9f5d-f7f6ef9d1fb5',
#   'connectionType': 'contains',
#   'fromUuid': '9377e839-e633-483c-a7e5-b34ae5131c52',
#   'payload': {'my_data': 'here is the data'},
#   'toUuid': 'f23622ac-5a1c-4630-bacd-f5af9fe75df4',
#   'verified': False},
#  {'_from': 'Entity/DATA_TYPE.DATA_TYPE_MET_O95544',
#   '_id': 'contains/DATA_TYPE.DATA_TYPE_MET_O95544_2064000',
#   '_key': 'DATA_TYPE.DATA_TYPE_MET_O95544_2064000',
#   '_rev': '_erll2cW---',
#   '_to': 'Entity/2064000',
#   'candidateId': '184e1f33-4b1b-47b6-9f5d-f7f6ef9d1fb5',
#   'connectionType': 'contains',
#   'fromUuid': '9377e839-e633-483c-a7e5-b34ae5131c52',
#   'payload': {'my_data': 'here is the data'},
#   'toUuid': 'f23622ac-5a1c-4630-bacd-f5af9fe75df4',
#   'verified': False}]
# {'_id': 'Entity/2064000',
#  '_key': '2064000',
#  '_rev': '_erW8PC----',
#  'basicEnum': 'NAD',
#  'candidateId': '184e1f33-4b1b-47b6-9f5d-f7f6ef9d1fb5',
#  'creator': 'SYSTEM',
#  'creatorType': 'SYSTEM',
#  'entityType': 'DATA_TYPE',
#  'enum': 'DATA_TYPE_NAD',
#  'name': 'NAD',
#  'payload': {'class': 'kinase',
#              'ec_number': '2.7.1.23',
#              'pathway': 'O95544',
#              'type': 'protein'},
#  'system': True,
#  'uuid': 'f23622ac-5a1c-4630-bacd-f5af9fe75df4',
#  'verified': False}

# %%
from knowledge_engine_sdk.models import GetEntityParams, EntityTypes

query_params = GetEntityParams(
    enum="P841A",
    entity_type_enum=EntityTypes.PH_ID,
    uuid=None  # Add this line to provide a value for the required uuid field
)

phid1 = sdk.get_entity(params=query_params)

pp.pprint(phid1)
# Out:
# None

# %%
import inspect
import knowledge_engine_sdk
from enum import Enum

def print_class_info(cls):
    print(f"\n{'='*50}\n{cls.__name__}\n{'='*50}")
    print("Docstring:")
    print(inspect.getdoc(cls))
    print("\nSignature:")
    try:
        print(inspect.signature(cls))
    except ValueError:
        print("No signature available")
    print("\nMethods:")
    for name, method in inspect.getmembers(cls, inspect.isfunction):
        print(f"  {name}:")
        try:
            print(f"    Signature: {inspect.signature(method)}")
        except ValueError:
            print("    Signature: Not available")
        doc = inspect.getdoc(method)
        if doc:
            print(f"    Docstring: {doc[:100]}..." if len(doc) > 100 else f"    Docstring: {doc}")
    print("\nAttributes:")
    for name, value in inspect.getmembers(cls):
        if not name.startswith('__') and not inspect.ismethod(value):
            print(f"  {name}: {type(value)}")

def print_enum_info(enum):
    print(f"\n{'='*50}\n{enum.__name__}\n{'='*50}")
    print("Values:")
    for name, member in enum.__members__.items():
        print(f"  {name}: {member.value}")

def print_function_info(func):
    print(f"\n{'-'*50}\n{func.__name__}\n{'-'*50}")
    print("Signature:")
    try:
        print(inspect.signature(func))
    except ValueError:
        print("No signature available")
    print("\nDocstring:")
    print(inspect.getdoc(func))

def print_all_info(module):
    print(f"Module: {module.__name__}")
    
    print("\nAll attributes:")
    for name in dir(module):
        print(name)
    
    print("\nClasses:")
    classes = [obj for name, obj in inspect.getmembers(module) if inspect.isclass(obj)]
    for cls in classes:
        if issubclass(cls, Enum):
            print_enum_info(cls)
        else:
            print_class_info(cls)
    
    print("\nFunctions:")
    functions = [obj for name, obj in inspect.getmembers(module) if inspect.isfunction(obj)]
    for func in functions:
        print_function_info(func)
    
    print("\nVariables:")
    variables = [name for name in dir(module) if not (name.startswith('__') or callable(getattr(module, name)))]
    for var in variables:
        value = getattr(module, var)
        print(f"  {var}: {type(value)}")
        if isinstance(value, (int, float, str, bool)):
            print(f"    Value: {value}")

    # Try to print version info
    try:
        print(f"\nKnowledge Engine SDK Version: {module.__version__}")
    except AttributeError:
        print("\nKnowledge Engine SDK Version: Not available")

# Run the function to print all info
print_all_info(knowledge_engine_sdk)

# Additional information about KnowledgeEngine class
ke_class = getattr(knowledge_engine_sdk, 'KnowledgeEngine', None)
if ke_class:
    print("\nDetailed KnowledgeEngine Methods:")
    for name, method in inspect.getmembers(ke_class, inspect.isfunction):
        if not name.startswith('__'):
            print(f"\n{name}:")
            try:
                print(f"Signature: {inspect.signature(method)}")
            except ValueError:
                print("Signature: Not available")
            doc = inspect.getdoc(method)
            if doc:
                print(f"Docstring: {doc}")
# Out:
# Module: knowledge_engine_sdk
#
# All attributes:
# Any
# BaseModel
# Connection
# ConnectionDirection
# ConnectionTypes
# CreateConnection
# CreateEntity
# DeleteConnection
# DeleteEntity
# Entity
# EntityTypes
# Enum
# GetConnectionListParams
# GetConnectionParams
# GetEntityListParams
# GetEntityParams
# GetEntityTypeParams
# Knowledge
# KnowledgeEngine
# List
# Optional
# OrderBy
# Pagination
# TraverseAlgorithm
# TraverseParams
# Union
# ValidationError
# __builtins__
# __cached__
# __doc__
# __file__
# __loader__
# __name__
# __package__
# __path__
# __spec__
# datetime
# errors
# knowledge_engine_sdk
# models
# utils
#
# Classes:
#
# ==================================================
# BaseModel
# ==================================================
# Docstring:
# Usage docs: https://docs.pydantic.dev/2.8/concepts/models/
#
# A base class for creating Pydantic models.
#
# Attributes:
#     __class_vars__: The names of classvars defined on the model.
#     __private_attributes__: Metadata about the private attributes of the model.
#     __signature__: The signature for instantiating the model.
#
#     __pydantic_complete__: Whether model building is completed, or if there are still undefined fields.
#     __pydantic_core_schema__: The pydantic-core schema used to build the SchemaValidator and SchemaSerializer.
#     __pydantic_custom_init__: Whether the model has a custom `__init__` function.
#     __pydantic_decorators__: Metadata containing the decorators defined on the model.
#         This replaces `Model.__validators__` and `Model.__root_validators__` from Pydantic V1.
#     __pydantic_generic_metadata__: Metadata for generic models; contains data used for a similar purpose to
#         __args__, __origin__, __parameters__ in typing-module generics. May eventually be replaced by these.
#     __pydantic_parent_namespace__: Parent namespace of the model, used for automatic rebuilding of models.
#     __pydantic_post_init__: The name of the post-init method for the model, if defined.
#     __pydantic_root_model__: Whether the model is a `RootModel`.
#     __pydantic_serializer__: The pydantic-core SchemaSerializer used to dump instances of the model.
#     __pydantic_validator__: The pydantic-core SchemaValidator used to validate instances of the model.
#
#     __pydantic_extra__: An instance attribute with the values of extra fields from validation when
#         `model_config['extra'] == 'allow'`.
#     __pydantic_fields_set__: An instance attribute with the names of fields explicitly set.
#     __pydantic_private__: Instance attribute with the values of private attributes set on the model instance.
#
# Signature:
# (**data: 'Any') -> 'None'
#
# Methods:
#   __copy__:
#     Signature: (self) -> 'Self'
#     Docstring: Returns a shallow copy of the model.
#   __deepcopy__:
#     Signature: (self, memo: 'dict[int, Any] | None' = None) -> 'Self'
#     Docstring: Returns a deep copy of the model.
#   __delattr__:
#     Signature: (self, item: 'str') -> 'Any'
#     Docstring: Implement delattr(self, name).
#   __eq__:
#     Signature: (self, other: 'Any') -> 'bool'
#     Docstring: Return self==value.
#   __getattr__:
#     Signature: (self, item: 'str') -> 'Any'
#   __getstate__:
#     Signature: (self) -> 'dict[Any, Any]'
#   __init__:
#     Signature: (self, /, **data: 'Any') -> 'None'
#     Docstring: Create a new model by parsing and validating input data from keyword arguments.
#
# Raises [`Validation...
#   __iter__:
#     Signature: (self) -> 'TupleGenerator'
#     Docstring: So `dict(model)` works.
#   __pretty__:
#     Signature: (self, fmt: 'typing.Callable[[Any], Any]', **kwargs: 'Any') -> 'typing.Generator[Any, None, None]'
#     Docstring: Used by devtools (https://python-devtools.helpmanual.io/) to pretty print objects.
#   __repr__:
#     Signature: (self) -> 'str'
#     Docstring: Return repr(self).
#   __repr_args__:
#     Signature: (self) -> '_repr.ReprArgs'
#   __repr_name__:
#     Signature: (self) -> 'str'
#     Docstring: Name of the instance's class, used in __repr__.
#   __repr_str__:
#     Signature: (self, join_str: 'str') -> 'str'
#   __rich_repr__:
#     Signature: (self) -> 'RichReprResult'
#     Docstring: Used by Rich (https://rich.readthedocs.io/en/stable/pretty.html) to pretty print objects.
#   __setattr__:
#     Signature: (self, name: 'str', value: 'Any') -> 'None'
#     Docstring: Implement setattr(self, name, value).
#   __setstate__:
#     Signature: (self, state: 'dict[Any, Any]') -> 'None'
#   __str__:
#     Signature: (self) -> 'str'
#     Docstring: Return str(self).
#   _calculate_keys:
#     Signature: (self, *args: 'Any', **kwargs: 'Any') -> 'Any'
#   _check_frozen:
#     Signature: (self, name: 'str', value: 'Any') -> 'None'
#   _copy_and_set_values:
#     Signature: (self, *args: 'Any', **kwargs: 'Any') -> 'Any'
#   _iter:
#     Signature: (self, *args: 'Any', **kwargs: 'Any') -> 'Any'
#   copy:
#     Signature: (self, *, include: 'AbstractSetIntStr | MappingIntStrAny | None' = None, exclude: 'AbstractSetIntStr | MappingIntStrAny | None' = None, update: 'Dict[str, Any] | None' = None, deep: 'bool' = False) -> 'Self'
#     Docstring: Returns a copy of the model.
#
# !!! warning "Deprecated"
#     This method is now deprecated; use `model...
#   dict:
#     Signature: (self, *, include: 'IncEx' = None, exclude: 'IncEx' = None, by_alias: 'bool' = False, exclude_unset: 'bool' = False, exclude_defaults: 'bool' = False, exclude_none: 'bool' = False) -> 'Dict[str, Any]'
#   json:
#     Signature: (self, *, include: 'IncEx' = None, exclude: 'IncEx' = None, by_alias: 'bool' = False, exclude_unset: 'bool' = False, exclude_defaults: 'bool' = False, exclude_none: 'bool' = False, encoder: 'Callable[[Any], Any] | None' = PydanticUndefined, models_as_dict: 'bool' = PydanticUndefined, **dumps_kwargs: 'Any') -> 'str'
#   model_copy:
#     Signature: (self, *, update: 'dict[str, Any] | None' = None, deep: 'bool' = False) -> 'Self'
#     Docstring: Usage docs: https://docs.pydantic.dev/2.8/concepts/serialization/#model_copy
#
# Returns a copy of the ...
#   model_dump:
#     Signature: (self, *, mode: "Literal['json', 'python'] | str" = 'python', include: 'IncEx' = None, exclude: 'IncEx' = None, context: 'Any | None' = None, by_alias: 'bool' = False, exclude_unset: 'bool' = False, exclude_defaults: 'bool' = False, exclude_none: 'bool' = False, round_trip: 'bool' = False, warnings: "bool | Literal['none', 'warn', 'error']" = True, serialize_as_any: 'bool' = False) -> 'dict[str, Any]'
#     Docstring: Usage docs: https://docs.pydantic.dev/2.8/concepts/serialization/#modelmodel_dump
#
# Generate a dictio...
#   model_dump_json:
#     Signature: (self, *, indent: 'int | None' = None, include: 'IncEx' = None, exclude: 'IncEx' = None, context: 'Any | None' = None, by_alias: 'bool' = False, exclude_unset: 'bool' = False, exclude_defaults: 'bool' = False, exclude_none: 'bool' = False, round_trip: 'bool' = False, warnings: "bool | Literal['none', 'warn', 'error']" = True, serialize_as_any: 'bool' = False) -> 'str'
#     Docstring: Usage docs: https://docs.pydantic.dev/2.8/concepts/serialization/#modelmodel_dump_json
#
# Generates a ...
#   model_post_init:
#     Signature: (self, _BaseModel__context: 'Any') -> 'None'
#     Docstring: Override this method to perform additional initialization after `__init__` and `model_construct`.
# Th...
#
# Attributes:
#   _abc_impl: <class '_abc._abc_data'>
#   _calculate_keys: <class 'function'>
#   _check_frozen: <class 'function'>
#   _copy_and_set_values: <class 'function'>
#   _iter: <class 'function'>
#   copy: <class 'function'>
#   dict: <class 'function'>
#   json: <class 'function'>
#   model_computed_fields: <class 'dict'>
#   model_config: <class 'dict'>
#   model_copy: <class 'function'>
#   model_dump: <class 'function'>
#   model_dump_json: <class 'function'>
#   model_extra: <class 'property'>
#   model_fields: <class 'dict'>
#   model_fields_set: <class 'property'>
#   model_post_init: <class 'function'>
#
# ==================================================
# Connection
# ==================================================
# Docstring:
# Usage docs: https://docs.pydantic.dev/2.8/concepts/models/
#
# A base class for creating Pydantic models.
#
# Attributes:
#     __class_vars__: The names of classvars defined on the model.
#     __private_attributes__: Metadata about the private attributes of the model.
#     __signature__: The signature for instantiating the model.
#
#     __pydantic_complete__: Whether model building is completed, or if there are still undefined fields.
#     __pydantic_core_schema__: The pydantic-core schema used to build the SchemaValidator and SchemaSerializer.
#     __pydantic_custom_init__: Whether the model has a custom `__init__` function.
#     __pydantic_decorators__: Metadata containing the decorators defined on the model.
#         This replaces `Model.__validators__` and `Model.__root_validators__` from Pydantic V1.
#     __pydantic_generic_metadata__: Metadata for generic models; contains data used for a similar purpose to
#         __args__, __origin__, __parameters__ in typing-module generics. May eventually be replaced by these.
#     __pydantic_parent_namespace__: Parent namespace of the model, used for automatic rebuilding of models.
#     __pydantic_post_init__: The name of the post-init method for the model, if defined.
#     __pydantic_root_model__: Whether the model is a `RootModel`.
#     __pydantic_serializer__: The pydantic-core SchemaSerializer used to dump instances of the model.
#     __pydantic_validator__: The pydantic-core SchemaValidator used to validate instances of the model.
#
#     __pydantic_extra__: An instance attribute with the values of extra fields from validation when
#         `model_config['extra'] == 'allow'`.
#     __pydantic_fields_set__: An instance attribute with the names of fields explicitly set.
#     __pydantic_private__: Instance attribute with the values of private attributes set on the model instance.
#
# Signature:
# (*, fromUuid: str, toUuid: str, candidateId: str, verified: bool, payload: Optional[dict]) -> None
#
# Methods:
#   __copy__:
#     Signature: (self) -> 'Self'
#     Docstring: Returns a shallow copy of the model.
#   __deepcopy__:
#     Signature: (self, memo: 'dict[int, Any] | None' = None) -> 'Self'
#     Docstring: Returns a deep copy of the model.
#   __delattr__:
#     Signature: (self, item: 'str') -> 'Any'
#     Docstring: Implement delattr(self, name).
#   __eq__:
#     Signature: (self, other: 'Any') -> 'bool'
#     Docstring: Return self==value.
#   __getattr__:
#     Signature: (self, item: 'str') -> 'Any'
#   __getstate__:
#     Signature: (self) -> 'dict[Any, Any]'
#   __init__:
#     Signature: (self, /, **data: 'Any') -> 'None'
#     Docstring: Create a new model by parsing and validating input data from keyword arguments.
#
# Raises [`Validation...
#   __iter__:
#     Signature: (self) -> 'TupleGenerator'
#     Docstring: So `dict(model)` works.
#   __pretty__:
#     Signature: (self, fmt: 'typing.Callable[[Any], Any]', **kwargs: 'Any') -> 'typing.Generator[Any, None, None]'
#     Docstring: Used by devtools (https://python-devtools.helpmanual.io/) to pretty print objects.
#   __repr__:
#     Signature: (self) -> 'str'
#     Docstring: Return repr(self).
#   __repr_args__:
#     Signature: (self) -> '_repr.ReprArgs'
#   __repr_name__:
#     Signature: (self) -> 'str'
#     Docstring: Name of the instance's class, used in __repr__.
#   __repr_str__:
#     Signature: (self, join_str: 'str') -> 'str'
#   __rich_repr__:
#     Signature: (self) -> 'RichReprResult'
#     Docstring: Used by Rich (https://rich.readthedocs.io/en/stable/pretty.html) to pretty print objects.
#   __setattr__:
#     Signature: (self, name: 'str', value: 'Any') -> 'None'
#     Docstring: Implement setattr(self, name, value).
#   __setstate__:
#     Signature: (self, state: 'dict[Any, Any]') -> 'None'
#   __str__:
#     Signature: (self) -> 'str'
#     Docstring: Return str(self).
#   _calculate_keys:
#     Signature: (self, *args: 'Any', **kwargs: 'Any') -> 'Any'
#   _check_frozen:
#     Signature: (self, name: 'str', value: 'Any') -> 'None'
#   _copy_and_set_values:
#     Signature: (self, *args: 'Any', **kwargs: 'Any') -> 'Any'
#   _iter:
#     Signature: (self, *args: 'Any', **kwargs: 'Any') -> 'Any'
#   copy:
#     Signature: (self, *, include: 'AbstractSetIntStr | MappingIntStrAny | None' = None, exclude: 'AbstractSetIntStr | MappingIntStrAny | None' = None, update: 'Dict[str, Any] | None' = None, deep: 'bool' = False) -> 'Self'
#     Docstring: Returns a copy of the model.
#
# !!! warning "Deprecated"
#     This method is now deprecated; use `model...
#   dict:
#     Signature: (self, *, include: 'IncEx' = None, exclude: 'IncEx' = None, by_alias: 'bool' = False, exclude_unset: 'bool' = False, exclude_defaults: 'bool' = False, exclude_none: 'bool' = False) -> 'Dict[str, Any]'
#   json:
#     Signature: (self, *, include: 'IncEx' = None, exclude: 'IncEx' = None, by_alias: 'bool' = False, exclude_unset: 'bool' = False, exclude_defaults: 'bool' = False, exclude_none: 'bool' = False, encoder: 'Callable[[Any], Any] | None' = PydanticUndefined, models_as_dict: 'bool' = PydanticUndefined, **dumps_kwargs: 'Any') -> 'str'
#   model_copy:
#     Signature: (self, *, update: 'dict[str, Any] | None' = None, deep: 'bool' = False) -> 'Self'
#     Docstring: Usage docs: https://docs.pydantic.dev/2.8/concepts/serialization/#model_copy
#
# Returns a copy of the ...
#   model_dump:
#     Signature: (self, *, mode: "Literal['json', 'python'] | str" = 'python', include: 'IncEx' = None, exclude: 'IncEx' = None, context: 'Any | None' = None, by_alias: 'bool' = False, exclude_unset: 'bool' = False, exclude_defaults: 'bool' = False, exclude_none: 'bool' = False, round_trip: 'bool' = False, warnings: "bool | Literal['none', 'warn', 'error']" = True, serialize_as_any: 'bool' = False) -> 'dict[str, Any]'
#     Docstring: Usage docs: https://docs.pydantic.dev/2.8/concepts/serialization/#modelmodel_dump
#
# Generate a dictio...
#   model_dump_json:
#     Signature: (self, *, indent: 'int | None' = None, include: 'IncEx' = None, exclude: 'IncEx' = None, context: 'Any | None' = None, by_alias: 'bool' = False, exclude_unset: 'bool' = False, exclude_defaults: 'bool' = False, exclude_none: 'bool' = False, round_trip: 'bool' = False, warnings: "bool | Literal['none', 'warn', 'error']" = True, serialize_as_any: 'bool' = False) -> 'str'
#     Docstring: Usage docs: https://docs.pydantic.dev/2.8/concepts/serialization/#modelmodel_dump_json
#
# Generates a ...
#   model_post_init:
#     Signature: (self, _BaseModel__context: 'Any') -> 'None'
#     Docstring: Override this method to perform additional initialization after `__init__` and `model_construct`.
# Th...
#
# Attributes:
#   _abc_impl: <class '_abc._abc_data'>
#   _calculate_keys: <class 'function'>
#   _check_frozen: <class 'function'>
#   _copy_and_set_values: <class 'function'>
#   _iter: <class 'function'>
#   copy: <class 'function'>
#   dict: <class 'function'>
#   json: <class 'function'>
#   model_computed_fields: <class 'dict'>
#   model_config: <class 'dict'>
#   model_copy: <class 'function'>
#   model_dump: <class 'function'>
#   model_dump_json: <class 'function'>
#   model_extra: <class 'property'>
#   model_fields: <class 'dict'>
#   model_fields_set: <class 'property'>
#   model_post_init: <class 'function'>
#
# ==================================================
# ConnectionDirection
# ==================================================
# Values:
#   INBOUND: in
#   OUTBOUND: out
#
# ==================================================
# ConnectionTypes
# ==================================================
# Values:
#   CONTAINS: contains
#
# ==================================================
# CreateConnection
# ==================================================
# Docstring:
# Usage docs: https://docs.pydantic.dev/2.8/concepts/models/
#
# A base class for creating Pydantic models.
#
# Attributes:
#     __class_vars__: The names of classvars defined on the model.
#     __private_attributes__: Metadata about the private attributes of the model.
#     __signature__: The signature for instantiating the model.
#
#     __pydantic_complete__: Whether model building is completed, or if there are still undefined fields.
#     __pydantic_core_schema__: The pydantic-core schema used to build the SchemaValidator and SchemaSerializer.
#     __pydantic_custom_init__: Whether the model has a custom `__init__` function.
#     __pydantic_decorators__: Metadata containing the decorators defined on the model.
#         This replaces `Model.__validators__` and `Model.__root_validators__` from Pydantic V1.
#     __pydantic_generic_metadata__: Metadata for generic models; contains data used for a similar purpose to
#         __args__, __origin__, __parameters__ in typing-module generics. May eventually be replaced by these.
#     __pydantic_parent_namespace__: Parent namespace of the model, used for automatic rebuilding of models.
#     __pydantic_post_init__: The name of the post-init method for the model, if defined.
#     __pydantic_root_model__: Whether the model is a `RootModel`.
#     __pydantic_serializer__: The pydantic-core SchemaSerializer used to dump instances of the model.
#     __pydantic_validator__: The pydantic-core SchemaValidator used to validate instances of the model.
#
#     __pydantic_extra__: An instance attribute with the values of extra fields from validation when
#         `model_config['extra'] == 'allow'`.
#     __pydantic_fields_set__: An instance attribute with the names of fields explicitly set.
#     __pydantic_private__: Instance attribute with the values of private attributes set on the model instance.
#
# Signature:
# (*, fromUuid: str, toUuid: str, connectionType: str, candidateId: str, payload: Optional[dict]) -> None
#
# Methods:
#   __copy__:
#     Signature: (self) -> 'Self'
#     Docstring: Returns a shallow copy of the model.
#   __deepcopy__:
#     Signature: (self, memo: 'dict[int, Any] | None' = None) -> 'Self'
#     Docstring: Returns a deep copy of the model.
#   __delattr__:
#     Signature: (self, item: 'str') -> 'Any'
#     Docstring: Implement delattr(self, name).
#   __eq__:
#     Signature: (self, other: 'Any') -> 'bool'
#     Docstring: Return self==value.
#   __getattr__:
#     Signature: (self, item: 'str') -> 'Any'
#   __getstate__:
#     Signature: (self) -> 'dict[Any, Any]'
#   __init__:
#     Signature: (self, /, **data: 'Any') -> 'None'
#     Docstring: Create a new model by parsing and validating input data from keyword arguments.
#
# Raises [`Validation...
#   __iter__:
#     Signature: (self) -> 'TupleGenerator'
#     Docstring: So `dict(model)` works.
#   __pretty__:
#     Signature: (self, fmt: 'typing.Callable[[Any], Any]', **kwargs: 'Any') -> 'typing.Generator[Any, None, None]'
#     Docstring: Used by devtools (https://python-devtools.helpmanual.io/) to pretty print objects.
#   __repr__:
#     Signature: (self) -> 'str'
#     Docstring: Return repr(self).
#   __repr_args__:
#     Signature: (self) -> '_repr.ReprArgs'
#   __repr_name__:
#     Signature: (self) -> 'str'
#     Docstring: Name of the instance's class, used in __repr__.
#   __repr_str__:
#     Signature: (self, join_str: 'str') -> 'str'
#   __rich_repr__:
#     Signature: (self) -> 'RichReprResult'
#     Docstring: Used by Rich (https://rich.readthedocs.io/en/stable/pretty.html) to pretty print objects.
#   __setattr__:
#     Signature: (self, name: 'str', value: 'Any') -> 'None'
#     Docstring: Implement setattr(self, name, value).
#   __setstate__:
#     Signature: (self, state: 'dict[Any, Any]') -> 'None'
#   __str__:
#     Signature: (self) -> 'str'
#     Docstring: Return str(self).
#   _calculate_keys:
#     Signature: (self, *args: 'Any', **kwargs: 'Any') -> 'Any'
#   _check_frozen:
#     Signature: (self, name: 'str', value: 'Any') -> 'None'
#   _copy_and_set_values:
#     Signature: (self, *args: 'Any', **kwargs: 'Any') -> 'Any'
#   _iter:
#     Signature: (self, *args: 'Any', **kwargs: 'Any') -> 'Any'
#   copy:
#     Signature: (self, *, include: 'AbstractSetIntStr | MappingIntStrAny | None' = None, exclude: 'AbstractSetIntStr | MappingIntStrAny | None' = None, update: 'Dict[str, Any] | None' = None, deep: 'bool' = False) -> 'Self'
#     Docstring: Returns a copy of the model.
#
# !!! warning "Deprecated"
#     This method is now deprecated; use `model...
#   dict:
#     Signature: (self, *, include: 'IncEx' = None, exclude: 'IncEx' = None, by_alias: 'bool' = False, exclude_unset: 'bool' = False, exclude_defaults: 'bool' = False, exclude_none: 'bool' = False) -> 'Dict[str, Any]'
#   json:
#     Signature: (self, *, include: 'IncEx' = None, exclude: 'IncEx' = None, by_alias: 'bool' = False, exclude_unset: 'bool' = False, exclude_defaults: 'bool' = False, exclude_none: 'bool' = False, encoder: 'Callable[[Any], Any] | None' = PydanticUndefined, models_as_dict: 'bool' = PydanticUndefined, **dumps_kwargs: 'Any') -> 'str'
#   model_copy:
#     Signature: (self, *, update: 'dict[str, Any] | None' = None, deep: 'bool' = False) -> 'Self'
#     Docstring: Usage docs: https://docs.pydantic.dev/2.8/concepts/serialization/#model_copy
#
# Returns a copy of the ...
#   model_dump:
#     Signature: (self, *, mode: "Literal['json', 'python'] | str" = 'python', include: 'IncEx' = None, exclude: 'IncEx' = None, context: 'Any | None' = None, by_alias: 'bool' = False, exclude_unset: 'bool' = False, exclude_defaults: 'bool' = False, exclude_none: 'bool' = False, round_trip: 'bool' = False, warnings: "bool | Literal['none', 'warn', 'error']" = True, serialize_as_any: 'bool' = False) -> 'dict[str, Any]'
#     Docstring: Usage docs: https://docs.pydantic.dev/2.8/concepts/serialization/#modelmodel_dump
#
# Generate a dictio...
#   model_dump_json:
#     Signature: (self, *, indent: 'int | None' = None, include: 'IncEx' = None, exclude: 'IncEx' = None, context: 'Any | None' = None, by_alias: 'bool' = False, exclude_unset: 'bool' = False, exclude_defaults: 'bool' = False, exclude_none: 'bool' = False, round_trip: 'bool' = False, warnings: "bool | Literal['none', 'warn', 'error']" = True, serialize_as_any: 'bool' = False) -> 'str'
#     Docstring: Usage docs: https://docs.pydantic.dev/2.8/concepts/serialization/#modelmodel_dump_json
#
# Generates a ...
#   model_post_init:
#     Signature: (self, _BaseModel__context: 'Any') -> 'None'
#     Docstring: Override this method to perform additional initialization after `__init__` and `model_construct`.
# Th...
#
# Attributes:
#   _abc_impl: <class '_abc._abc_data'>
#   _calculate_keys: <class 'function'>
#   _check_frozen: <class 'function'>
#   _copy_and_set_values: <class 'function'>
#   _iter: <class 'function'>
#   copy: <class 'function'>
#   dict: <class 'function'>
#   json: <class 'function'>
#   model_computed_fields: <class 'dict'>
#   model_config: <class 'dict'>
#   model_copy: <class 'function'>
#   model_dump: <class 'function'>
#   model_dump_json: <class 'function'>
#   model_extra: <class 'property'>
#   model_fields: <class 'dict'>
#   model_fields_set: <class 'property'>
#   model_post_init: <class 'function'>
#
# ==================================================
# CreateEntity
# ==================================================
# Docstring:
# Usage docs: https://docs.pydantic.dev/2.8/concepts/models/
#
# A base class for creating Pydantic models.
#
# Attributes:
#     __class_vars__: The names of classvars defined on the model.
#     __private_attributes__: Metadata about the private attributes of the model.
#     __signature__: The signature for instantiating the model.
#
#     __pydantic_complete__: Whether model building is completed, or if there are still undefined fields.
#     __pydantic_core_schema__: The pydantic-core schema used to build the SchemaValidator and SchemaSerializer.
#     __pydantic_custom_init__: Whether the model has a custom `__init__` function.
#     __pydantic_decorators__: Metadata containing the decorators defined on the model.
#         This replaces `Model.__validators__` and `Model.__root_validators__` from Pydantic V1.
#     __pydantic_generic_metadata__: Metadata for generic models; contains data used for a similar purpose to
#         __args__, __origin__, __parameters__ in typing-module generics. May eventually be replaced by these.
#     __pydantic_parent_namespace__: Parent namespace of the model, used for automatic rebuilding of models.
#     __pydantic_post_init__: The name of the post-init method for the model, if defined.
#     __pydantic_root_model__: Whether the model is a `RootModel`.
#     __pydantic_serializer__: The pydantic-core SchemaSerializer used to dump instances of the model.
#     __pydantic_validator__: The pydantic-core SchemaValidator used to validate instances of the model.
#
#     __pydantic_extra__: An instance attribute with the values of extra fields from validation when
#         `model_config['extra'] == 'allow'`.
#     __pydantic_fields_set__: An instance attribute with the names of fields explicitly set.
#     __pydantic_private__: Instance attribute with the values of private attributes set on the model instance.
#
# Signature:
# (*, name: str, isSystem: bool, entityType: knowledge_engine_sdk.models.EntityTypes, candidateId: str, payload: Optional[dict]) -> None
#
# Methods:
#   __copy__:
#     Signature: (self) -> 'Self'
#     Docstring: Returns a shallow copy of the model.
#   __deepcopy__:
#     Signature: (self, memo: 'dict[int, Any] | None' = None) -> 'Self'
#     Docstring: Returns a deep copy of the model.
#   __delattr__:
#     Signature: (self, item: 'str') -> 'Any'
#     Docstring: Implement delattr(self, name).
#   __eq__:
#     Signature: (self, other: 'Any') -> 'bool'
#     Docstring: Return self==value.
#   __getattr__:
#     Signature: (self, item: 'str') -> 'Any'
#   __getstate__:
#     Signature: (self) -> 'dict[Any, Any]'
#   __init__:
#     Signature: (self, /, **data: 'Any') -> 'None'
#     Docstring: Create a new model by parsing and validating input data from keyword arguments.
#
# Raises [`Validation...
#   __iter__:
#     Signature: (self) -> 'TupleGenerator'
#     Docstring: So `dict(model)` works.
#   __pretty__:
#     Signature: (self, fmt: 'typing.Callable[[Any], Any]', **kwargs: 'Any') -> 'typing.Generator[Any, None, None]'
#     Docstring: Used by devtools (https://python-devtools.helpmanual.io/) to pretty print objects.
#   __repr__:
#     Signature: (self) -> 'str'
#     Docstring: Return repr(self).
#   __repr_args__:
#     Signature: (self) -> '_repr.ReprArgs'
#   __repr_name__:
#     Signature: (self) -> 'str'
#     Docstring: Name of the instance's class, used in __repr__.
#   __repr_str__:
#     Signature: (self, join_str: 'str') -> 'str'
#   __rich_repr__:
#     Signature: (self) -> 'RichReprResult'
#     Docstring: Used by Rich (https://rich.readthedocs.io/en/stable/pretty.html) to pretty print objects.
#   __setattr__:
#     Signature: (self, name: 'str', value: 'Any') -> 'None'
#     Docstring: Implement setattr(self, name, value).
#   __setstate__:
#     Signature: (self, state: 'dict[Any, Any]') -> 'None'
#   __str__:
#     Signature: (self) -> 'str'
#     Docstring: Return str(self).
#   _calculate_keys:
#     Signature: (self, *args: 'Any', **kwargs: 'Any') -> 'Any'
#   _check_frozen:
#     Signature: (self, name: 'str', value: 'Any') -> 'None'
#   _copy_and_set_values:
#     Signature: (self, *args: 'Any', **kwargs: 'Any') -> 'Any'
#   _iter:
#     Signature: (self, *args: 'Any', **kwargs: 'Any') -> 'Any'
#   copy:
#     Signature: (self, *, include: 'AbstractSetIntStr | MappingIntStrAny | None' = None, exclude: 'AbstractSetIntStr | MappingIntStrAny | None' = None, update: 'Dict[str, Any] | None' = None, deep: 'bool' = False) -> 'Self'
#     Docstring: Returns a copy of the model.
#
# !!! warning "Deprecated"
#     This method is now deprecated; use `model...
#   dict:
#     Signature: (self, *, include: 'IncEx' = None, exclude: 'IncEx' = None, by_alias: 'bool' = False, exclude_unset: 'bool' = False, exclude_defaults: 'bool' = False, exclude_none: 'bool' = False) -> 'Dict[str, Any]'
#   json:
#     Signature: (self, *, include: 'IncEx' = None, exclude: 'IncEx' = None, by_alias: 'bool' = False, exclude_unset: 'bool' = False, exclude_defaults: 'bool' = False, exclude_none: 'bool' = False, encoder: 'Callable[[Any], Any] | None' = PydanticUndefined, models_as_dict: 'bool' = PydanticUndefined, **dumps_kwargs: 'Any') -> 'str'
#   model_copy:
#     Signature: (self, *, update: 'dict[str, Any] | None' = None, deep: 'bool' = False) -> 'Self'
#     Docstring: Usage docs: https://docs.pydantic.dev/2.8/concepts/serialization/#model_copy
#
# Returns a copy of the ...
#   model_dump:
#     Signature: (self, *, mode: "Literal['json', 'python'] | str" = 'python', include: 'IncEx' = None, exclude: 'IncEx' = None, context: 'Any | None' = None, by_alias: 'bool' = False, exclude_unset: 'bool' = False, exclude_defaults: 'bool' = False, exclude_none: 'bool' = False, round_trip: 'bool' = False, warnings: "bool | Literal['none', 'warn', 'error']" = True, serialize_as_any: 'bool' = False) -> 'dict[str, Any]'
#     Docstring: Usage docs: https://docs.pydantic.dev/2.8/concepts/serialization/#modelmodel_dump
#
# Generate a dictio...
#   model_dump_json:
#     Signature: (self, *, indent: 'int | None' = None, include: 'IncEx' = None, exclude: 'IncEx' = None, context: 'Any | None' = None, by_alias: 'bool' = False, exclude_unset: 'bool' = False, exclude_defaults: 'bool' = False, exclude_none: 'bool' = False, round_trip: 'bool' = False, warnings: "bool | Literal['none', 'warn', 'error']" = True, serialize_as_any: 'bool' = False) -> 'str'
#     Docstring: Usage docs: https://docs.pydantic.dev/2.8/concepts/serialization/#modelmodel_dump_json
#
# Generates a ...
#   model_post_init:
#     Signature: (self, _BaseModel__context: 'Any') -> 'None'
#     Docstring: Override this method to perform additional initialization after `__init__` and `model_construct`.
# Th...
#
# Attributes:
#   _abc_impl: <class '_abc._abc_data'>
#   _calculate_keys: <class 'function'>
#   _check_frozen: <class 'function'>
#   _copy_and_set_values: <class 'function'>
#   _iter: <class 'function'>
#   copy: <class 'function'>
#   dict: <class 'function'>
#   json: <class 'function'>
#   model_computed_fields: <class 'dict'>
#   model_config: <class 'dict'>
#   model_copy: <class 'function'>
#   model_dump: <class 'function'>
#   model_dump_json: <class 'function'>
#   model_extra: <class 'property'>
#   model_fields: <class 'dict'>
#   model_fields_set: <class 'property'>
#   model_post_init: <class 'function'>
#
# ==================================================
# DeleteConnection
# ==================================================
# Docstring:
# Usage docs: https://docs.pydantic.dev/2.8/concepts/models/
#
# A base class for creating Pydantic models.
#
# Attributes:
#     __class_vars__: The names of classvars defined on the model.
#     __private_attributes__: Metadata about the private attributes of the model.
#     __signature__: The signature for instantiating the model.
#
#     __pydantic_complete__: Whether model building is completed, or if there are still undefined fields.
#     __pydantic_core_schema__: The pydantic-core schema used to build the SchemaValidator and SchemaSerializer.
#     __pydantic_custom_init__: Whether the model has a custom `__init__` function.
#     __pydantic_decorators__: Metadata containing the decorators defined on the model.
#         This replaces `Model.__validators__` and `Model.__root_validators__` from Pydantic V1.
#     __pydantic_generic_metadata__: Metadata for generic models; contains data used for a similar purpose to
#         __args__, __origin__, __parameters__ in typing-module generics. May eventually be replaced by these.
#     __pydantic_parent_namespace__: Parent namespace of the model, used for automatic rebuilding of models.
#     __pydantic_post_init__: The name of the post-init method for the model, if defined.
#     __pydantic_root_model__: Whether the model is a `RootModel`.
#     __pydantic_serializer__: The pydantic-core SchemaSerializer used to dump instances of the model.
#     __pydantic_validator__: The pydantic-core SchemaValidator used to validate instances of the model.
#
#     __pydantic_extra__: An instance attribute with the values of extra fields from validation when
#         `model_config['extra'] == 'allow'`.
#     __pydantic_fields_set__: An instance attribute with the names of fields explicitly set.
#     __pydantic_private__: Instance attribute with the values of private attributes set on the model instance.
#
# Signature:
# (*, fromUuid: str, toUuid: str, connectionType: str) -> None
#
# Methods:
#   __copy__:
#     Signature: (self) -> 'Self'
#     Docstring: Returns a shallow copy of the model.
#   __deepcopy__:
#     Signature: (self, memo: 'dict[int, Any] | None' = None) -> 'Self'
#     Docstring: Returns a deep copy of the model.
#   __delattr__:
#     Signature: (self, item: 'str') -> 'Any'
#     Docstring: Implement delattr(self, name).
#   __eq__:
#     Signature: (self, other: 'Any') -> 'bool'
#     Docstring: Return self==value.
#   __getattr__:
#     Signature: (self, item: 'str') -> 'Any'
#   __getstate__:
#     Signature: (self) -> 'dict[Any, Any]'
#   __init__:
#     Signature: (self, /, **data: 'Any') -> 'None'
#     Docstring: Create a new model by parsing and validating input data from keyword arguments.
#
# Raises [`Validation...
#   __iter__:
#     Signature: (self) -> 'TupleGenerator'
#     Docstring: So `dict(model)` works.
#   __pretty__:
#     Signature: (self, fmt: 'typing.Callable[[Any], Any]', **kwargs: 'Any') -> 'typing.Generator[Any, None, None]'
#     Docstring: Used by devtools (https://python-devtools.helpmanual.io/) to pretty print objects.
#   __repr__:
#     Signature: (self) -> 'str'
#     Docstring: Return repr(self).
#   __repr_args__:
#     Signature: (self) -> '_repr.ReprArgs'
#   __repr_name__:
#     Signature: (self) -> 'str'
#     Docstring: Name of the instance's class, used in __repr__.
#   __repr_str__:
#     Signature: (self, join_str: 'str') -> 'str'
#   __rich_repr__:
#     Signature: (self) -> 'RichReprResult'
#     Docstring: Used by Rich (https://rich.readthedocs.io/en/stable/pretty.html) to pretty print objects.
#   __setattr__:
#     Signature: (self, name: 'str', value: 'Any') -> 'None'
#     Docstring: Implement setattr(self, name, value).
#   __setstate__:
#     Signature: (self, state: 'dict[Any, Any]') -> 'None'
#   __str__:
#     Signature: (self) -> 'str'
#     Docstring: Return str(self).
#   _calculate_keys:
#     Signature: (self, *args: 'Any', **kwargs: 'Any') -> 'Any'
#   _check_frozen:
#     Signature: (self, name: 'str', value: 'Any') -> 'None'
#   _copy_and_set_values:
#     Signature: (self, *args: 'Any', **kwargs: 'Any') -> 'Any'
#   _iter:
#     Signature: (self, *args: 'Any', **kwargs: 'Any') -> 'Any'
#   copy:
#     Signature: (self, *, include: 'AbstractSetIntStr | MappingIntStrAny | None' = None, exclude: 'AbstractSetIntStr | MappingIntStrAny | None' = None, update: 'Dict[str, Any] | None' = None, deep: 'bool' = False) -> 'Self'
#     Docstring: Returns a copy of the model.
#
# !!! warning "Deprecated"
#     This method is now deprecated; use `model...
#   dict:
#     Signature: (self, *, include: 'IncEx' = None, exclude: 'IncEx' = None, by_alias: 'bool' = False, exclude_unset: 'bool' = False, exclude_defaults: 'bool' = False, exclude_none: 'bool' = False) -> 'Dict[str, Any]'
#   json:
#     Signature: (self, *, include: 'IncEx' = None, exclude: 'IncEx' = None, by_alias: 'bool' = False, exclude_unset: 'bool' = False, exclude_defaults: 'bool' = False, exclude_none: 'bool' = False, encoder: 'Callable[[Any], Any] | None' = PydanticUndefined, models_as_dict: 'bool' = PydanticUndefined, **dumps_kwargs: 'Any') -> 'str'
#   model_copy:
#     Signature: (self, *, update: 'dict[str, Any] | None' = None, deep: 'bool' = False) -> 'Self'
#     Docstring: Usage docs: https://docs.pydantic.dev/2.8/concepts/serialization/#model_copy
#
# Returns a copy of the ...
#   model_dump:
#     Signature: (self, *, mode: "Literal['json', 'python'] | str" = 'python', include: 'IncEx' = None, exclude: 'IncEx' = None, context: 'Any | None' = None, by_alias: 'bool' = False, exclude_unset: 'bool' = False, exclude_defaults: 'bool' = False, exclude_none: 'bool' = False, round_trip: 'bool' = False, warnings: "bool | Literal['none', 'warn', 'error']" = True, serialize_as_any: 'bool' = False) -> 'dict[str, Any]'
#     Docstring: Usage docs: https://docs.pydantic.dev/2.8/concepts/serialization/#modelmodel_dump
#
# Generate a dictio...
#   model_dump_json:
#     Signature: (self, *, indent: 'int | None' = None, include: 'IncEx' = None, exclude: 'IncEx' = None, context: 'Any | None' = None, by_alias: 'bool' = False, exclude_unset: 'bool' = False, exclude_defaults: 'bool' = False, exclude_none: 'bool' = False, round_trip: 'bool' = False, warnings: "bool | Literal['none', 'warn', 'error']" = True, serialize_as_any: 'bool' = False) -> 'str'
#     Docstring: Usage docs: https://docs.pydantic.dev/2.8/concepts/serialization/#modelmodel_dump_json
#
# Generates a ...
#   model_post_init:
#     Signature: (self, _BaseModel__context: 'Any') -> 'None'
#     Docstring: Override this method to perform additional initialization after `__init__` and `model_construct`.
# Th...
#
# Attributes:
#   _abc_impl: <class '_abc._abc_data'>
#   _calculate_keys: <class 'function'>
#   _check_frozen: <class 'function'>
#   _copy_and_set_values: <class 'function'>
#   _iter: <class 'function'>
#   copy: <class 'function'>
#   dict: <class 'function'>
#   json: <class 'function'>
#   model_computed_fields: <class 'dict'>
#   model_config: <class 'dict'>
#   model_copy: <class 'function'>
#   model_dump: <class 'function'>
#   model_dump_json: <class 'function'>
#   model_extra: <class 'property'>
#   model_fields: <class 'dict'>
#   model_fields_set: <class 'property'>
#   model_post_init: <class 'function'>
#
# ==================================================
# DeleteEntity
# ==================================================
# Docstring:
# Usage docs: https://docs.pydantic.dev/2.8/concepts/models/
#
# A base class for creating Pydantic models.
#
# Attributes:
#     __class_vars__: The names of classvars defined on the model.
#     __private_attributes__: Metadata about the private attributes of the model.
#     __signature__: The signature for instantiating the model.
#
#     __pydantic_complete__: Whether model building is completed, or if there are still undefined fields.
#     __pydantic_core_schema__: The pydantic-core schema used to build the SchemaValidator and SchemaSerializer.
#     __pydantic_custom_init__: Whether the model has a custom `__init__` function.
#     __pydantic_decorators__: Metadata containing the decorators defined on the model.
#         This replaces `Model.__validators__` and `Model.__root_validators__` from Pydantic V1.
#     __pydantic_generic_metadata__: Metadata for generic models; contains data used for a similar purpose to
#         __args__, __origin__, __parameters__ in typing-module generics. May eventually be replaced by these.
#     __pydantic_parent_namespace__: Parent namespace of the model, used for automatic rebuilding of models.
#     __pydantic_post_init__: The name of the post-init method for the model, if defined.
#     __pydantic_root_model__: Whether the model is a `RootModel`.
#     __pydantic_serializer__: The pydantic-core SchemaSerializer used to dump instances of the model.
#     __pydantic_validator__: The pydantic-core SchemaValidator used to validate instances of the model.
#
#     __pydantic_extra__: An instance attribute with the values of extra fields from validation when
#         `model_config['extra'] == 'allow'`.
#     __pydantic_fields_set__: An instance attribute with the names of fields explicitly set.
#     __pydantic_private__: Instance attribute with the values of private attributes set on the model instance.
#
# Signature:
# (*, uuid: str) -> None
#
# Methods:
#   __copy__:
#     Signature: (self) -> 'Self'
#     Docstring: Returns a shallow copy of the model.
#   __deepcopy__:
#     Signature: (self, memo: 'dict[int, Any] | None' = None) -> 'Self'
#     Docstring: Returns a deep copy of the model.
#   __delattr__:
#     Signature: (self, item: 'str') -> 'Any'
#     Docstring: Implement delattr(self, name).
#   __eq__:
#     Signature: (self, other: 'Any') -> 'bool'
#     Docstring: Return self==value.
#   __getattr__:
#     Signature: (self, item: 'str') -> 'Any'
#   __getstate__:
#     Signature: (self) -> 'dict[Any, Any]'
#   __init__:
#     Signature: (self, /, **data: 'Any') -> 'None'
#     Docstring: Create a new model by parsing and validating input data from keyword arguments.
#
# Raises [`Validation...
#   __iter__:
#     Signature: (self) -> 'TupleGenerator'
#     Docstring: So `dict(model)` works.
#   __pretty__:
#     Signature: (self, fmt: 'typing.Callable[[Any], Any]', **kwargs: 'Any') -> 'typing.Generator[Any, None, None]'
#     Docstring: Used by devtools (https://python-devtools.helpmanual.io/) to pretty print objects.
#   __repr__:
#     Signature: (self) -> 'str'
#     Docstring: Return repr(self).
#   __repr_args__:
#     Signature: (self) -> '_repr.ReprArgs'
#   __repr_name__:
#     Signature: (self) -> 'str'
#     Docstring: Name of the instance's class, used in __repr__.
#   __repr_str__:
#     Signature: (self, join_str: 'str') -> 'str'
#   __rich_repr__:
#     Signature: (self) -> 'RichReprResult'
#     Docstring: Used by Rich (https://rich.readthedocs.io/en/stable/pretty.html) to pretty print objects.
#   __setattr__:
#     Signature: (self, name: 'str', value: 'Any') -> 'None'
#     Docstring: Implement setattr(self, name, value).
#   __setstate__:
#     Signature: (self, state: 'dict[Any, Any]') -> 'None'
#   __str__:
#     Signature: (self) -> 'str'
#     Docstring: Return str(self).
#   _calculate_keys:
#     Signature: (self, *args: 'Any', **kwargs: 'Any') -> 'Any'
#   _check_frozen:
#     Signature: (self, name: 'str', value: 'Any') -> 'None'
#   _copy_and_set_values:
#     Signature: (self, *args: 'Any', **kwargs: 'Any') -> 'Any'
#   _iter:
#     Signature: (self, *args: 'Any', **kwargs: 'Any') -> 'Any'
#   copy:
#     Signature: (self, *, include: 'AbstractSetIntStr | MappingIntStrAny | None' = None, exclude: 'AbstractSetIntStr | MappingIntStrAny | None' = None, update: 'Dict[str, Any] | None' = None, deep: 'bool' = False) -> 'Self'
#     Docstring: Returns a copy of the model.
#
# !!! warning "Deprecated"
#     This method is now deprecated; use `model...
#   dict:
#     Signature: (self, *, include: 'IncEx' = None, exclude: 'IncEx' = None, by_alias: 'bool' = False, exclude_unset: 'bool' = False, exclude_defaults: 'bool' = False, exclude_none: 'bool' = False) -> 'Dict[str, Any]'
#   json:
#     Signature: (self, *, include: 'IncEx' = None, exclude: 'IncEx' = None, by_alias: 'bool' = False, exclude_unset: 'bool' = False, exclude_defaults: 'bool' = False, exclude_none: 'bool' = False, encoder: 'Callable[[Any], Any] | None' = PydanticUndefined, models_as_dict: 'bool' = PydanticUndefined, **dumps_kwargs: 'Any') -> 'str'
#   model_copy:
#     Signature: (self, *, update: 'dict[str, Any] | None' = None, deep: 'bool' = False) -> 'Self'
#     Docstring: Usage docs: https://docs.pydantic.dev/2.8/concepts/serialization/#model_copy
#
# Returns a copy of the ...
#   model_dump:
#     Signature: (self, *, mode: "Literal['json', 'python'] | str" = 'python', include: 'IncEx' = None, exclude: 'IncEx' = None, context: 'Any | None' = None, by_alias: 'bool' = False, exclude_unset: 'bool' = False, exclude_defaults: 'bool' = False, exclude_none: 'bool' = False, round_trip: 'bool' = False, warnings: "bool | Literal['none', 'warn', 'error']" = True, serialize_as_any: 'bool' = False) -> 'dict[str, Any]'
#     Docstring: Usage docs: https://docs.pydantic.dev/2.8/concepts/serialization/#modelmodel_dump
#
# Generate a dictio...
#   model_dump_json:
#     Signature: (self, *, indent: 'int | None' = None, include: 'IncEx' = None, exclude: 'IncEx' = None, context: 'Any | None' = None, by_alias: 'bool' = False, exclude_unset: 'bool' = False, exclude_defaults: 'bool' = False, exclude_none: 'bool' = False, round_trip: 'bool' = False, warnings: "bool | Literal['none', 'warn', 'error']" = True, serialize_as_any: 'bool' = False) -> 'str'
#     Docstring: Usage docs: https://docs.pydantic.dev/2.8/concepts/serialization/#modelmodel_dump_json
#
# Generates a ...
#   model_post_init:
#     Signature: (self, _BaseModel__context: 'Any') -> 'None'
#     Docstring: Override this method to perform additional initialization after `__init__` and `model_construct`.
# Th...
#
# Attributes:
#   _abc_impl: <class '_abc._abc_data'>
#   _calculate_keys: <class 'function'>
#   _check_frozen: <class 'function'>
#   _copy_and_set_values: <class 'function'>
#   _iter: <class 'function'>
#   copy: <class 'function'>
#   dict: <class 'function'>
#   json: <class 'function'>
#   model_computed_fields: <class 'dict'>
#   model_config: <class 'dict'>
#   model_copy: <class 'function'>
#   model_dump: <class 'function'>
#   model_dump_json: <class 'function'>
#   model_extra: <class 'property'>
#   model_fields: <class 'dict'>
#   model_fields_set: <class 'property'>
#   model_post_init: <class 'function'>
#
# ==================================================
# Entity
# ==================================================
# Docstring:
# Usage docs: https://docs.pydantic.dev/2.8/concepts/models/
#
# A base class for creating Pydantic models.
#
# Attributes:
#     __class_vars__: The names of classvars defined on the model.
#     __private_attributes__: Metadata about the private attributes of the model.
#     __signature__: The signature for instantiating the model.
#
#     __pydantic_complete__: Whether model building is completed, or if there are still undefined fields.
#     __pydantic_core_schema__: The pydantic-core schema used to build the SchemaValidator and SchemaSerializer.
#     __pydantic_custom_init__: Whether the model has a custom `__init__` function.
#     __pydantic_decorators__: Metadata containing the decorators defined on the model.
#         This replaces `Model.__validators__` and `Model.__root_validators__` from Pydantic V1.
#     __pydantic_generic_metadata__: Metadata for generic models; contains data used for a similar purpose to
#         __args__, __origin__, __parameters__ in typing-module generics. May eventually be replaced by these.
#     __pydantic_parent_namespace__: Parent namespace of the model, used for automatic rebuilding of models.
#     __pydantic_post_init__: The name of the post-init method for the model, if defined.
#     __pydantic_root_model__: Whether the model is a `RootModel`.
#     __pydantic_serializer__: The pydantic-core SchemaSerializer used to dump instances of the model.
#     __pydantic_validator__: The pydantic-core SchemaValidator used to validate instances of the model.
#
#     __pydantic_extra__: An instance attribute with the values of extra fields from validation when
#         `model_config['extra'] == 'allow'`.
#     __pydantic_fields_set__: An instance attribute with the names of fields explicitly set.
#     __pydantic_private__: Instance attribute with the values of private attributes set on the model instance.
#
# Signature:
# (*, uuid: str, name: Optional[str], enum: Optional[str], basicEnum: Optional[str], system: bool, creator: str, creatorType: str, entityType: str, candidateId: str, verified: bool) -> None
#
# Methods:
#   __copy__:
#     Signature: (self) -> 'Self'
#     Docstring: Returns a shallow copy of the model.
#   __deepcopy__:
#     Signature: (self, memo: 'dict[int, Any] | None' = None) -> 'Self'
#     Docstring: Returns a deep copy of the model.
#   __delattr__:
#     Signature: (self, item: 'str') -> 'Any'
#     Docstring: Implement delattr(self, name).
#   __eq__:
#     Signature: (self, other: 'Any') -> 'bool'
#     Docstring: Return self==value.
#   __getattr__:
#     Signature: (self, item: 'str') -> 'Any'
#   __getstate__:
#     Signature: (self) -> 'dict[Any, Any]'
#   __init__:
#     Signature: (self, /, **data: 'Any') -> 'None'
#     Docstring: Create a new model by parsing and validating input data from keyword arguments.
#
# Raises [`Validation...
#   __iter__:
#     Signature: (self) -> 'TupleGenerator'
#     Docstring: So `dict(model)` works.
#   __pretty__:
#     Signature: (self, fmt: 'typing.Callable[[Any], Any]', **kwargs: 'Any') -> 'typing.Generator[Any, None, None]'
#     Docstring: Used by devtools (https://python-devtools.helpmanual.io/) to pretty print objects.
#   __repr__:
#     Signature: (self) -> 'str'
#     Docstring: Return repr(self).
#   __repr_args__:
#     Signature: (self) -> '_repr.ReprArgs'
#   __repr_name__:
#     Signature: (self) -> 'str'
#     Docstring: Name of the instance's class, used in __repr__.
#   __repr_str__:
#     Signature: (self, join_str: 'str') -> 'str'
#   __rich_repr__:
#     Signature: (self) -> 'RichReprResult'
#     Docstring: Used by Rich (https://rich.readthedocs.io/en/stable/pretty.html) to pretty print objects.
#   __setattr__:
#     Signature: (self, name: 'str', value: 'Any') -> 'None'
#     Docstring: Implement setattr(self, name, value).
#   __setstate__:
#     Signature: (self, state: 'dict[Any, Any]') -> 'None'
#   __str__:
#     Signature: (self) -> 'str'
#     Docstring: Return str(self).
#   _calculate_keys:
#     Signature: (self, *args: 'Any', **kwargs: 'Any') -> 'Any'
#   _check_frozen:
# ...
#     Signature: (self, item: 'str') -> 'Any'
#   __getstate__:
#     Signature: (self) -> 'dict[Any, Any]'
#   __init__:
#     Signature: (self, /, **data: 'Any') -> 'None'
#     Docstring: Create a new model by parsing and validating input data from keyword arguments.
#
# Raises [`Validation...
#   __iter__:
#     Signature: (self) -> 'TupleGenerator'
#     Docstring: So `dict(model)` works.
#   __pretty__:
#     Signature: (self, fmt: 'typing.Callable[[Any], Any]', **kwargs: 'Any') -> 'typing.Generator[Any, None, None]'
#     Docstring: Used by devtools (https://python-devtools.helpmanual.io/) to pretty print objects.
#   __repr__:
#     Signature: (self) -> 'str'
#     Docstring: Return repr(self).
#   __repr_args__:
#     Signature: (self) -> '_repr.ReprArgs'
#   __repr_name__:
#     Signature: (self) -> 'str'
#     Docstring: Name of the instance's class, used in __repr__.
#   __repr_str__:
#     Signature: (self, join_str: 'str') -> 'str'
#   __rich_repr__:
#     Signature: (self) -> 'RichReprResult'
#     Docstring: Used by Rich (https://rich.readthedocs.io/en/stable/pretty.html) to pretty print objects.
#   __setattr__:
#     Signature: (self, name: 'str', value: 'Any') -> 'None'
#     Docstring: Implement setattr(self, name, value).
#   __setstate__:
#     Signature: (self, state: 'dict[Any, Any]') -> 'None'
#   __str__:
#     Signature: (self) -> 'str'
#     Docstring: Return str(self).
#   _calculate_keys:
#     Signature: (self, *args: 'Any', **kwargs: 'Any') -> 'Any'
#   _check_frozen:
#     Signature: (self, name: 'str', value: 'Any') -> 'None'
#   _copy_and_set_values:
#     Signature: (self, *args: 'Any', **kwargs: 'Any') -> 'Any'
#   _iter:
#     Signature: (self, *args: 'Any', **kwargs: 'Any') -> 'Any'
#   copy:
#     Signature: (self, *, include: 'AbstractSetIntStr | MappingIntStrAny | None' = None, exclude: 'AbstractSetIntStr | MappingIntStrAny | None' = None, update: 'Dict[str, Any] | None' = None, deep: 'bool' = False) -> 'Self'
#     Docstring: Returns a copy of the model.
#
# !!! warning "Deprecated"
#     This method is now deprecated; use `model...
#   dict:
#     Signature: (self, *, include: 'IncEx' = None, exclude: 'IncEx' = None, by_alias: 'bool' = False, exclude_unset: 'bool' = False, exclude_defaults: 'bool' = False, exclude_none: 'bool' = False) -> 'Dict[str, Any]'
#   json:
#     Signature: (self, *, include: 'IncEx' = None, exclude: 'IncEx' = None, by_alias: 'bool' = False, exclude_unset: 'bool' = False, exclude_defaults: 'bool' = False, exclude_none: 'bool' = False, encoder: 'Callable[[Any], Any] | None' = PydanticUndefined, models_as_dict: 'bool' = PydanticUndefined, **dumps_kwargs: 'Any') -> 'str'
#   model_copy:
#     Signature: (self, *, update: 'dict[str, Any] | None' = None, deep: 'bool' = False) -> 'Self'
#     Docstring: Usage docs: https://docs.pydantic.dev/2.8/concepts/serialization/#model_copy
#
# Returns a copy of the ...
#   model_dump:
#     Signature: (self, *, mode: "Literal['json', 'python'] | str" = 'python', include: 'IncEx' = None, exclude: 'IncEx' = None, context: 'Any | None' = None, by_alias: 'bool' = False, exclude_unset: 'bool' = False, exclude_defaults: 'bool' = False, exclude_none: 'bool' = False, round_trip: 'bool' = False, warnings: "bool | Literal['none', 'warn', 'error']" = True, serialize_as_any: 'bool' = False) -> 'dict[str, Any]'
#     Docstring: Usage docs: https://docs.pydantic.dev/2.8/concepts/serialization/#modelmodel_dump
#
# Generate a dictio...
#   model_dump_json:
#     Signature: (self, *, indent: 'int | None' = None, include: 'IncEx' = None, exclude: 'IncEx' = None, context: 'Any | None' = None, by_alias: 'bool' = False, exclude_unset: 'bool' = False, exclude_defaults: 'bool' = False, exclude_none: 'bool' = False, round_trip: 'bool' = False, warnings: "bool | Literal['none', 'warn', 'error']" = True, serialize_as_any: 'bool' = False) -> 'str'
#     Docstring: Usage docs: https://docs.pydantic.dev/2.8/concepts/serialization/#modelmodel_dump_json
#
# Generates a ...
#   model_post_init:
#     Signature: (self, _BaseModel__context: 'Any') -> 'None'
#     Docstring: Override this method to perform additional initialization after `__init__` and `model_construct`.
# Th...
#
# Attributes:
#   _abc_impl: <class '_abc._abc_data'>
#   _calculate_keys: <class 'function'>
#   _check_frozen: <class 'function'>
#   _copy_and_set_values: <class 'function'>
#   _iter: <class 'function'>
#   copy: <class 'function'>
#   dict: <class 'function'>
#   json: <class 'function'>
#   model_computed_fields: <class 'dict'>
#   model_config: <class 'dict'>
#   model_copy: <class 'function'>
#   model_dump: <class 'function'>
#   model_dump_json: <class 'function'>
#   model_extra: <class 'property'>
#   model_fields: <class 'dict'>
#   model_fields_set: <class 'property'>
#   model_post_init: <class 'function'>
#
# ==================================================
# TraverseAlgorithm
# ==================================================
# Values:
#   DEPTH: depthfirst
#   BREADTH: breadthfirst
#
# ==================================================
# TraverseParams
# ==================================================
# Docstring:
# Usage docs: https://docs.pydantic.dev/2.8/concepts/models/
#
# A base class for creating Pydantic models.
#
# Attributes:
#     __class_vars__: The names of classvars defined on the model.
#     __private_attributes__: Metadata about the private attributes of the model.
#     __signature__: The signature for instantiating the model.
#
#     __pydantic_complete__: Whether model building is completed, or if there are still undefined fields.
#     __pydantic_core_schema__: The pydantic-core schema used to build the SchemaValidator and SchemaSerializer.
#     __pydantic_custom_init__: Whether the model has a custom `__init__` function.
#     __pydantic_decorators__: Metadata containing the decorators defined on the model.
#         This replaces `Model.__validators__` and `Model.__root_validators__` from Pydantic V1.
#     __pydantic_generic_metadata__: Metadata for generic models; contains data used for a similar purpose to
#         __args__, __origin__, __parameters__ in typing-module generics. May eventually be replaced by these.
#     __pydantic_parent_namespace__: Parent namespace of the model, used for automatic rebuilding of models.
#     __pydantic_post_init__: The name of the post-init method for the model, if defined.
#     __pydantic_root_model__: Whether the model is a `RootModel`.
#     __pydantic_serializer__: The pydantic-core SchemaSerializer used to dump instances of the model.
#     __pydantic_validator__: The pydantic-core SchemaValidator used to validate instances of the model.
#
#     __pydantic_extra__: An instance attribute with the values of extra fields from validation when
#         `model_config['extra'] == 'allow'`.
#     __pydantic_fields_set__: An instance attribute with the names of fields explicitly set.
#     __pydantic_private__: Instance attribute with the values of private attributes set on the model instance.
#
# Signature:
# (*, start_entity_uuid: str, direction: knowledge_engine_sdk.models.ConnectionDirection, min_depth: Optional[int], max_depth: Optional[int], algorithm: Optional[knowledge_engine_sdk.models.TraverseAlgorithm]) -> None
#
# Methods:
#   __copy__:
#     Signature: (self) -> 'Self'
#     Docstring: Returns a shallow copy of the model.
#   __deepcopy__:
#     Signature: (self, memo: 'dict[int, Any] | None' = None) -> 'Self'
#     Docstring: Returns a deep copy of the model.
#   __delattr__:
#     Signature: (self, item: 'str') -> 'Any'
#     Docstring: Implement delattr(self, name).
#   __eq__:
#     Signature: (self, other: 'Any') -> 'bool'
#     Docstring: Return self==value.
#   __getattr__:
#     Signature: (self, item: 'str') -> 'Any'
#   __getstate__:
#     Signature: (self) -> 'dict[Any, Any]'
#   __init__:
#     Signature: (self, /, **data: 'Any') -> 'None'
#     Docstring: Create a new model by parsing and validating input data from keyword arguments.
#
# Raises [`Validation...
#   __iter__:
#     Signature: (self) -> 'TupleGenerator'
#     Docstring: So `dict(model)` works.
#   __pretty__:
#     Signature: (self, fmt: 'typing.Callable[[Any], Any]', **kwargs: 'Any') -> 'typing.Generator[Any, None, None]'
#     Docstring: Used by devtools (https://python-devtools.helpmanual.io/) to pretty print objects.
#   __repr__:
#     Signature: (self) -> 'str'
#     Docstring: Return repr(self).
#   __repr_args__:
#     Signature: (self) -> '_repr.ReprArgs'
#   __repr_name__:
#     Signature: (self) -> 'str'
#     Docstring: Name of the instance's class, used in __repr__.
#   __repr_str__:
#     Signature: (self, join_str: 'str') -> 'str'
#   __rich_repr__:
#     Signature: (self) -> 'RichReprResult'
#     Docstring: Used by Rich (https://rich.readthedocs.io/en/stable/pretty.html) to pretty print objects.
#   __setattr__:
#     Signature: (self, name: 'str', value: 'Any') -> 'None'
#     Docstring: Implement setattr(self, name, value).
#   __setstate__:
#     Signature: (self, state: 'dict[Any, Any]') -> 'None'
#   __str__:
#     Signature: (self) -> 'str'
#     Docstring: Return str(self).
#   _calculate_keys:
#     Signature: (self, *args: 'Any', **kwargs: 'Any') -> 'Any'
#   _check_frozen:
#     Signature: (self, name: 'str', value: 'Any') -> 'None'
#   _copy_and_set_values:
#     Signature: (self, *args: 'Any', **kwargs: 'Any') -> 'Any'
#   _iter:
#     Signature: (self, *args: 'Any', **kwargs: 'Any') -> 'Any'
#   copy:
#     Signature: (self, *, include: 'AbstractSetIntStr | MappingIntStrAny | None' = None, exclude: 'AbstractSetIntStr | MappingIntStrAny | None' = None, update: 'Dict[str, Any] | None' = None, deep: 'bool' = False) -> 'Self'
#     Docstring: Returns a copy of the model.
#
# !!! warning "Deprecated"
#     This method is now deprecated; use `model...
#   dict:
#     Signature: (self, *, include: 'IncEx' = None, exclude: 'IncEx' = None, by_alias: 'bool' = False, exclude_unset: 'bool' = False, exclude_defaults: 'bool' = False, exclude_none: 'bool' = False) -> 'Dict[str, Any]'
#   json:
#     Signature: (self, *, include: 'IncEx' = None, exclude: 'IncEx' = None, by_alias: 'bool' = False, exclude_unset: 'bool' = False, exclude_defaults: 'bool' = False, exclude_none: 'bool' = False, encoder: 'Callable[[Any], Any] | None' = PydanticUndefined, models_as_dict: 'bool' = PydanticUndefined, **dumps_kwargs: 'Any') -> 'str'
#   model_copy:
#     Signature: (self, *, update: 'dict[str, Any] | None' = None, deep: 'bool' = False) -> 'Self'
#     Docstring: Usage docs: https://docs.pydantic.dev/2.8/concepts/serialization/#model_copy
#
# Returns a copy of the ...
#   model_dump:
#     Signature: (self, *, mode: "Literal['json', 'python'] | str" = 'python', include: 'IncEx' = None, exclude: 'IncEx' = None, context: 'Any | None' = None, by_alias: 'bool' = False, exclude_unset: 'bool' = False, exclude_defaults: 'bool' = False, exclude_none: 'bool' = False, round_trip: 'bool' = False, warnings: "bool | Literal['none', 'warn', 'error']" = True, serialize_as_any: 'bool' = False) -> 'dict[str, Any]'
#     Docstring: Usage docs: https://docs.pydantic.dev/2.8/concepts/serialization/#modelmodel_dump
#
# Generate a dictio...
#   model_dump_json:
#     Signature: (self, *, indent: 'int | None' = None, include: 'IncEx' = None, exclude: 'IncEx' = None, context: 'Any | None' = None, by_alias: 'bool' = False, exclude_unset: 'bool' = False, exclude_defaults: 'bool' = False, exclude_none: 'bool' = False, round_trip: 'bool' = False, warnings: "bool | Literal['none', 'warn', 'error']" = True, serialize_as_any: 'bool' = False) -> 'str'
#     Docstring: Usage docs: https://docs.pydantic.dev/2.8/concepts/serialization/#modelmodel_dump_json
#
# Generates a ...
#   model_post_init:
#     Signature: (self, _BaseModel__context: 'Any') -> 'None'
#     Docstring: Override this method to perform additional initialization after `__init__` and `model_construct`.
# Th...
#
# Attributes:
#   _abc_impl: <class '_abc._abc_data'>
#   _calculate_keys: <class 'function'>
#   _check_frozen: <class 'function'>
#   _copy_and_set_values: <class 'function'>
#   _iter: <class 'function'>
#   copy: <class 'function'>
#   dict: <class 'function'>
#   json: <class 'function'>
#   model_computed_fields: <class 'dict'>
#   model_config: <class 'dict'>
#   model_copy: <class 'function'>
#   model_dump: <class 'function'>
#   model_dump_json: <class 'function'>
#   model_extra: <class 'property'>
#   model_fields: <class 'dict'>
#   model_fields_set: <class 'property'>
#   model_post_init: <class 'function'>
#
# ==================================================
# ValidationError
# ==================================================
# Docstring:
# Inappropriate argument value (of correct type).
#
# Signature:
# No signature available
#
# Methods:
#
# Attributes:
#   args: <class 'getset_descriptor'>
#   error_count: <class 'method_descriptor'>
#   errors: <class 'method_descriptor'>
#   from_exception_data: <class 'builtin_function_or_method'>
#   json: <class 'method_descriptor'>
#   title: <class 'getset_descriptor'>
#   with_traceback: <class 'method_descriptor'>
#
# ==================================================
# datetime
# ==================================================
# Docstring:
# datetime(year, month, day[, hour[, minute[, second[, microsecond[,tzinfo]]]]])
#
# The year, month and day arguments are required. tzinfo may be None, or an
# instance of a tzinfo subclass. The remaining arguments may be ints.
#
# Signature:
# No signature available
#
# Methods:
#
# Attributes:
#   astimezone: <class 'method_descriptor'>
#   combine: <class 'builtin_function_or_method'>
#   ctime: <class 'method_descriptor'>
#   date: <class 'method_descriptor'>
#   day: <class 'getset_descriptor'>
#   dst: <class 'method_descriptor'>
#   fold: <class 'getset_descriptor'>
#   fromisocalendar: <class 'builtin_function_or_method'>
#   fromisoformat: <class 'builtin_function_or_method'>
#   fromordinal: <class 'builtin_function_or_method'>
#   fromtimestamp: <class 'builtin_function_or_method'>
#   hour: <class 'getset_descriptor'>
#   isocalendar: <class 'method_descriptor'>
#   isoformat: <class 'method_descriptor'>
#   isoweekday: <class 'method_descriptor'>
#   max: <class 'datetime.datetime'>
#   microsecond: <class 'getset_descriptor'>
#   min: <class 'datetime.datetime'>
#   minute: <class 'getset_descriptor'>
#   month: <class 'getset_descriptor'>
#   now: <class 'builtin_function_or_method'>
#   replace: <class 'method_descriptor'>
#   resolution: <class 'datetime.timedelta'>
#   second: <class 'getset_descriptor'>
#   strftime: <class 'method_descriptor'>
#   strptime: <class 'builtin_function_or_method'>
#   time: <class 'method_descriptor'>
#   timestamp: <class 'method_descriptor'>
#   timetuple: <class 'method_descriptor'>
#   timetz: <class 'method_descriptor'>
#   today: <class 'builtin_function_or_method'>
#   toordinal: <class 'method_descriptor'>
#   tzinfo: <class 'getset_descriptor'>
#   tzname: <class 'method_descriptor'>
#   utcfromtimestamp: <class 'builtin_function_or_method'>
#   utcnow: <class 'builtin_function_or_method'>
#   utcoffset: <class 'method_descriptor'>
#   utctimetuple: <class 'method_descriptor'>
#   weekday: <class 'method_descriptor'>
#   year: <class 'getset_descriptor'>
#
# Functions:
#
# Variables:
#   errors: <class 'module'>
#   knowledge_engine_sdk: <class 'module'>
#   models: <class 'module'>
#   utils: <class 'module'>
#
# Knowledge Engine SDK Version: Not available
#
# Detailed KnowledgeEngine Methods:
#
# _init_db:
# Signature: (self, main_db, base_url, username, password)
#
# create_candidate_id:
# Signature: (self)
#
# create_connection:
# Signature: (self, data: knowledge_engine_sdk.models.CreateConnection)
#
# create_entity:
# Signature: (self, data: knowledge_engine_sdk.models.CreateEntity)
#
# delete_connection:
# Signature: (self, data: knowledge_engine_sdk.models.DeleteConnection)
#
# delete_entity:
# Signature: (self, data: knowledge_engine_sdk.models.DeleteEntity)
#
# get_connection:
# Signature: (self, params: knowledge_engine_sdk.models.GetConnectionParams)
#
# get_connection_types:
# Signature: (self)
#
# get_connections:
# Signature: (self, params: knowledge_engine_sdk.models.GetConnectionListParams)
#
# get_entities:
# Signature: (self, params: Optional[knowledge_engine_sdk.models.GetEntityListParams])
#
# get_entity:
# Signature: (self, params: knowledge_engine_sdk.models.GetEntityParams)
#
# get_entity_types:
# Signature: (self)
#
# traverse_graph:
# Signature: (self, params: knowledge_engine_sdk.models.TraverseParams)
